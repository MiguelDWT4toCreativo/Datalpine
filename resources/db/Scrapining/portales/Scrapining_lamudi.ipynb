# %% [markdown]
# # **Limpieza**

# %% [markdown]
# #### LIBRERÍAS

# %%
import pandas as pd # Manipulación df
import os # Directorios
import re # Manipulación de cadenas de texto (expresiones regulares)
import unicodedata # Función para eliminar acentos
from datetime import datetime, date  # Para trabajar con fechas y horas
from currency_converter import CurrencyConverter # convertidor de monedas
from dateutil.relativedelta import relativedelta  # Para calcular diferencias entre fechas, incluyendo años, meses y días

# %% [markdown]
# #### CARGAR ARCHIVO

# %% [markdown]
# Solo cambia el nombre en 'archivo_filename' y su ruta con 'archivo_dir'

# %%
directorio_actual = os.getcwd() # Directorio actual de trabajo
# Ruta relativa al archivo CSV
archivo_filename = "ruta/relativa/al/archivo.csv"
archivo_dir = os.path.join(directorio_actual)
archivo_path = os.path.join(archivo_dir, archivo_filename)

# %% [markdown]
# Elimina el # de la primer línea si el archivo a leer no contiene el nombre de las columnas

# %%
#column_names=['precio','denominacion','propiedad','metros_total','metros_construido','tiempo_de_publicacion','tipo','estacionamientos','recamaras','banos','medio_banos','seguridad_privada','ubicacion','url','descripcion']
df = pd.read_csv(archivo_path)
df.info()

# Elegir tipo de archivo a leer
#df = pd.read_excel(csv_path) 
df = pd.read_csv(archivo_path)

# %% [markdown]
# #### LIMPIEZA NULOS

# %%
df.fillna({'precio': 0}, inplace=True) 
#df.fillna({'denominacion': 'MXN'}, inplace=True) 
df.fillna({'propiedad': 'Propiedad sin título'}, inplace=True) 
df.fillna({'metros_total': 0}, inplace=True) 
df.fillna({'metros_construido': 0}, inplace=True) 
#df.fillna({'tiempo_de_publicacion': '1 ene 1000'}, inplace=True) 
df.fillna({'tipo': 'Propiedad sin tipo de casa'}, inplace=True) 
df.fillna({'estacionamientos': 0}, inplace=True) 
df.fillna({'recamaras': 0}, inplace=True) 
df.fillna({'banos': 0}, inplace=True) 
df.fillna({'medio_banos': 0}, inplace=True) 
df.fillna({'seguridad_privada': 'No'}, inplace=True) 
df.fillna({'ubicacion': 'Propiedad sin ubicación'}, inplace=True) 
df.fillna({'url': '-'}, inplace=True) 
df.fillna({'descripcion': "Propiedad sin descripcion"}, inplace=True)

# %% [markdown]
# # 1. Manipulación de precios

# %% [markdown]
# ## a) Precio en descripción

# %% [markdown]
# Agrega las diferentes formas de que el precio se encuentre en la descripción.

# %%
def extraer_precio(descripcion):
    descripcion = descripcion.lower()
    # Buscar patrones
    precios = re.findall(r'\b(\d+[\.,]?\d*[\.,]?\d*)\s*($|mxn|USD|precio|pesos|monto|)', descripcion)
    precio = None
    for match in precios:
        numero, moneda = match
        numero = numero.replace(',', '').replace("'", '').replace(".",'')
        try:
            precio = float(numero)
        except ValueError:
            continue
        if precio:
            break
    return precio

# Denominación de la descripción
def extraer_denominacion(descripcion):
    descripcion = descripcion.lower()
    # Buscar patrones 
    denominaciones = re.findall(r'\b(mil|mxn|precio|pesos|monto|Mexicanos|Estadounidenses)\b', descripcion)
    return denominaciones[0] if denominaciones else None

df['precio_desc'] = df['descripcion'].apply(extraer_precio)
#df['denominacion_desc'] = df['descripcion'].apply(extraer_denominacion)

# %% [markdown]
# ### Precio [0 / 0]

# %%
# Filtrar los registros según las condiciones dadas
totales = df[( (df['precio'] == 0 ) & (df['precio_desc'].isna()) )] 
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas
# Iterar sobre los registros filtrados
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    print(row[['precio', 'precio_desc', 'url']])
    print("\n¿Qué acción te gustaría realizar?")
    print("1. Sustituir el valor manualmente")
    print("2. Pasar al siguiente registro")

    # Solicitar la opción al usuario
    option = input("Elige una opción (1 o 2): ")

    if option == '1':
        # Sustituir el valor manualmente
        new_value = input("Introduce el nuevo valor para 'precio': ")
        df.at[idx, 'precio'] = float(new_value)
    elif option == '2':
        # Pasar al siguiente registro
        continue
    else:
        print("Opción no válida. Pasando al siguiente registro...")
    
    print("\n---\n")

print("Proceso completado.")
# Out:
# Proceso completado.

# %% [markdown]
# Eliminar registros que no recuperaron su precio ni desde la descripción

# %%
df = df[~( (df['precio'] == 0 ) & (df['precio_desc'].isna()) )]

# %% [markdown]
# ### Precio [0 / #]

# %%
# Filtrar los registros según las condiciones dadas
totales = df[( (df['precio'] == 0 ) & (df['precio_desc'].notna()) )] 
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# Iterar sobre los registros filtrados
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    print(row[['precio', 'precio_desc', 'url']])
    print("\n¿Qué acción te gustaría realizar?")
    print("1. Sustituir el valor manualmente")
    print("2. Sustituir el valor de 'precio' por el de 'precio_desc'")
    print("3. Pasar al siguiente registro")

    # Solicitar la opción al usuario
    option = input("Elige una opción (1, 2, 3): ")

    if option == '1':
        # Sustituir el valor manualmente
        new_value = input("Introduce el nuevo valor para 'precio': ")
        df.at[idx, 'precio'] = float(new_value)
    elif option == '2':
        # Sustituir el valor de 'metros_total' por 'totales_desc'
        df.at[idx, 'precio'] = df.at[idx, 'precio_desc']
    elif option == '3':
        # Pasar al siguiente registro
        continue
    else:
        print("Opción no válida. Pasando al siguiente registro...")
    
    print("\n---\n")

print("Proceso completado.")
# Out:
# Proceso completado.

# %% [markdown]
# ### Precio [# / #]

# %%
# Filtrar los registros según las condiciones dadas
totales = df[( ((df['precio']!= 0) & (df['precio_desc'].notna())) & (df['precio'] != df['precio_desc']) )] 
# Filtro dentro del estándar
totales = totales[(totales['precio_desc'] >= 250000) & (totales['precio_desc'] <= 500000000)]
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# Iterar sobre los registros filtrados
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    print(row[['precio', 'precio_desc', 'url']])
    print("\n¿Qué acción te gustaría realizar?")
    print("1. Sustituir el valor manualmente")
    print("2. Sustituir el valor de 'precio' por el de 'precio_desc'")
    print("3. Pasar al siguiente registro")

    # Solicitar la opción al usuario
    option = input("Elige una opción (1, 2, 3): ")

    if option == '1':
        # Sustituir el valor manualmente
        new_value = input("Introduce el nuevo valor para 'precio': ")
        df.at[idx, 'precio'] = float(new_value)
    elif option == '2':
        # Sustituir el valor de 'metros_total' por 'totales_desc'
        df.at[idx, 'precio'] = df.at[idx, 'precio_desc']
    elif option == '3':
        # Pasar al siguiente registro
        continue
    else:
        print("Opción no válida. Pasando al siguiente registro...")

    print("\n---\n")

print("Proceso completado.")

# %% [markdown]
# ## b) Denominación MXN

# %% [markdown]
# SI EXISTE UNA DENOMINACIÓN QUE NO SEA MXN, SE CONVIERTA EL PRECIO

# %%
import datetime
c = CurrencyConverter() # Instancia del convertidor de monedas
def convertir_a_mxn(precio, denominacion):
    if denominacion != 'MXN':
        return int(round(c.convert(precio, denominacion, 'MXN')))
    return precio

def convertir_a_usd(precio, denominacion):
    if denominacion != 'USD':
        return round(c.convert(precio, denominacion, 'USD'))
    return precio

# Obtener la fecha actual
fecha_conversion = datetime.datetime.now().date()

# Aplicar la conversión a cada fila del DataFrame y agregar la fecha de conversión
df['precio_mxn'] = df.apply(lambda row: convertir_a_mxn(row['precio'], row['denominacion']), axis=1)
df['precio_usd'] = df.apply(lambda row: convertir_a_usd(row['precio'], row['denominacion']), axis=1)
df['fecha_conversion'] = fecha_conversion
print(df[['precio', 'denominacion', 'precio_mxn', 'precio_usd', 'fecha_conversion']].head())
# Out:
#     precio denominacion  precio_mxn  precio_usd fecha_conversion
# 0  8000000          MXN     8000000   444999.64       2024-09-19
# 1  4810000          MXN     4810000   267556.03       2024-09-19
# 2  4500000          MXN     4500000   250312.30       2024-09-19
# 3  4300000          MXN     4300000   239187.31       2024-09-19
# 4  3946465          MXN     3946465   219521.94       2024-09-19

# %% [markdown]
# ## c) Precio fuera del estandar

# %% [markdown]
# IDENTIFICAR Y ELIMINAR PROPIEDADES QUE CUENTEN CON PRECIOS BAJOS y ALTOS AL ESTANDAR

# %%
# Eliminar los registros donde el precio es menor al estandar (250,000) y con precio_desc vacío
df = df[(df['precio'] >= 250000)] #& (df['precio_desc'].notna())]
# Eliminar los registros donde el precio es mayor al estandar (500,000,000) y con precio_desc vacío
df = df[(df['precio'] <= 500000000)] #& (df['precio_desc'].notna())] 
# Ordenar valores de manera ascendente
df['precio'].sort_values()
# Out:
# 1605      415000
# 1604      419710
# 1603      419770
# 1598      419770
# 1602      419770
#           ...
# 4       24000000
# 3       24000000
# 2       26000000
# 1       27000000
# 0       32000000
# Name: precio, Length: 1607, dtype: int64

# %% [markdown]
# ## D) Segmento o categoría

# %%
# Crear un diccionario donde las llaves son las categorías y los valores son las tuplas de rangos
rangos_precio = {
    "E1": (0, 500000),
    "E2": (500000, 750000),
    "E3": (750001, 1000000),
    "D1": (1000001, 1250000),
    "D2": (1250001, 1500000),
    "D3": (1500001, 1750000),
    "C1": (1750001, 2000000),
    "C2": (2000001, 2250000),
    "C3": (2250001, 2500000),
    "B1": (2500001, 2750000),  
    "B2": (2750001, 3000000),  
    "B3": (3000001, 3250000),  
    "A1": (3250001, 3500000),
    "A2": (3500001, 3750000),
    "A3": (3750001, 4000000),
    "S1": (4000001, 6000000),
    "S2": (6000001, 8000000),
    "S3": (8000001, 12000000),
    "L1": (12000001, 14000000),
    "L2": (14000001, 16000000),
    "L3": (16000001, 18000000),
    "L+": (18000001, 22000000),
    "ELITE": (22000001, float('inf'))
}

# Función para asignar la categoría según el precio
def asignar_categoria(precio):
    for categoria, (limite_inferior, limite_superior) in rangos_precio.items():
        if limite_inferior <= precio < limite_superior:
            return categoria
    return None  # En caso de que el precio no caiga en ningún rango (caso raro)

# Asignar la categoría a cada registro
df['categoria'] = df['precio'].apply(asignar_categoria)
print(df['categoria'].unique())
# Out:
# [None 'S1' 'A3' 'A2' 'A1' 'B3' 'B2' 'B1' 'C3' 'C2' 'C1' 'D3' 'D2' 'D1'
#  'E3' 'E2' 'E1']

# %% [markdown]
# # 2. Meses transcurridos

# %% [markdown]
# Sacar el número de meses transcurridos desde la fecha de su publicación a la actual

# %%
from dateutil.relativedelta import relativedelta  # Diferencias entre fechas, incluyendo años, meses y días
from datetime import datetime
# Convertir el mes abreviado en número
def month_to_int(month):
    months = ['ene', 'feb', 'mar', 'abr', 'may', 'jun', 'jul', 'ago', 'sep', 'oct', 'nov', 'dic']
    return months.index(month.lower()) + 1

# Estandarizar el formato de fecha
def standardize_date(date_str):
    # Caso 1: formato "20 abr. 2023" -> "2023-04-20"
    try:
        day, month, year = date_str.split(' ')
        month_int = month_to_int(month.replace('.', ''))  # Eliminar puntos si existen
        return f"{year}-{month_int:02d}-{int(day):02d}"
    except (ValueError, AttributeError):
        pass

    # Caso 2: formato "YYYY-MM-DD HH:MM:SS" o "YYYY-MM-DD"
    try:
        return pd.to_datetime(date_str).strftime('%Y-%m-%d')
    except (ValueError, TypeError):
        # Si no se puede convertir, devolver None
        return None

# Aplicar la función a la columna 'tiempo_de_publicacion'
df['fecha_estandarizada'] = df['tiempo_de_publicacion'].apply(standardize_date)

# Convertir a datetime y manejar errores
df['fecha_estandarizada'] = pd.to_datetime(df['fecha_estandarizada'], errors='coerce')

# Obtener la fecha actual
fecha_actual = datetime.now().date()

# Función para calcular la diferencia en meses
def calcular_meses(fecha):
    if pd.isnull(fecha):
        return None
    rd = relativedelta(fecha_actual, fecha.date())
    return rd.years * 12 + rd.months

# Aplicar la función para calcular los meses transcurridos
df['meses_transcurridos'] = df['fecha_estandarizada'].apply(calcular_meses)

#Registro de fecha de conversión
df['meses_transcurridos_fecha'] = fecha_actual

# Mostrar el DataFrame con las fechas estandarizadas y meses transcurridos
print(df[['tiempo_de_publicacion', 'fecha_estandarizada', 'meses_transcurridos','meses_transcurridos_fecha']])
# Out:
#     tiempo_de_publicacion fecha_estandarizada  meses_transcurridos  \
# 0              2023-03-29          2023-03-29                   17
# 1              2023-04-28          2023-04-28                   16
# 2              2024-01-11          2024-01-11                    8
# 3              2023-09-13          2023-09-13                   12
# 4              2024-02-21          2024-02-21                    6
# ..                    ...                 ...                  ...
# 127            2024-03-04          2024-03-04                    6
# 128            2024-03-04          2024-03-04                    6
# 129            2024-02-17          2024-02-17                    7
# 130            2023-09-20          2023-09-20                   11
# 131            2024-03-04          2024-03-04                    6
#
#     meses_transcurridos_fecha
# 0                  2024-09-19
# 1                  2024-09-19
# 2                  2024-09-19
# 3                  2024-09-19
# 4                  2024-09-19
# ..                        ...
# 127                2024-09-19
# 128                2024-09-19
# 129                2024-09-19
# 130                2024-09-19
# 131                2024-09-19
#
# [132 rows x 4 columns]

# %% [markdown]
# # 3. Tipo de propiedad

# %% [markdown]
# ## a) Lista de tipos deseados

# %%
# Filtrar los registros según los tipos especificados
tipos_permitidos = 'Casa|Casa en Condominio|Departamento|Penthouse|Dúplex|Loft|Estudio|Condominio Horizontal'
df = df[df['tipo'].str.contains(tipos_permitidos, na=False)]
df['tipo'].unique()
# Out:
# array(['Departamento', 'Condominio Horizontal', 'Casa', 'Dúplex',
#        'Casa Dúplex', 'Casa en Fraccionamiento', 'Casa en Condominio'],
#       dtype=object)

# %% [markdown]
# * Casas: Casa en condominio,
# * Departamento: Penthouse, Loft

# %% [markdown]
# ## b) Manejo de terrenos

# %% [markdown]
# Se buscan los registros que no sean las propiedades si no un solo terreno

# %%
# Filtrar los registros según las condiciones dadas
totales =df[df['descripcion'].str.contains('lote', case=False)]
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# MANEJAR PROCESO DE ELIMINACIÓN 
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    print(row[['url']])#'descripcion',
    
    print("\n¿Te gustaría eliminar el registro?")
    # Solicitar la opción al usuario
    option = input("Elige una opción (si / no): ").strip().lower()
    
    if option == 'si':
        df.drop(idx, inplace=True)
        print(f"Registro eliminado.\n")
    else:
        print(f"Registro conservado.\n")
        print("\n---\n")
print("Proceso completado.")

# %% [markdown]
# ## C) Estandarizar

# %%
# Convierte todos los valores a strings, maneja NaN o None como cadenas vacías
df['tipo'] = df['tipo'].astype(str)
# Convertir a minúsculas
df['tipo'] = df['tipo'].str.lower()

import unicodedata# Función para eliminar acentos
def eliminar_acentos(texto):
    # Normaliza y elimina los acentos
    texto_normalizado = unicodedata.normalize('NFKD', texto)
    return ''.join(char for char in texto_normalizado if unicodedata.category(char) != 'Mn')
df['tipo'] = df['tipo'].apply(eliminar_acentos)

# Reemplazar Ñ
#df['propiedad'] = df['propiedad'].str.replace('ñ', 'n')
df['tipo'] = df['tipo'].str.replace(r'[^a-zA-Z0-9\s]', '', regex=True)
# Convertir la primera letra de cada palabra a mayúscula
df['tipo'] = df['tipo'].str.title()
df['tipo'].unique()
# Out:
# array(['Casa', 'Casa En Fraccionamiento', 'Departamento',
#        'Casa En Condominio', 'Condominio Horizontal'], dtype=object)

# %% [markdown]
# # 4. Metros totales

# %% [markdown]
# ## a) Metros en descripción

# %%
# Función para extraer totales de la descripción
def extraer_totales(descripcion):
    descripcion = descripcion.lower()
    # Buscar patrones de totales
    totales = re.findall(r'\b(\d+[\.,]?\d*)\s*(metros|totales|mt2)\b', descripcion)
    total = None
    for match in totales:
        numero, _ = match
        numero = numero.replace(',', '').replace("'", '')
        try:
            total = float(numero)
        except ValueError:
            continue
        if total:
            break
    return total

# Aplicar la función al DataFrame
df['totales_desc'] = df['descripcion'].apply(extraer_totales)

# %% [markdown]
# ### Metros [0 / 0]

# %%
# Filtrar los registros según las condiciones dadas
totales = df[( (df['metros_total'] == 0 ) & (df['totales_desc'].isna() | df['totales_desc']==0) )] 
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# Iterar sobre los registros filtrados
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    print(row[['metros_total', 'totales_desc', 'url']])
    print("\n¿Qué acción te gustaría realizar?")
    print("1. Sustituir el valor manualmente")
    print("2. Sustituir el valor de 'metros_total' por el de 'totales_desc'")
    print("3. Pasar al siguiente registro")

    # Solicitar la opción al usuario
    option = input("Elige una opción (1, 2, 3): ")

    if option == '1':
        # Sustituir el valor manualmente
        new_value = input("Introduce el nuevo valor para 'metros_total': ")
        df.at[idx, 'metros_total'] = float(new_value)
    elif option == '2':
        # Sustituir el valor de 'metros_total' por 'totales_desc'
        df.at[idx, 'metros_total'] = df.at[idx, 'totales_desc']
    elif option == '3':
        # Pasar al siguiente registro
        continue
    else:
        print("Opción no válida. Pasando al siguiente registro...")
    
    print("\n---\n")

print("Proceso completado.")
# Out:
# Proceso completado.

# %% [markdown]
# ### Metros [0 / #]

# %%
# Filtrar los registros según las condiciones dadas
totales = df[( (df['metros_total'] == 0 ) & (df['totales_desc'].notna()) )] 
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# Iterar sobre los registros filtrados
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    print(row[['metros_total', 'totales_desc', 'url']])
    print("\n¿Qué acción te gustaría realizar?")
    print("1. Sustituir el valor manualmente")
    print("2. Sustituir el valor de 'metros_total' por el de 'totales_desc'")
    print("3. Pasar al siguiente registro")

    # Solicitar la opción al usuario
    option = input("Elige una opción (1, 2, 3): ")

    if option == '1':
        # Sustituir el valor manualmente
        new_value = input("Introduce el nuevo valor para 'metros_total': ")
        df.at[idx, 'metros_total'] = float(new_value)
    elif option == '2':
        # Sustituir el valor de 'metros_total' por 'totales_desc'
        df.at[idx, 'metros_total'] = df.at[idx, 'totales_desc']
    elif option == '3':
        # Pasar al siguiente registro
        continue
    else:
        print("Opción no válida. Pasando al siguiente registro...")
    
    print("\n---\n")

print("Proceso completado.")
# Out:
# Proceso completado.

# %% [markdown]
# ### Metros [# / #]

# %%
# Filtrar los registros según las condiciones dadas
totales = df[( ((df['metros_total']!= 0) & (df['totales_desc'].notna())) & (df['metros_total'] != df['totales_desc']) )] 
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# Iterar sobre los registros filtrados
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    print(f"metros_total: {row['metros_total']}")
    print(f"totales_desc: {row['totales_desc']}")
    print(f"url: {row['url']}")
    
    print("\n¿Qué acción te gustaría realizar?")
    print("1. Sustituir el valor manualmente")
    print("2. Sustituir el valor de 'metros_total' por el de 'totales_desc'")
    print("3. Pasar al siguiente registro")

    # Solicitar la opción al usuario
    option = input("Elige una opción (1, 2, 3): ")

    if option == '1':
        # Sustituir el valor manualmente
        while True:
            try:
                new_value = float(input("Introduce el nuevo valor para 'metros_total': "))
                df.at[idx, 'metros_total'] = new_value
                break
            except ValueError:
                print("Por favor, introduce un número válido (entero o decimal).")
    elif option == '2':
        # Sustituir el valor de 'metros_total' por 'totales_desc'
        df.at[idx, 'metros_total'] = df.at[idx, 'totales_desc']
    elif option == '3':
        # Pasar al siguiente registro
        continue
    else:
        print("Opción no válida. Pasando al siguiente registro...")
    print("\n---\n")

print("Proceso completado.")

# %% [markdown]
# ## b) Manejo por rangos de UMA

# %% [markdown]
# Paso opcional por si no se espera cambiar el precio por el que se tenga en descripción

# %% [markdown]
# Rangos
# * 118 UMAS = 40m2
# * 118.1-200 = 50m2
# * 200.1-350 = 71m2
# * 350.1-750 = 102m2
# * 750.1-1500 = 156m2

# %% [markdown]
# ### DF cuando ambas columnas son 0 o vacíos

# %%
# Rangos de UMAs y sus equivalencias en m²
umas_to_m2 = [
    (118, 40),
    (200, 50),
    (350, 71),
    (750, 102),
    (1500, 156)
]
valor_uma = 108.57

# Convertir MXN a UMAs
def precio_a_umas(precio, valor_uma):
    return precio / valor_uma

# Asignar m² basado en el precio en UMAs
def asignar_m2(precio_umas):
    for upper_bound, m2 in umas_to_m2:
        if precio_umas <= upper_bound:
            return m2
    return None  # En caso de que el precio en UMAs sea mayor al máximo definido

# Actualizar los registros con 'metros_total' igual a 0 y 'totales_desc' es NaN
def actualizar_metros_total(row):
    if row['metros_total'] == 0 and pd.isna(row['totales_desc']):
        precio_umas = precio_a_umas(row['precio'], valor_uma)
        row['metros_total'] = asignar_m2(precio_umas)
    return row

totales = df[( (df['metros_total'] == 0 ) & (df['totales_desc'].isna() | df['totales_desc']==0) )] 
totales = df.apply(actualizar_metros_total, axis=1)
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

#df = df.apply(actualizar_metros_total, axis=1)
print(totales[['metros_total', 'totales_desc', 'url']])

# %%
# Si se aceptan los cambios:
df = df.apply(actualizar_metros_total, axis=1)

# %% [markdown]
# # 5. M2 construidos

# %% [markdown]
# ## a) M-construidos en descripción

# %%
# Función para extraer totales de la descripción
def extraer_totales(descripcion):
    descripcion = descripcion.lower()
    # Buscar patrones de totales
    totales = re.findall(r'\b(\d+[\.,]?\d*)\s*(metros|construidos)\b', descripcion)
    total = None
    for match in totales:
        numero, _ = match
        numero = numero.replace(',', '').replace("'", '')
        try:
            total = float(numero)
        except ValueError:
            continue
        if total:
            break
    return total

# Aplicar la función al DataFrame
df['construidos_desc'] = df['descripcion'].apply(extraer_totales)

# %% [markdown]
# ### Metros [0 / 0]

# %%
# Filtrar los registros según las condiciones dadas
totales = df[( (df['metros_construido'] == 0 ) & (df['construidos_desc'].isna() | df['construidos_desc']==0) )] 
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# Iterar sobre los registros filtrados
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    print(row[['metros_construido', 'construidos_desc', 'url']])
    print("\n¿Qué acción te gustaría realizar?")
    print("1. Sustituir el valor manualmente")
    print("2. Sustituir el valor de 'metros_construido' por el de 'construidos_desc'")
    print("3. Pasar al siguiente registro")

    # Solicitar la opción al usuario
    option = input("Elige una opción (1, 2, 3): ")

    if option == '1':
        # Sustituir el valor manualmente
        new_value = input("Introduce el nuevo valor para 'metros_construido': ")
        df.at[idx, 'metros_construido'] = float(new_value)
    elif option == '2':
        # Sustituir el valor de 'metros_construido' por 'construidos_desc'
        df.at[idx, 'metros_construido'] = df.at[idx, 'construidos_desc']
    elif option == '3':
        # Pasar al siguiente registro
        continue
    else:
        print("Opción no válida. Pasando al siguiente registro...")
    
    print("\n---\n")

print("Proceso completado.")
# Out:
# Proceso completado.

# %% [markdown]
# ### Metros [0 / #]

# %%
# Filtrar los registros según las condiciones dadas
totales = df[( (df['metros_construido'] == 0 ) & (df['construidos_desc'].notna()) )] 
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# Iterar sobre los registros filtrados
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    print(row[['metros_construido', 'construidos_desc', 'url']])
    print("\n¿Qué acción te gustaría realizar?")
    print("1. Sustituir el valor manualmente")
    print("2. Sustituir el valor de 'metros_construido' por el de 'construidos_desc'")
    print("3. Pasar al siguiente registro")

    # Solicitar la opción al usuario
    option = input("Elige una opción (1, 2, 3): ")

    if option == '1':
        # Sustituir el valor manualmente
        new_value = input("Introduce el nuevo valor para 'metros_construido': ")
        df.at[idx, 'metros_construido'] = float(new_value)
    elif option == '2':
        # Sustituir el valor de 'metros_construido' por 'construidos_desc'
        df.at[idx, 'metros_construido'] = df.at[idx, 'construidos_desc']
    elif option == '3':
        # Pasar al siguiente registro
        continue
    else:
        print("Opción no válida. Pasando al siguiente registro...")
    
    print("\n---\n")

print("Proceso completado.")
# Out:
# Proceso completado.

# %% [markdown]
# ### Metros [# / #]

# %%
# Filtrar los registros según las condiciones dadas
totales = df[( ((df['metros_construido']!= 0) & (df['construidos_desc'].notna())) & (df['metros_construido'] != df['construidos_desc']) )] 
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# Iterar sobre los registros filtrados
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    print(row[['metros_construido', 'construidos_desc', 'url']])
    print("\n¿Qué acción te gustaría realizar?")
    print("1. Sustituir el valor manualmente")
    print("2. Sustituir el valor de 'metros_construido' por el de 'construidos_desc'")
    print("3. Pasar al siguiente registro")

    # Solicitar la opción al usuario
    option = input("Elige una opción (1, 2, 3): ")

    if option == '1':
        # Sustituir el valor manualmente
        new_value = input("Introduce el nuevo valor para 'metros_construido': ")
        try:
            df.at[idx, 'metros_construido'] = float(new_value)
        except ValueError:
            print("Valor no válido. Debe ser un número. Pasando al siguiente registro...")
    elif option == '2':
        # Sustituir el valor de 'metros_construido' por 'construidos_desc'
        df.at[idx, 'metros_construido'] = df.at[idx, 'construidos_desc']
    elif option == '3':
        # Pasar al siguiente registro
        continue
    else:
        print("Opción no válida. Pasando al siguiente registro...")
    
    print("\n---\n")

print("Proceso completado.")

# %% [markdown]
# # 6. Precio / m2

# %% [markdown]
# ## M2 Totales (terreno)

# %%
# Calcular precio por metro cuadrado del terreno
df['precio_m2_terreno'] = df['precio']/df['metros_total']

# %% [markdown]
# ## M2 Construidos

# %%
# Calcular precio por metro cuadrado de la cosntrucción
df['precio_m2_construido'] = df['precio']/df['metros_construido']

# %% [markdown]
# # 7. Estacionamientos

# %% [markdown]
# ## a) Estacionamientos descritos

# %% [markdown]
# Asigna las diferentes maneras en las que puede encontrarse descrito el espacio de estacionamientos

# %%
# Función para extraer estacionamientos de la descripción
def extraer_coches(descripcion):
    descripcion = descripcion.lower()
    # Buscar patrones de totales
    totales = re.findall(r'\b(\d+[\.,]?\d*)\s*(|cochera|garage|carros|carro|coche|coches|autos|automóviles|automóvil|auto|lugares de estacionamiento)\b', descripcion)
    total = None
    for match in totales:
        numero, _ = match
        numero = numero.replace(',', '').replace("'", '').replace('.','')
        try:
            total = float(numero)
        except ValueError:
            continue
        if total:
            break
    return total

# Aplicar la función al DataFrame
df['estacionamiento_desc'] = df['descripcion'].apply(extraer_coches)

# %% [markdown]
# ### Estacionamientos [0 / 0]

# %%
# Filtrar los registros según las condiciones dadas
totales = df[( (df['estacionamientos']==0) & (df['estacionamiento_desc'].isna()) )] 
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# Iterar sobre los registros filtrados
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    print(row[['url']])
    print("\n¿Qué acción te gustaría realizar?")
    print("1. Sustituir el valor manualmente")
    print("2. Pasar al siguiente registro")

    # Solicitar la opción al usuario
    option = input("Elige una opción (1 | 2): ")

    if option == '1':
        # Sustituir el valor manualmente
        new_value = input("Introduce el nuevo valor para 'estacionamientos': ")
        df.at[idx, 'estacionamientos'] = float(new_value)    
    elif option == '2':
        # Pasar al siguiente registro
        continue
    else:
        print("Opción no válida. Pasando al siguiente registro...")
    
    print("\n---\n")

print("Proceso completado.")
# Out:
# Proceso completado.

# %% [markdown]
# ### Estacionamientos [0 / #]

# %%
# Filtrar los registros según las condiciones dadas
totales = df[( (df['estacionamientos']==0) & (df['estacionamiento_desc'].notna()) )] 
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# Iterar sobre los registros filtrados
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    print(row[['estacionamientos', 'estacionamiento_desc', 'url']])
    print("\n¿Qué acción te gustaría realizar?")
    print("1. Sustituir el valor manualmente")
    print("2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'")
    print("3. Pasar al siguiente registro")

    # Solicitar la opción al usuario
    option = input("Elige una opción (1, 2, 3): ")

    if option == '1':
        # Sustituir el valor manualmente
        new_value = input("Introduce el nuevo valor para 'estacionamientos': ")
        df.at[idx, 'estacionamientos'] = float(new_value)
    elif option == '2':
        # Sustituir el valor de 'metros_total' por 'totales_desc'
        df.at[idx, 'estacionamientos'] = df.at[idx, 'estacionamiento_desc']
    elif option == '3':
        # Pasar al siguiente registro
        continue
    else:
        print("Opción no válida. Pasando al siguiente registro...")
    
    print("\n---\n")

print("Proceso completado.")
# Out:
# Proceso completado.

# %% [markdown]
# ### Estacionamientos [# / #]

# %%
# Filtrar los registros según las condiciones dadas
totales = df[( ((df['estacionamientos']!=0) & (df['estacionamiento_desc'].notna())) & (df['estacionamientos'] != df['estacionamiento_desc']) )] 
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# Iterar sobre los registros filtrados
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    print(row[['estacionamientos', 'estacionamiento_desc', 'url']])
    print("\n¿Qué acción te gustaría realizar?")
    print("1. Sustituir el valor manualmente")
    print("2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'")
    print("3. Pasar al siguiente registro")

    # Solicitar la opción al usuario
    option = input("Elige una opción (1, 2, 3): ")

    if option == '1':
        # Sustituir el valor manualmente
        new_value = input("Introduce el nuevo valor para 'estacionamientos': ")
        df.at[idx, 'estacionamientos'] = float(new_value)
    elif option == '2':
        # Sustituir el valor de 'metros_total' por 'totales_desc'
        df.at[idx, 'estacionamientos'] = df.at[idx, 'estacionamiento_desc']
    elif option == '3':
        # Pasar al siguiente registro
        continue
    else:
        print("Opción no válida. Pasando al siguiente registro...")
    
    print("\n---\n")

print("Proceso completado.")

# %% [markdown]
# ## b) Mantener rango de estacionamientos < 5 (mínimo 1)

# %%
df = df[df['estacionamientos'] <= 8]
#df[['estacionamientos','estacionamiento_desc','url']]

# %% [markdown]
# # 8. Recámaras

# %% [markdown]
# ## a) Recámaras en descripción

# %%
# Función para extraer cantidad de recamaras en descripción
def extraer_recamaras(descripcion):
    descripcion = descripcion.lower()
    # Buscar patrones de totales
    totales = re.findall(r'\b(\d+[\.,]?\d*)\s*(recamara|recamaras|habitaciones|dormitorio|dormitorios)\b', descripcion)
    total = None
    for match in totales:
        numero, _ = match
        numero = numero.replace(',', '').replace("'", '')
        try:
            total = float(numero)
        except ValueError:
            continue
        if total:
            break
    return total

# Aplicar la función al DataFrame
df['recamaras_desc'] = df['descripcion'].apply(extraer_recamaras)

# %% [markdown]
# ### Recámaras [0 / 0]

# %%
# Filtrar los registros según las condiciones dadas
totales = df[ (df['recamaras'] == 0 ) & (df['recamaras_desc'].isna()) ] 
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# Iterar sobre los registros filtrados
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    print(row[['url']])
    print("\n¿Qué acción te gustaría realizar?")
    print("1. Sustituir el valor manualmente")
    print("2. Pasar al siguiente registro")

    # Solicitar la opción al usuario
    option = input("Elige una opción (1 | 2): ")

    if option == '1':
        # Sustituir el valor manualmente
        new_value = input("Introduce el nuevo valor para 'recamaras': ")
        df.at[idx, 'recamaras'] = float(new_value)
    elif option == '2':
        # Pasar al siguiente registro
        continue
    else:
        print("Opción no válida. Pasando al siguiente registro...")
    
    print("\n---\n")

print("Proceso completado.")
# Out:
# Proceso completado.

# %% [markdown]
# ### Recámaras [0 / #]

# %%
# Filtrar los registros según las condiciones dadas
totales = df[( (df['recamaras']==0) & (df['recamaras_desc'].notna()) )] 
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# Iterar sobre los registros filtrados
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    print(row[['recamaras', 'recamaras_desc', 'url']])
    print("\n¿Qué acción te gustaría realizar?")
    print("1. Sustituir el valor manualmente")
    print("2. Sustituir el valor de 'recamaras' por el de 'recamaras_desc'")
    print("3. Pasar al siguiente registro")

    # Solicitar la opción al usuario
    option = input("Elige una opción (1, 2, 3): ")

    if option == '1':
        # Sustituir el valor manualmente
        new_value = input("Introduce el nuevo valor para 'recamaras': ")
        df.at[idx, 'recamaras'] = float(new_value)
    elif option == '2':
        # Sustituir el valor de 'metros_total' por 'totales_desc'
        df.at[idx, 'recamaras'] = df.at[idx, 'recamaras_desc']
    elif option == '3':
        # Pasar al siguiente registro
        continue
    else:
        print("Opción no válida. Pasando al siguiente registro...")
    
    print("\n---\n")

print("Proceso completado.")
# Out:
# Proceso completado.

# %% [markdown]
# ### Recámaras [# / #]

# %%
# Filtrar los registros según las condiciones dadas
totales = df[( (df['recamaras']!=0) & (df['recamaras_desc'].notna()) ) & (df['recamaras'] != df['recamaras_desc'])] 
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# Iterar sobre los registros filtrados
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    print(row[['recamaras', 'recamaras_desc', 'url']])
    print("\n¿Qué acción te gustaría realizar?")
    print("1. Sustituir el valor manualmente")
    print("2. Sustituir el valor de 'recamaras' por el de 'recamaras_desc'")
    print("3. Pasar al siguiente registro")

    # Solicitar la opción al usuario
    option = input("Elige una opción (1, 2, 3): ")

    if option == '1':
        # Sustituir el valor manualmente
        new_value = input("Introduce el nuevo valor para 'recamaras': ")
        df.at[idx, 'recamaras'] = float(new_value)
    elif option == '2':
        # Sustituir el valor de 'metros_total' por 'totales_desc'
        df.at[idx, 'recamaras'] = df.at[idx, 'recamaras_desc']
    elif option == '3':
        # Pasar al siguiente registro
        continue
    else:
        print("Opción no válida. Pasando al siguiente registro...")
    
    print("\n---\n")

print("Proceso completado.")

# %% [markdown]
# ## b) Mantener rango de recámaras <= 7

# %%
print(df['recamaras'].unique())
df = df[(df['recamaras'] <= 7)] 
#print(df[['recamaras','recamaras_desc','url']])

# %% [markdown]
# # 9. Baños

# %% [markdown]
# ## a) Baños en descripción

# %% [markdown]
# Manejando tanto los completos como los medios

# %%
# Extraer la cantidad de baños y medios baños en la descripción
def extraer_baños(descripcion):
    descripcion = descripcion.lower()
    
    # Buscar patrones de baños completos
    completos = re.findall(r'\b(\d+[\.,]?\d*)\s*baños?\b', descripcion)
    total_completos = sum([float(match.replace(',', '').replace("'", '')) for match in completos])
    
    # Buscar patrones de medios baños (1/2 baño)
    medios = re.findall(r'\b(\d+[\.,]?\d*)\s*medios?\s*baños?\b', descripcion)
    total_medios = sum([float(match.replace(',', '').replace("'", '')) for match in medios])
    
    # Retornar como un diccionario o una tupla
    return {'completos': total_completos, 'medios': total_medios}

# Aplicar la función al DataFrame
df['baños_desc'] = df['descripcion'].apply(extraer_baños)

# Si deseas separar en dos columnas distintas:
df['baños_completos'] = df['baños_desc'].apply(lambda x: x['completos'] if x else 0)
df['medios_baños'] = df['baños_desc'].apply(lambda x: x['medios'] if x else 0)

# %% [markdown]
# ### Baños

# %% [markdown]
# #### [0 / 0]

# %% [markdown]
# Poner como mínimo para el registro 1 en baños, pero si cuenta con medio baño en descripción que se le asigne ese valor.

# %%
# Filtrar los registros según las condiciones dadas
totales = df[(df['banos'] == 0) & (df['baños_completos'].isna())]
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# Iterar sobre los registros filtrados
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    print(row[['url']])
    print("\n¿Qué acción te gustaría realizar?")
    print("1. Sustituir el valor manualmente")
    #print("2. Asignar 1 como mínimo y pasar al siguiente registro")
    print("2. Pasar al siguiente registro")

    # Solicitar la opción al usuario
    option = input("Elige una opción (1 | 2): ")

    if option == '1':
        # Sustituir el valor manualmente
        new_value = input("Introduce el nuevo valor para 'banos': ")
        df.at[idx, 'banos'] = float(new_value)
    #elif option == '2':
        # Asignar valor de 1 como mínimo
        #df.at[idx, 'banos'] = 1
        #continue  # Pasar al siguiente registro
    else:
        continue  # Pasar al siguiente registro

    print("\n---\n")

print("Proceso completado.")
# Out:
# Proceso completado.

# %% [markdown]
# #### [0 / #]

# %%
# Filtrar los registros según las condiciones dadas
totales = df[( (df['banos']==0) & (df['baños_completos'].notna()) )] 
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# Iterar sobre los registros filtrados
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    print(row[['banos']])
    print(row[['baños_completos']])
    print(row[['url']])
    print("\n¿Qué acción te gustaría realizar?")
    print("1. Sustituir el valor manualmente")
    print("2. Sustituir el valor de 'banos' por el de 'baños_completos'")
    #print("3. Asignar 1 como mínimo y pasar al siguiente registro")
    print("3. Pasar al siguiente registro")

    # Solicitar la opción al usuario
    option = input("Elige una opción (1 | 2 | 3): ")

    if option == '1':
        # Sustituir el valor manualmente
        new_value = input("Introduce el nuevo valor para 'banos': ")
        df.at[idx, 'banos'] = float(new_value)
    elif option == '2':
        # Sustituir el valor de 'banos' por 'baños_completos'
        df.at[idx, 'banos'] = df.at[idx, 'baños_completos']
    #elif option == '3':
        # Asignar valor de 1 como mínimo
        #df.at[idx, 'banos'] = 1
        #continue  # Pasar al siguiente registro
    else:
        continue  # Pasar al siguiente registro

    print("\n---\n")

print("Proceso completado.")
# Out:
# Registro 236:
# banos    0.0
# Name: 236, dtype: object
# baños_completos    0.0
# Name: 236, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-a3ee8bf8fc9d-524a-1f3db509-83cd-4b7b
# Name: 236, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# ---------------------------------------------------------------------------
#
#
#
# KeyboardInterrupt                         Traceback (most recent call last)
#
#
#
# ~\AppData\Local\Temp\ipykernel_10972\779107267.py in <module>
#
#
#
#      15
#
#
#
#      16     # Solicitar la opción al usuario
#
#
#
# ---> 17     option = input("Elige una opción (1 | 2 | 3): ")
#
#
#
#      18
#
#
#
#      19     if option == '1':
#
#
#
#
#
#
#
# c:\Users\yoe11\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#
#
#
#    1173                 "raw_input was called, but this frontend does not support input requests."
#
#
#
#    1174             )
#
#
#
# -> 1175         return self._input_request(
#
#
#
#    1176             str(prompt),
#
#
#
#    1177             self._parent_ident["shell"],
#
#
#
#
#
#
#
# c:\Users\yoe11\anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#
#
#
#    1215             except KeyboardInterrupt:
#
#
#
#    1216                 # re-raise KeyboardInterrupt, to truncate traceback
#
#
#
# -> 1217                 raise KeyboardInterrupt("Interrupted by user") from None
#
#
#
#    1218             except Exception:
#
#
#
#    1219                 self.log.warning("Invalid Message:", exc_info=True)
#
#
#
#
#
#
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# #### [# / #]

# %%
# Filtrar los registros según las condiciones dadas
totales = df[( ((df['banos']!=0) & (df['baños_completos'].notna())) & (df['banos'] != df['baños_completos']))] 
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# Iterar sobre los registros filtrados
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    print(row[['banos']])
    print(row[['baños_completos']])    
    print(row[['url']])
    
    print("\n¿Qué acción te gustaría realizar?")
    print("1. Sustituir el valor manualmente")
    print("2. Sustituir el valor de 'banos' por el de 'baños_completos'")
    #print("3. Asignar 1 como mínimo y pasar al siguiente registro")
    print("3. Pasar al siguiente registro")

    # Solicitar la opción al usuario
    option = input("Elige una opción (1 | 2 | 3): ")

    if option == '1':
        # Sustituir el valor manualmente
        new_value = input("Introduce el nuevo valor para 'banos': ")
        df.at[idx, 'banos'] = float(new_value)
    elif option == '2':
        # Sustituir el valor de 'banos' por 'baños_completos'
        df.at[idx, 'banos'] = df.at[idx, 'baños_completos']
    #elif option == '3':
        # Asignar valor de 1 como mínimo
        #df.at[idx, 'banos'] = 1
        #continue  # Pasar al siguiente registro
    else:
        continue  # Pasar al siguiente registro

    print("\n---\n")

print("Proceso completado.")
# Out:
# Registro 31:
# banos    2
# Name: 31, dtype: object
# baños_completos    5.0
# Name: 31, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-93d194dc33d-d035-bf07501c-825e-4a4a
# Name: 31, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 37:
# banos    3
# Name: 37, dtype: object
# baños_completos    0.0
# Name: 37, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-27915b7692e9-3bc0-67bbfd01-9453-4608
# Name: 37, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 65:
# banos    1
# Name: 65, dtype: object
# baños_completos    0.0
# Name: 65, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-c7136c4c8f36-cb2f-fd601220-8b1e-4305
# Name: 65, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 91:
# banos    1
# Name: 91, dtype: object
# baños_completos    4.0
# Name: 91, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-cbd89c1181eb-6233-72e52972-be96-4e29
# Name: 91, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 95:
# banos    3
# Name: 95, dtype: object
# baños_completos    0.0
# Name: 95, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-ece532a1de91-7596-9cfd993-b6d6-5038
# Name: 95, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 114:
# banos    1
# Name: 114, dtype: object
# baños_completos    2.0
# Name: 114, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-b508efd58246-532d-db9a6d07-89c7-49ad
# Name: 114, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 140:
# banos    1
# Name: 140, dtype: object
# baños_completos    0.0
# Name: 140, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-5e3154762f91-b464-3c3d91c2-b0fb-4e72
# Name: 140, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 143:
# banos    3
# Name: 143, dtype: object
# baños_completos    0.0
# Name: 143, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-9f8416fe7d20-4558-6fedd2c1-b3af-3a95
# Name: 143, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 145:
# banos    2
# Name: 145, dtype: object
# baños_completos    0.0
# Name: 145, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-1380b23a017b-eb33-179baee1-baca-3af7
# Name: 145, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 146:
# banos    2
# Name: 146, dtype: object
# baños_completos    0.0
# Name: 146, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-54c9a76db762-9d8c-bfbd3eaf-b2e0-47ba
# Name: 146, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 153:
# banos    1
# Name: 153, dtype: object
# baños_completos    0.0
# Name: 153, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-b52ebb7e062a-1c16-282bc937-92dd-4559
# Name: 153, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 179:
# banos    3
# Name: 179, dtype: object
# baños_completos    0.0
# Name: 179, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-edb7d9699a45-bf79-71f1ad94-8d6e-354c
# Name: 179, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 181:
# banos    2
# Name: 181, dtype: object
# baños_completos    0.0
# Name: 181, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-f75d6780630b-8d42-297f81a9-b296-4751
# Name: 181, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 188:
# banos    2
# Name: 188, dtype: object
# baños_completos    0.0
# Name: 188, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-ad88958b7e4b-2bb2-c0c7e785-a185-4bf5
# Name: 188, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 195:
# banos    1
# Name: 195, dtype: object
# baños_completos    0.0
# Name: 195, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-2574f4ca7595-b1a2-a87e072b-9825-435a
# Name: 195, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 198:
# banos    1
# Name: 198, dtype: object
# baños_completos    2.0
# Name: 198, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-693603a35ed7-4722-ec4a245b-9482-4c8e
# Name: 198, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 201:
# banos    1
# Name: 201, dtype: object
# baños_completos    2.0
# Name: 201, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-18fe349753c6-ff0f-eaa172a9-85dc-4b6f
# Name: 201, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 233:
# banos    3
# Name: 233, dtype: object
# baños_completos    0.0
# Name: 233, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-c2dd6927fde4-1b1f-5b749227-9f3b-410e
# Name: 233, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 235:
# banos    1
# Name: 235, dtype: object
# baños_completos    3.0
# Name: 235, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-2e47451c060f-da81-a84f117-bd93-4bce
# Name: 235, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 236:
# banos    2
# Name: 236, dtype: object
# baños_completos    0.0
# Name: 236, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-a3ee8bf8fc9d-524a-1f3db509-83cd-4b7b
# Name: 236, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 322:
# banos    3
# Name: 322, dtype: object
# baños_completos    0.0
# Name: 322, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-caf342ff5ab1-bf9e-2aa3e70e-b9fc-4bee
# Name: 322, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 347:
# banos    1
# Name: 347, dtype: object
# baños_completos    0.0
# Name: 347, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-704fd025bb38-1e15-97349991-9551-455f
# Name: 347, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 392:
# banos    1
# Name: 392, dtype: object
# baños_completos    0.0
# Name: 392, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-90b676e4ac53-bc36-f7eb833-8e6b-4924
# Name: 392, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 431:
# banos    1
# Name: 431, dtype: object
# baños_completos    0.0
# Name: 431, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-f6235560e31a-1749-a0081ec8-a824-4bdd
# Name: 431, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 434:
# banos    2
# Name: 434, dtype: object
# baños_completos    0.0
# Name: 434, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-33235dedb4ed-ac9e-fcaba94c-b874-4181
# Name: 434, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 448:
# banos    1
# Name: 448, dtype: object
# baños_completos    0.0
# Name: 448, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-1d57a30e2009-c097-848a0f8b-94dd-4a10
# Name: 448, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 454:
# banos    1
# Name: 454, dtype: object
# baños_completos    0.0
# Name: 454, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-f11931ad4504-6d50-57fbeead-805b-478d
# Name: 454, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 457:
# banos    1
# Name: 457, dtype: object
# baños_completos    0.0
# Name: 457, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-3431de6259b7-7af9-a113c8ce-bc30-47fd
# Name: 457, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 516:
# banos    1
# Name: 516, dtype: object
# baños_completos    0.0
# Name: 516, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-50d17c00c137-4c06-e7fc02eb-ba22-4912
# Name: 516, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 552:
# banos    2
# Name: 552, dtype: object
# baños_completos    0.0
# Name: 552, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-6945048fb219-fa03-43aa7a74-bab9-4364
# Name: 552, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 565:
# banos    3
# Name: 565, dtype: object
# baños_completos    0.0
# Name: 565, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-ffef1447fcb-2a77-43df6de7-9b68-42d0
# Name: 565, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 591:
# banos    1
# Name: 591, dtype: object
# baños_completos    4.0
# Name: 591, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-1f5bce4bef3-3e4e-b37badba-a9ab-4b4f
# Name: 591, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 593:
# banos    1
# Name: 593, dtype: object
# baños_completos    0.0
# Name: 593, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-85bc36bf8eaf-6efb-327a921b-859e-4c09
# Name: 593, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 603:
# banos    1
# Name: 603, dtype: object
# baños_completos    0.0
# Name: 603, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-40e021068c65-d03f-f0bfbcf3-83f9-333c
# Name: 603, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 681:
# banos    1
# Name: 681, dtype: object
# baños_completos    0.0
# Name: 681, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-cdc4cefa2500-fbb7-b04903b2-b071-344e
# Name: 681, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 683:
# banos    3
# Name: 683, dtype: object
# baños_completos    0.0
# Name: 683, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-c489ef03a162-8ed1-3db9227a-98a2-39c9
# Name: 683, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 687:
# banos    1
# Name: 687, dtype: object
# baños_completos    0.0
# Name: 687, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-56ab4fd0779b-3a2c-9d4dac41-b4d1-4132
# Name: 687, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 703:
# banos    2
# Name: 703, dtype: object
# baños_completos    2.5
# Name: 703, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-c99c82f29f03-d903-b606018d-ba70-365d
# Name: 703, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 705:
# banos    3
# Name: 705, dtype: object
# baños_completos    0.0
# Name: 705, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-667d9cb29bd6-4b6d-28f2ba3d-a07e-3313
# Name: 705, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 715:
# banos    2
# Name: 715, dtype: object
# baños_completos    0.0
# Name: 715, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-7ec904ade2ad-729e-b98841f5-bbdb-477f
# Name: 715, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 805:
# banos    1
# Name: 805, dtype: object
# baños_completos    0.0
# Name: 805, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-355f1f2508e4-e726-3b85c981-a39f-4300
# Name: 805, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 825:
# banos    1
# Name: 825, dtype: object
# baños_completos    0.0
# Name: 825, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-9b82da76bcac-a572-9c71140c-98f9-3d1a
# Name: 825, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 829:
# banos    1
# Name: 829, dtype: object
# baños_completos    0.0
# Name: 829, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-f1aeaaf44ccf-2367-85c8ac0e-b631-3341
# Name: 829, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 849:
# banos    2
# Name: 849, dtype: object
# baños_completos    0.0
# Name: 849, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-9a66a6c61eb4-78df-71c0c7b7-bc27-3f1c
# Name: 849, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 872:
# banos    1
# Name: 872, dtype: object
# baños_completos    2.5
# Name: 872, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-513d40a5f259-4d1d-e9064450-9e9f-3b7d
# Name: 872, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 873:
# banos    1
# Name: 873, dtype: object
# baños_completos    0.0
# Name: 873, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-526d8529bbba-e36a-841c587f-9b4d-4fcd
# Name: 873, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 878:
# banos    1
# Name: 878, dtype: object
# baños_completos    0.0
# Name: 878, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-66f77b4c2b00-d505-8be28d26-8c82-4711
# Name: 878, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 879:
# banos    1
# Name: 879, dtype: object
# baños_completos    0.0
# Name: 879, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-af5162cc88fb-ae7a-9ad7d266-a260-40aa
# Name: 879, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 880:
# banos    1
# Name: 880, dtype: object
# baños_completos    0.0
# Name: 880, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-251e52dffce8-274d-377b437c-a29e-4e89
# Name: 880, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 888:
# banos    1
# Name: 888, dtype: object
# baños_completos    0.0
# Name: 888, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-a2012c98622d-6203-ae93989d-a1bc-4a48
# Name: 888, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 897:
# banos    2
# Name: 897, dtype: object
# baños_completos    0.0
# Name: 897, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-9f0a085fc26f-17cb-e04cccfb-9c6c-33d6
# Name: 897, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 899:
# banos    2
# Name: 899, dtype: object
# baños_completos    0.0
# Name: 899, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-bdf7c0be02f8-20d5-982e27eb-8839-4bba
# Name: 899, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 948:
# banos    1
# Name: 948, dtype: object
# baños_completos    2.0
# Name: 948, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-4d3b789263c4-8ccb-53957f26-af9f-4f01
# Name: 948, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 965:
# banos    1
# Name: 965, dtype: object
# baños_completos    0.0
# Name: 965, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-efb4a7889912-7154-757fb66a-9a5a-43d7
# Name: 965, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 990:
# banos    1
# Name: 990, dtype: object
# baños_completos    0.0
# Name: 990, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-439dca51c554-f56-8c37417-a4bb-4a8d
# Name: 990, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 999:
# banos    1
# Name: 999, dtype: object
# baños_completos    3.0
# Name: 999, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-24f8d8a95d18-a620-51d2dcea-bf05-4ec6
# Name: 999, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 1016:
# banos    1
# Name: 1016, dtype: object
# baños_completos    0.0
# Name: 1016, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-5aa92dbf3480-cd3b-bddd263e-9166-397e
# Name: 1016, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 1036:
# banos    2
# Name: 1036, dtype: object
# baños_completos    0.0
# Name: 1036, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-f33c5602b15e-9729-179864f1-a192-3e19
# Name: 1036, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 1053:
# banos    1
# Name: 1053, dtype: object
# baños_completos    2.0
# Name: 1053, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-69eae9389044-a328-4db845ba-8373-3a33
# Name: 1053, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 1247:
# banos    2
# Name: 1247, dtype: object
# baños_completos    0.0
# Name: 1247, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-1f7479da9cb8-6713-e41a7b17-b6df-43b3
# Name: 1247, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 1267:
# banos    1
# Name: 1267, dtype: object
# baños_completos    2.5
# Name: 1267, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-d8550f2c0e7c-ca78-b962a5eb-92ac-3842
# Name: 1267, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 1293:
# banos    2
# Name: 1293, dtype: object
# baños_completos    3.0
# Name: 1293, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-98657fa95fe1-5ebb-c94a7aac-abf1-3a73
# Name: 1293, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 2347:
# banos    1
# Name: 2347, dtype: object
# baños_completos    0.0
# Name: 2347, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-ab676eaa234c-9a31-e1cb029a-869a-3106
# Name: 2347, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 2350:
# banos    1
# Name: 2350, dtype: object
# baños_completos    0.0
# Name: 2350, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-e3dfc2fea653-9763-ac93dc96-af2d-3b79
# Name: 2350, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 2360:
# banos    2
# Name: 2360, dtype: object
# baños_completos    0.0
# Name: 2360, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-e05a703b5128-4614-2bc30816-832e-4f81
# Name: 2360, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 2455:
# banos    1
# Name: 2455, dtype: object
# baños_completos    0.0
# Name: 2455, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-10bceccb677b-4d41-615714ab-b6a6-3d7c
# Name: 2455, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 2510:
# banos    1
# Name: 2510, dtype: object
# baños_completos    2.0
# Name: 2510, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-30002a0c30e6-7a80-f6651e89-9302-4d13
# Name: 2510, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 2603:
# banos    1
# Name: 2603, dtype: object
# baños_completos    6.0
# Name: 2603, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-6b6e82c6da71-e540-f308cd9b-a27b-3e64
# Name: 2603, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 2623:
# banos    2
# Name: 2623, dtype: object
# baños_completos    0.0
# Name: 2623, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-175b8797ae68-adb8-c207b80c-ba28-30e3
# Name: 2623, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 2631:
# banos    1
# Name: 2631, dtype: object
# baños_completos    0.0
# Name: 2631, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-3c82f0d39ab-3635-c54b684d-a3ae-4475
# Name: 2631, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 2654:
# banos    1
# Name: 2654, dtype: object
# baños_completos    3.5
# Name: 2654, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-25e2bc985874-e619-5b2fdd90-bc72-3698
# Name: 2654, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 2658:
# banos    1
# Name: 2658, dtype: object
# baños_completos    0.0
# Name: 2658, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-163eb44a2f36-122f-aa0caf9-9555-4982
# Name: 2658, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 2677:
# banos    1
# Name: 2677, dtype: object
# baños_completos    0.0
# Name: 2677, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-6fe169562924-73c8-d4069bc5-9e17-344f
# Name: 2677, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 2685:
# banos    1
# Name: 2685, dtype: object
# baños_completos    0.0
# Name: 2685, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-a61ac2bfb733-c165-8ac0a757-8799-462f
# Name: 2685, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 2758:
# banos    3
# Name: 2758, dtype: object
# baños_completos    1.0
# Name: 2758, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-b5de9c15a734-7700-cf0b66c9-905f-328e
# Name: 2758, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 2767:
# banos    1
# Name: 2767, dtype: object
# baños_completos    0.0
# Name: 2767, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-6f94edfc37cf-88cc-5e0685e4-b1f9-47ee
# Name: 2767, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 2901:
# banos    5
# Name: 2901, dtype: object
# baños_completos    0.0
# Name: 2901, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-eac6bb37ade9-6fa5-81abbe41-80b7-3e42
# Name: 2901, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 2902:
# banos    1
# Name: 2902, dtype: object
# baños_completos    3.5
# Name: 2902, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-abf59cacd162-e4e-ceac70db-8d4c-31cf
# Name: 2902, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 2987:
# banos    1
# Name: 2987, dtype: object
# baños_completos    0.0
# Name: 2987, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-f4c19132bc91-73c3-40b01e03-979a-3080
# Name: 2987, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 2989:
# banos    3
# Name: 2989, dtype: object
# baños_completos    0.0
# Name: 2989, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-b8f0d57e9590-2a67-cbde93af-8a6a-3c8b
# Name: 2989, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 3054:
# banos    1
# Name: 3054, dtype: object
# baños_completos    0.0
# Name: 3054, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-17538019971d-8068-f9565e19-940d-31e5
# Name: 3054, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 3099:
# banos    4
# Name: 3099, dtype: object
# baños_completos    0.0
# Name: 3099, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-1e4c23eab18f-cf36-e1db5550-a2c0-364d
# Name: 3099, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 3109:
# banos    1
# Name: 3109, dtype: object
# baños_completos    0.0
# Name: 3109, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-8ff9c113cb88-c749-1fdb5535-ba03-4e7c
# Name: 3109, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 3135:
# banos    5
# Name: 3135, dtype: object
# baños_completos    0.0
# Name: 3135, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-16a908d3bf55-748b-2d71be40-a9b7-3fef
# Name: 3135, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 3154:
# banos    1
# Name: 3154, dtype: object
# baños_completos    0.0
# Name: 3154, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-d24c10b55e38-80e5-66cb3bec-8b29-36fd
# Name: 3154, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 3155:
# banos    1
# Name: 3155, dtype: object
# baños_completos    3.5
# Name: 3155, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-9fb07810e62-f0e3-398e92dc-b2b8-30c7
# Name: 3155, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 3164:
# banos    1
# Name: 3164, dtype: object
# baños_completos    0.0
# Name: 3164, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-5162c94cb157-3589-d9345eb0-a684-314b
# Name: 3164, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 3221:
# banos    1
# Name: 3221, dtype: object
# baños_completos    0.0
# Name: 3221, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-1b7765ec29c1-d5dc-f1c3395f-91a7-3e27
# Name: 3221, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 3233:
# banos    1
# Name: 3233, dtype: object
# baños_completos    0.0
# Name: 3233, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-381ac6595599-ab2d-c78299a8-9204-3b9c
# Name: 3233, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 3281:
# banos    3
# Name: 3281, dtype: object
# baños_completos    0.0
# Name: 3281, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-8d1b496b8685-e007-608ddc70-8099-3d71
# Name: 3281, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 3286:
# banos    1
# Name: 3286, dtype: object
# baños_completos    9.0
# Name: 3286, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-f3f4c22386bf-d301-f1f05549-b343-3df4
# Name: 3286, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 3321:
# banos    3
# Name: 3321, dtype: object
# baños_completos    0.0
# Name: 3321, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-8a23014f49d5-c4b3-b24c83ef-9d65-34a9
# Name: 3321, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 3381:
# banos    1
# Name: 3381, dtype: object
# baños_completos    3.0
# Name: 3381, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-bb08859d4a90-2894-fda48353-936f-4c6c
# Name: 3381, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 3390:
# banos    4
# Name: 3390, dtype: object
# baños_completos    0.0
# Name: 3390, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-23521da68416-cc7f-cbbe44b8-a985-3749
# Name: 3390, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 3436:
# banos    1
# Name: 3436, dtype: object
# baños_completos    0.0
# Name: 3436, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-fe6ae7d88a31-1bad-7cb3a288-808e-39a1
# Name: 3436, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 3441:
# banos    1
# Name: 3441, dtype: object
# baños_completos    3.5
# Name: 3441, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-23ac3093f9e1-1afb-51c3d517-b0be-37b0
# Name: 3441, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 3477:
# banos    1
# Name: 3477, dtype: object
# baños_completos    3.0
# Name: 3477, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-f8187db14223-36a5-5fdaeed8-be86-3224
# Name: 3477, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 3495:
# banos    1
# Name: 3495, dtype: object
# baños_completos    0.0
# Name: 3495, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-38225f2fdcfa-7058-440d1408-b1cf-3400
# Name: 3495, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 3557:
# banos    3
# Name: 3557, dtype: object
# baños_completos    0.0
# Name: 3557, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-8307b34890fe-9baf-22629867-a752-3a19
# Name: 3557, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 3606:
# banos    1
# Name: 3606, dtype: object
# baños_completos    3.5
# Name: 3606, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-55910417fdba-6a9-33486daf-b0c1-4490
# Name: 3606, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 3624:
# banos    1
# Name: 3624, dtype: object
# baños_completos    0.0
# Name: 3624, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-a07a98bcca71-d158-f080605a-a4a9-3ac0
# Name: 3624, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 3642:
# banos    2
# Name: 3642, dtype: object
# baños_completos    0.0
# Name: 3642, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-9f31bc543e1-9f61-ba7b696b-b72a-379b
# Name: 3642, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 3648:
# banos    4
# Name: 3648, dtype: object
# baños_completos    0.0
# Name: 3648, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-1df6e297e8c5-2ccf-4d299739-8467-368d
# Name: 3648, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 3695:
# banos    1
# Name: 3695, dtype: object
# baños_completos    0.0
# Name: 3695, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-69219a0e3330-5144-392daa7b-bc26-3c7d
# Name: 3695, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 3712:
# banos    3
# Name: 3712, dtype: object
# baños_completos    5.5
# Name: 3712, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-38f95b1e57ed-1033-feddd240-9255-3a1e
# Name: 3712, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 3729:
# banos    1
# Name: 3729, dtype: object
# baños_completos    2.5
# Name: 3729, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-93f425db615e-c044-afca3b32-863a-3746
# Name: 3729, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 3748:
# banos    4
# Name: 3748, dtype: object
# baños_completos    0.0
# Name: 3748, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-20b5d7a14f6f-c9bd-934ca425-89f1-3abd
# Name: 3748, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 3786:
# banos    4
# Name: 3786, dtype: object
# baños_completos    0.0
# Name: 3786, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-e8253545563f-c279-9c8a2ca-9ca6-32df
# Name: 3786, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 3790:
# banos    3
# Name: 3790, dtype: object
# baños_completos    0.0
# Name: 3790, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-60cdf2d13516-558b-8d5edb69-a9fc-3ee0
# Name: 3790, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 3800:
# banos    1
# Name: 3800, dtype: object
# baños_completos    0.0
# Name: 3800, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-35a0937ceafc-fa2-4b80f4f7-80c4-3d7d
# Name: 3800, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 3877:
# banos    2
# Name: 3877, dtype: object
# baños_completos    3.0
# Name: 3877, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-325bd803ea2d-7464-a1e25950-a2b9-422d
# Name: 3877, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 3950:
# banos    1
# Name: 3950, dtype: object
# baños_completos    0.0
# Name: 3950, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-a36ad8234b82-89b3-f998373c-818a-4c34
# Name: 3950, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 3951:
# banos    1
# Name: 3951, dtype: object
# baños_completos    0.0
# Name: 3951, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-7b52bd8a4d6d-bcbe-ff078c60-a788-488f
# Name: 3951, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 3952:
# banos    1
# Name: 3952, dtype: object
# baños_completos    0.0
# Name: 3952, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-693dff2b0386-f6a3-24e241ee-80dd-4df4
# Name: 3952, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 4001:
# banos    3
# Name: 4001, dtype: object
# baños_completos    2.0
# Name: 4001, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-cdcd15d3455d-f2b4-86854254-91bc-3d3d
# Name: 4001, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 4060:
# banos    1
# Name: 4060, dtype: object
# baños_completos    0.0
# Name: 4060, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-4c135c3023ca-ea1e-50139c9e-ae46-38c3
# Name: 4060, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 4108:
# banos    1
# Name: 4108, dtype: object
# baños_completos    0.0
# Name: 4108, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-c4706d21dbf9-9f72-eca7cb3c-ac21-3dcc
# Name: 4108, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 4110:
# banos    1
# Name: 4110, dtype: object
# baños_completos    0.0
# Name: 4110, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-b0a2e6240cd6-75e5-ca3b0663-9f25-3b9c
# Name: 4110, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 4115:
# banos    4
# Name: 4115, dtype: object
# baños_completos    0.0
# Name: 4115, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-9a4a7a5ffeb7-41e8-4a2a2b4e-9de3-4e4e
# Name: 4115, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 4147:
# banos    4
# Name: 4147, dtype: object
# baños_completos    0.0
# Name: 4147, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-351ea48a26bf-8654-dc02ee24-a37a-36bb
# Name: 4147, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 4196:
# banos    1
# Name: 4196, dtype: object
# baños_completos    0.0
# Name: 4196, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-1f52b3f4d65-10a2-c639a5af-8423-3998
# Name: 4196, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 4253:
# banos    1
# Name: 4253, dtype: object
# baños_completos    0.0
# Name: 4253, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-c8a51191bb58-dc98-72b68300-941c-447e
# Name: 4253, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 4407:
# banos    2
# Name: 4407, dtype: object
# baños_completos    0.0
# Name: 4407, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-8546b1f44055-f475-a3f36f-bdbe-3bf0
# Name: 4407, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 4419:
# banos    1
# Name: 4419, dtype: object
# baños_completos    0.0
# Name: 4419, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-ae0fff79ba3c-1996-896c993d-95e3-3e61
# Name: 4419, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 4430:
# banos    4
# Name: 4430, dtype: object
# baños_completos    0.0
# Name: 4430, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-8e7dadcbd10a-7928-49ded9e9-9391-4930
# Name: 4430, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 4431:
# banos    1
# Name: 4431, dtype: object
# baños_completos    4.0
# Name: 4431, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-6666b534d99c-93e-d98f43e3-9841-3fe7
# Name: 4431, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 4496:
# banos    1
# Name: 4496, dtype: object
# baños_completos    4.5
# Name: 4496, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-ca2829c6cec7-9218-63f6169c-b88d-3298
# Name: 4496, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 4498:
# banos    1
# Name: 4498, dtype: object
# baños_completos    0.0
# Name: 4498, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-a326385500a-9c2b-b4287daf-9f2a-452b
# Name: 4498, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# ...
# Name: 8406, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 8466:
# banos    4
# Name: 8466, dtype: object
# baños_completos    0.0
# Name: 8466, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-29ffa279aa7b-917-40d7c958-a898-31ae
# Name: 8466, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 8512:
# banos    4
# Name: 8512, dtype: object
# baños_completos    0.0
# Name: 8512, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-61e7c263eacc-7f97-225a7bc7-8cbc-3d39
# Name: 8512, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 8567:
# banos    4
# Name: 8567, dtype: object
# baños_completos    0.0
# Name: 8567, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-9cdcca64a108-62bd-feabfe7-8477-3153
# Name: 8567, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 8619:
# banos    4
# Name: 8619, dtype: object
# baños_completos    0.0
# Name: 8619, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-5d2a740f705a-57d3-196c2e9c-a264-3904
# Name: 8619, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 8645:
# banos    4
# Name: 8645, dtype: object
# baños_completos    0.0
# Name: 8645, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-a8880f6413c8-5054-ce8d8082-b840-3da8
# Name: 8645, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 8655:
# banos    4
# Name: 8655, dtype: object
# baños_completos    0.0
# Name: 8655, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-f8d7b83dcd8b-5836-900e73cc-b079-3f05
# Name: 8655, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 8729:
# banos    4
# Name: 8729, dtype: object
# baños_completos    0.0
# Name: 8729, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-192d03dfd899-d4b1-5a145dc9-84f8-4c08
# Name: 8729, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 8739:
# banos    4
# Name: 8739, dtype: object
# baños_completos    0.0
# Name: 8739, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-deb5b29b5a39-2086-e24672ae-9203-3e4f
# Name: 8739, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 8796:
# banos    4
# Name: 8796, dtype: object
# baños_completos    0.0
# Name: 8796, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-2508059d6cb4-d2ef-9616ca88-898f-31dd
# Name: 8796, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 8797:
# banos    4
# Name: 8797, dtype: object
# baños_completos    0.0
# Name: 8797, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-30574cffd8c8-d90-3a2378fb-9324-4038
# Name: 8797, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 8802:
# banos    4
# Name: 8802, dtype: object
# baños_completos    2.0
# Name: 8802, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-efb269c3b939-7202-d9c942f3-8be6-442a
# Name: 8802, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 8807:
# banos    4
# Name: 8807, dtype: object
# baños_completos    0.0
# Name: 8807, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-10140b855147-65d0-77d9d707-a081-35ec
# Name: 8807, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 8809:
# banos    4
# Name: 8809, dtype: object
# baños_completos    0.0
# Name: 8809, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-990116b708bb-b87f-48c33ea4-9dc2-34a0
# Name: 8809, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 8820:
# banos    4
# Name: 8820, dtype: object
# baños_completos    0.0
# Name: 8820, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-dba084047e07-c73a-bddd7b8d-b6fa-386a
# Name: 8820, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 8822:
# banos    4
# Name: 8822, dtype: object
# baños_completos    0.0
# Name: 8822, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-d6cddc7ca082-676c-a81fdfe2-b6bf-3955
# Name: 8822, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 8823:
# banos    4
# Name: 8823, dtype: object
# baños_completos    0.0
# Name: 8823, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-df4589fd6a66-a8c6-efca3927-a263-33f3
# Name: 8823, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 8829:
# banos    4
# Name: 8829, dtype: object
# baños_completos    0.0
# Name: 8829, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-35aa8a4a9751-1533-276d726e-ba83-3fe0
# Name: 8829, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 8847:
# banos    4
# Name: 8847, dtype: object
# baños_completos    0.0
# Name: 8847, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-9214f103d28a-b6f0-22422320-99dd-3b82
# Name: 8847, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 8861:
# banos    4
# Name: 8861, dtype: object
# baños_completos    0.0
# Name: 8861, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-6e8baaa35015-202f-e2d70726-8fe8-316e
# Name: 8861, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 8910:
# banos    5
# Name: 8910, dtype: object
# baños_completos    0.0
# Name: 8910, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-908ffa94aec0-969b-760c2bc0-8ea0-316c
# Name: 8910, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 8959:
# banos    5
# Name: 8959, dtype: object
# baños_completos    0.0
# Name: 8959, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-a602f5758367-2479-52a66b4-ac2a-502a
# Name: 8959, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 8979:
# banos    5
# Name: 8979, dtype: object
# baños_completos    0.0
# Name: 8979, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-d44ad15d9c74-4684-ee11361d-a205-4f65
# Name: 8979, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 8980:
# banos    5
# Name: 8980, dtype: object
# baños_completos    0.0
# Name: 8980, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-1ba5fee63d72-3c22-a6d61bff-bccf-4e80
# Name: 8980, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 8981:
# banos    5
# Name: 8981, dtype: object
# baños_completos    0.0
# Name: 8981, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-c2d024963647-2959-5bf1783d-b160-41fc
# Name: 8981, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 8982:
# banos    5
# Name: 8982, dtype: object
# baños_completos    0.0
# Name: 8982, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-a2f047faf9a2-4a27-34550499-a69d-44c9
# Name: 8982, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 8999:
# banos    5
# Name: 8999, dtype: object
# baños_completos    3.0
# Name: 8999, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-c36043a4a711-ad77-ac7d0c7d-b3d1-43b6
# Name: 8999, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 9000:
# banos    5
# Name: 9000, dtype: object
# baños_completos    3.0
# Name: 9000, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-e9a7d6ade2aa-d326-a216620b-be34-4c2a
# Name: 9000, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 9003:
# banos    5
# Name: 9003, dtype: object
# baños_completos    3.0
# Name: 9003, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-aec8a71e84b5-7a1f-4e7191a9-aeae-4ece
# Name: 9003, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 9037:
# banos    5
# Name: 9037, dtype: object
# baños_completos    0.0
# Name: 9037, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-80258b5dcc4f-db53-4b0676b8-8763-3bcf
# Name: 9037, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 9120:
# banos    5
# Name: 9120, dtype: object
# baños_completos    3.0
# Name: 9120, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-cb8d32683bd0-516c-8f242dd6-b989-3241
# Name: 9120, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 9134:
# banos    5
# Name: 9134, dtype: object
# baños_completos    0.0
# Name: 9134, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-1cb6e95e0bc1-44f4-61762d86-91f5-3235
# Name: 9134, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 9154:
# banos    5
# Name: 9154, dtype: object
# baños_completos    0.0
# Name: 9154, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-f88747ff4a61-36fd-3e8ab050-87de-3aa5
# Name: 9154, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 9166:
# banos    5
# Name: 9166, dtype: object
# baños_completos    0.0
# Name: 9166, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-786b1b1b97b9-282d-1b6e8f7e-a08a-363a
# Name: 9166, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 9188:
# banos    5
# Name: 9188, dtype: object
# baños_completos    0.0
# Name: 9188, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-287f9528609d-3863-6de42d53-ac14-3674
# Name: 9188, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 9255:
# banos    6
# Name: 9255, dtype: object
# baños_completos    0.0
# Name: 9255, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-55ee224bbca7-2e4b-443c8af1-a707-3abe
# Name: 9255, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 9266:
# banos    6
# Name: 9266, dtype: object
# baños_completos    12.0
# Name: 9266, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-69b26b89a98c-6d50-b77dacc9-be44-3fb5
# Name: 9266, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 9271:
# banos    6
# Name: 9271, dtype: object
# baños_completos    2.0
# Name: 9271, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-c26391c201d7-d8c4-b8b377f0-b71d-3f74
# Name: 9271, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 9285:
# banos    6
# Name: 9285, dtype: object
# baños_completos    0.0
# Name: 9285, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-abcff9f31f91-9b42-df0a9f46-965b-364d
# Name: 9285, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 9317:
# banos    7
# Name: 9317, dtype: object
# baños_completos    2.0
# Name: 9317, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-b3dd7ee02da2-77a-8d0d4cd6-a067-3355
# Name: 9317, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 9321:
# banos    8
# Name: 9321, dtype: object
# baños_completos    1.5
# Name: 9321, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-42a5d7276768-fca6-536261bd-b26e-33af
# Name: 9321, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 9327:
# banos    8
# Name: 9327, dtype: object
# baños_completos    0.0
# Name: 9327, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-2ba25b8df524-7fc-97af003c-aa2f-339c
# Name: 9327, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 9332:
# banos    9
# Name: 9332, dtype: object
# baños_completos    0.0
# Name: 9332, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-125ba1cd9739-e9b5-77b6a502-b769-3fcf
# Name: 9332, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Proceso completado.

# %% [markdown]
# ### Medio baños

# %% [markdown]
# #### [0 / 0]

# %% [markdown]
# Poner como mínimo para el registro 1 en baños, pero si cuenta con valor en descripción que se le asigne ese valor.

# %%
# Filtrar los registros según las condiciones dadas
totales = df[(df['medio_baños'] == 0) & (df['medios_baños'].isna())]
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# Iterar sobre los registros filtrados
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    print(row[['url']])
    print("\n¿Qué acción te gustaría realizar?")
    print("1. Sustituir el valor manualmente")
    #print("2. Asignar 1 como mínimo y pasar al siguiente registro")
    print("2. Pasar al siguiente registro")

    # Solicitar la opción al usuario
    option = input("Elige una opción (1 | 2): ")

    if option == '1':
        # Sustituir el valor manualmente
        new_value = input("Introduce el nuevo valor para 'banos': ")
        df.at[idx, 'banos'] = float(new_value)
    #elif option == '2':
        # Asignar valor de 1 como mínimo
        #df.at[idx, 'banos'] = 1
        #continue  # Pasar al siguiente registro
    else:
        continue  # Pasar al siguiente registro

    print("\n---\n")

print("Proceso completado.")
# Out:
# ---------------------------------------------------------------------------
#
#
#
# KeyError                                  Traceback (most recent call last)
#
#
#
# c:\Users\yoe11\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key)
#
#
#
#    3804         try:
#
#
#
# -> 3805             return self._engine.get_loc(casted_key)
#
#
#
#    3806         except KeyError as err:
#
#
#
#
#
#
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
#
#
#
#
#
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
#
#
#
#
#
#
# pandas\\_libs\\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
#
#
#
#
#
#
# pandas\\_libs\\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
#
#
#
#
#
#
# KeyError: 'medio_baños'
#
#
#
#
#
#
#
# The above exception was the direct cause of the following exception:
#
#
#
#
#
#
#
# KeyError                                  Traceback (most recent call last)
#
#
#
# ~\AppData\Local\Temp\ipykernel_10972\2625185884.py in <module>
#
#
#
#       1 # Filtrar los registros según las condiciones dadas
#
#
#
# ----> 2 totales = df[(df['medio_baños'] == 0) & (df['medios_baños'].isna())]
#
#
#
#       3
#
#
#
#       4 # Iterar sobre los registros filtrados
#
#
#
#       5 for idx, row in totales.iterrows():
#
#
#
#
#
#
#
# c:\Users\yoe11\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#
#
#
#    4100             if self.columns.nlevels > 1:
#
#
#
#    4101                 return self._getitem_multilevel(key)
#
#
#
# -> 4102             indexer = self.columns.get_loc(key)
#
#
#
#    4103             if is_integer(indexer):
#
#
#
#    4104                 indexer = [indexer]
#
#
#
#
#
#
#
# c:\Users\yoe11\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key)
#
#
#
#    3810             ):
#
#
#
#    3811                 raise InvalidIndexError(key)
#
#
#
# -> 3812             raise KeyError(key) from err
#
#
#
#    3813         except TypeError:
#
#
#
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
#
#
#
#
#
#
# KeyError: 'medio_baños'

# %% [markdown]
# #### [0 / #]

# %%
# Filtrar los registros según las condiciones dadas
totales = df[( (df['medio_baños']==0) & (df['medios_baños'].notna()) )] 
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# Iterar sobre los registros filtrados
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    print(row[['url']])
    print("\n¿Qué acción te gustaría realizar?")
    print("1. Sustituir el valor manualmente")
    print("2. Sustituir el valor de 'medio_baños' por el de 'medios_baños'")
    #print("3. Asignar 1 como mínimo y pasar al siguiente registro")
    print("3. Pasar al siguiente registro")

    # Solicitar la opción al usuario
    option = input("Elige una opción (1 | 2 | 3): ")

    if option == '1':
        # Sustituir el valor manualmente
        new_value = input("Introduce el nuevo valor para 'medio_baños': ")
        df.at[idx, 'medio_baños'] = float(new_value)
    elif option == '2':
        # Sustituir el valor de 'medio_baños' por 'medios_baños'
        df.at[idx, 'medio_baños'] = df.at[idx, 'medios_baños']
    #elif option == '3':
        # Asignar valor de 1 como mínimo
        #df.at[idx, 'medio_baños'] = 1
        #continue  # Pasar al siguiente registro
    else:
        continue  # Pasar al siguiente registro

    print("\n---\n")

print("Proceso completado.")

# %% [markdown]
# #### [# / #]

# %%
# Filtrar los registros según las condiciones dadas
totales = df[( ((df['medio_baños']!=0) & (df['medios_baños'].notna())) & (df['medio_baños'] != df['medios_baños']))] 
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# Iterar sobre los registros filtrados
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    print(row[['url']])
    print("\n¿Qué acción te gustaría realizar?")
    print("1. Sustituir el valor manualmente")
    print("2. Sustituir el valor de 'medio_baños' por el de 'medios_baños'")
    #print("3. Asignar 1 como mínimo y pasar al siguiente registro")
    print("3. Pasar al siguiente registro")

    # Solicitar la opción al usuario
    option = input("Elige una opción (1 | 2 | 3): ")

    if option == '1':
        # Sustituir el valor manualmente
        new_value = input("Introduce el nuevo valor para 'medio_baños': ")
        df.at[idx, 'medio_baños'] = float(new_value)
    elif option == '2':
        # Sustituir el valor de 'medio_baños' por 'medios_baños'
        df.at[idx, 'medio_baños'] = df.at[idx, 'medios_baños']
    #elif option == '3':
        # Asignar valor de 1 como mínimo
        #df.at[idx, 'medio_baños'] = 1
        #continue  # Pasar al siguiente registro
    else:
        continue  # Pasar al siguiente registro

    print("\n---\n")

print("Proceso completado.")

# %% [markdown]
# ## B) Total de baños

# %%
# Make the medio_baños and banos sum
# 'medio_baños', divididos entre 2 para representar medios
df['bano_total'] = df['banos'] + (df['medio_banos'] / 2)
df['bano_total'] = df['bano_total'].round(1)  # Round the total, not just 'banos'
print(df[['banos', 'medio_banos', 'bano_total']].head())
# Out:
#    banos  medio_banos  bano_total
# 0      5            0         5.0
# 1      0            0         0.0
# 2      0            0         0.0
# 3      1            0         1.0
# 4      1            0         1.0
