# %% [markdown]
# # **Limpieza**

# %% [markdown]
# #### LIBRERÍAS

# %%
import pandas as pd # Manipulación df
import os # Directorios
import re # Manipulación de cadenas de texto (expresiones regulares)
import unicodedata# Función para eliminar acentos
from datetime import datetime, date  # Para trabajar con fechas y horas
from currency_converter import CurrencyConverter # convertidor de monedas
from dateutil.relativedelta import relativedelta  # Para calcular diferencias entre fechas, incluyendo años, meses y días

# %% [markdown]
# #### CARGAR ARCHIVO

# %% [markdown]
# Solo cambia el nombre del archivo en 'csv_filename' y su ruta con 'csv_dir'

# %%
directorio_actual = os.getcwd() # Directorio actual de trabajo
# Ruta relativa al archivo CSV
csv_filename = 'lamudi-Abril-QueretaroInmuebles .xlsx'
csv_dir = os.path.join(directorio_actual)#, 'datos'
csv_path = os.path.join(csv_dir, csv_filename)

# %% [markdown]
# Elimina el # de la primer línea si el archivo a leer no contiene el nombre de las columnas

# %%
#column_names=['precio','denominacion','propiedad','metros_total','metros_construido','tiempo_de_publicacion','tipo','estacionamientos','recamaras','banos','medio_banos','seguridad_privada','ubicacion','url','descripcion']
df = pd.read_excel(csv_path)#, names=column_names
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9344 entries, 0 to 9343
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   precio                 9344 non-null   int64
#  1   denominacion           9344 non-null   object
#  2   propiedad              9344 non-null   object
#  3   metros_total           9344 non-null   int64
#  4   metros_construido      9344 non-null   int64
#  5   tiempo_de_publicacion  9344 non-null   object
#  6   tipo                   9343 non-null   object
#  7   estacionamientos       9344 non-null   int64
#  8   recamaras              9344 non-null   int64
#  9   banos                  9344 non-null   int64
#  10  medio_banos            9344 non-null   int64
#  11  seguridad_privada      9344 non-null   object
#  12  ubicacion              9344 non-null   object
#  13  url                    9344 non-null   object
#  14  descripcion            9344 non-null   object
# dtypes: int64(7), object(8)
# memory usage: 1.1+ MB

# %% [markdown]
# #### LIMPIEZA NULOS

# %%
df.fillna({'precio': 0}, inplace=True) 
df.fillna({'propiedad': 'Propiedad sin título'}, inplace=True) 
df.fillna({'metros_total': 0}, inplace=True) 
df.fillna({'metros_construido': 0}, inplace=True) 
df.fillna({'tiempo_de_publicacion': '1 ene 1000'}, inplace=True) 
df.fillna({'tipo': 'Propiedad sin tipo de casa'}, inplace=True) 
df.fillna({'estacionamientos': 0}, inplace=True) 
df.fillna({'recamaras': 0}, inplace=True) 
df.fillna({'banos': 0}, inplace=True) 
df.fillna({'medio_banos': 0}, inplace=True) 
df.fillna({'seguridad_privada': 'No'}, inplace=True) 
df.fillna({'ubicacion': 'Propiedad sin ubicación'}, inplace=True) 
df.fillna({'url': '-'}, inplace=True) 
df.fillna({'descripcion': "Propiedad sin descripcion"}, inplace=True)

# %%
df.isna().sum()
# Out:
# precio                   0
# denominacion             0
# propiedad                0
# metros_total             0
# metros_construido        0
# tiempo_de_publicacion    0
# tipo                     0
# estacionamientos         0
# recamaras                0
# banos                    0
# medio_banos              0
# seguridad_privada        0
# ubicacion                0
# url                      0
# descripcion              0
# dtype: int64

# %% [markdown]
# # 1. Manipulación de precios

# %% [markdown]
# ## a) Precio en descripción

# %% [markdown]
# Agrega las diferentes formas de que el precio se encuentre en la descripción.

# %%
def extraer_precio(descripcion):
    descripcion = descripcion.lower()
    # Buscar patrones
    precios = re.findall(r'\b(\d+[\.,]?\d*[\.,]?\d*)\s*($|mil pesos|mxn|precio|pesos|monto|Pesos Mexicanos|USD)', descripcion)
    precio = None
    for match in precios:
        numero, moneda = match
        numero = numero.replace(',', '').replace("'", '').replace(".",'')
        try:
            precio = float(numero)
        except ValueError:
            continue
        if precio:
            break
    return precio

# Denominación de la descripción
def extraer_denominacion(descripcion):
    descripcion = descripcion.lower()
    # Buscar patrones 
    denominaciones = re.findall(r'\b(mil|mxn|precio|pesos|monto|Mexicanos|Estadounidenses)\b', descripcion)
    return denominaciones[0] if denominaciones else None

df['precio_desc'] = df['descripcion'].apply(extraer_precio)
#df['denominacion_desc'] = df['descripcion'].apply(extraer_denominacion)

# %% [markdown]
# ### Precio [0 / 0]

# %%
# Filtrar los registros según las condiciones dadas
totales = df[( (df['precio'] == 0 ) & (df['precio_desc'].isna()) )] 
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas
# Iterar sobre los registros filtrados
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    print(row[['precio', 'precio_desc', 'url']])
    print("\n¿Qué acción te gustaría realizar?")
    print("1. Sustituir el valor manualmente")
    print("2. Pasar al siguiente registro")

    # Solicitar la opción al usuario
    option = input("Elige una opción (1 o 2): ")

    if option == '1':
        # Sustituir el valor manualmente
        new_value = input("Introduce el nuevo valor para 'precio': ")
        df.at[idx, 'precio'] = float(new_value)
    elif option == '2':
        # Pasar al siguiente registro
        continue
    else:
        print("Opción no válida. Pasando al siguiente registro...")
    
    print("\n---\n")

print("Proceso completado.")
# Out:
# Proceso completado.

# %% [markdown]
# Eliminar registros que no recuperaron su precio ni desde la descripción

# %%
df = df[~( (df['precio'] == 0 ) & (df['precio_desc'].isna()) )]

# %% [markdown]
# ### Precio [0 / #]

# %%
# Filtrar los registros según las condiciones dadas
totales = df[( (df['precio'] == 0 ) & (df['precio_desc'].notna()) )] 
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# Iterar sobre los registros filtrados
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    print(row[['precio', 'precio_desc', 'url']])
    print("\n¿Qué acción te gustaría realizar?")
    print("1. Sustituir el valor manualmente")
    print("2. Sustituir el valor de 'precio' por el de 'precio_desc'")
    print("3. Pasar al siguiente registro")

    # Solicitar la opción al usuario
    option = input("Elige una opción (1, 2, 3): ")

    if option == '1':
        # Sustituir el valor manualmente
        new_value = input("Introduce el nuevo valor para 'precio': ")
        df.at[idx, 'precio'] = float(new_value)
    elif option == '2':
        # Sustituir el valor de 'metros_total' por 'totales_desc'
        df.at[idx, 'precio'] = df.at[idx, 'precio_desc']
    elif option == '3':
        # Pasar al siguiente registro
        continue
    else:
        print("Opción no válida. Pasando al siguiente registro...")
    
    print("\n---\n")

print("Proceso completado.")
# Out:
# Proceso completado.

# %% [markdown]
# ### Precio [# / #]

# %%
# Filtrar los registros según las condiciones dadas
totales = df[( ((df['precio']!= 0) & (df['precio_desc'].notna())) & (df['precio'] != df['precio_desc']) )] 
# Filtro dentro del estándar
totales = totales[(totales['precio_desc'] >= 250000) & (totales['precio_desc'] <= 500000000)]
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# Iterar sobre los registros filtrados
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    print(row[['precio', 'precio_desc', 'url']])
    print("\n¿Qué acción te gustaría realizar?")
    print("1. Sustituir el valor manualmente")
    print("2. Sustituir el valor de 'precio' por el de 'precio_desc'")
    print("3. Pasar al siguiente registro")

    # Solicitar la opción al usuario
    option = input("Elige una opción (1, 2, 3): ")

    if option == '1':
        # Sustituir el valor manualmente
        new_value = input("Introduce el nuevo valor para 'precio': ")
        df.at[idx, 'precio'] = float(new_value)
    elif option == '2':
        # Sustituir el valor de 'metros_total' por 'totales_desc'
        df.at[idx, 'precio'] = df.at[idx, 'precio_desc']
    elif option == '3':
        # Pasar al siguiente registro
        continue
    else:
        print("Opción no válida. Pasando al siguiente registro...")
    
    print("\n---\n")

print("Proceso completado.")
# Out:
# Registro 22:
# precio                                                                                   600000
# precio_desc                                                                           2500000.0
# url            https://www.lamudi.com.mx//detalle/41032-73-6777bfd1c02c-5ecc-c4010eec-81e6-47d4
# Name: 22, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Registro 23:
# precio                                                                                   610000
# precio_desc                                                                          61000000.0
# url            https://www.lamudi.com.mx//detalle/41032-73-58c0cd447fd0-bf57-407329a9-b48b-429c
# Name: 23, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Registro 54:
# precio                                                                                 730000
# precio_desc                                                                        33000000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-1c0ac48169d-88a6-1908b65e-bd7c-41d2
# Name: 54, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Registro 102:
# precio                                                                                  750000
# precio_desc                                                                          3300000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-ba2968667c83-da18-e90444be-8e44-4103
# Name: 102, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Registro 203:
# precio                                                                                  810000
# precio_desc                                                                          5000000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-87727839c13b-d626-d8c3bf42-97f1-4797
# Name: 203, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Registro 269:
# precio                                                                                   865000
# precio_desc                                                                          86500000.0
# url            https://www.lamudi.com.mx//detalle/41032-73-9e5da0aae2ba-e792-299e5bf9-8bf5-4c3a
# Name: 269, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 453:
# precio                                                                                 1101000
# precio_desc                                                                         15000000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-ba5c66d13353-97fa-eb765495-b95a-36ae
# Name: 453, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Registro 499:
# precio                                                                                  1200000
# precio_desc                                                                          20000000.0
# url            https://www.lamudi.com.mx//detalle/41032-73-255a70596672-776a-767072bc-acba-3ced
# Name: 499, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Registro 504:
# precio                                                                                  1220000
# precio_desc                                                                           5000000.0
# url            https://www.lamudi.com.mx//detalle/41032-73-44ae6beea308-638f-c404249a-a36b-4820
# Name: 504, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Registro 548:
# precio                                                                                  1270287
# precio_desc                                                                           1406070.0
# url            https://www.lamudi.com.mx//detalle/41032-73-2c20ed0bf325-ec8a-1f7e0f54-841c-37c1
# Name: 548, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Registro 589:
# precio                                                                                  1348000
# precio_desc                                                                          34800000.0
# url            https://www.lamudi.com.mx//detalle/41032-73-4fd20be313a6-44c0-96ecab6d-8b93-3add
# Name: 589, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Registro 606:
# precio                                                                                  1350000
# precio_desc                                                                           1300000.0
# url            https://www.lamudi.com.mx//detalle/41032-73-e632985224c1-afb8-4f17c198-babf-38e2
# Name: 606, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Registro 620:
# precio                                                                                 1378000
# precio_desc                                                                          1324000.0
# url            https://www.lamudi.com.mx//detalle/41032-73-c57b58f17808-a33-dc68d36b-909b-3fe2
# Name: 620, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Registro 727:
# precio                                                                                 1502000
# precio_desc                                                                          1600000.0
# url            https://www.lamudi.com.mx//detalle/41032-73
.0
# url            https://www.lamudi.com.mx//detalle/41032-73-c3516fed2052-f4a5-c719ca42-9cdb-3b97
# Name: 2763, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2936:
# precio                                                                                  3000000
# precio_desc                                                                           3150000.0
# url            https://www.lamudi.com.mx//detalle/41032-73-896b64a3f210-680e-453bf709-a570-1237
# Name: 2936, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Registro 3098:
# precio                                                                                  2790000
# precio_desc                                                                           3370000.0
# url            https://www.lamudi.com.mx//detalle/41032-73-90d77b4669d8-a9de-61c11462-8a34-4603
# Name: 3098, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 3157:
# precio                                                                                 3902206
# precio_desc                                                                          4181000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-52bebbb85c54-2074-de06761f-8f7b-3d09
# Name: 3157, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Registro 3210:
# precio                                                                                  2850000
# precio_desc                                                                          90000000.0
# url            https://www.lamudi.com.mx//detalle/41032-73-f48a0712d68c-e48a-b0916dce-91a7-48a6
# Name: 3210, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 3307:
# precio                                                                                  3098000
# precio_desc                                                                           3198650.0
# url            https://www.lamudi.com.mx//detalle/41032-73-154268631f7c-1cc3-b6a6affd-92d5-38eb
# Name: 3307, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Registro 3359:
# precio                                                                                 3850000
# precio_desc                                                                          3500000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-fb975132159e-2153-7b1b4d1c-ac54-33d4
# Name: 3359, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Registro 3449:
# precio                                                                                  3750000
# precio_desc                                                                          75000000.0
# url            https://www.lamudi.com.mx//detalle/41032-73-7066bf42289e-6305-ffc0adf0-80de-4ecc
# Name: 3449, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Registro 3470:
# precio                                                                                3600000
# precio_desc                                                                          600000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-32df45043ab4-9377-f7c18dd-b060-4726
# Name: 3470, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Registro 3552:
# precio                                                                                  3850000
# precio_desc                                                                          85000000.0
# url            https://www.lamudi.com.mx//detalle/41032-73-cf60bc443b68-c7f9-6f21ed99-b5b8-1237
# Name: 3552, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Registro 3553:
# precio                                                                                 3850000
# precio_desc                                                                         85000000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-cf60bc443b68-c7f9-6f21ed99-b5b8-1237
# Name: 3553, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Registro 3717:
# precio                                                                                 3350000
# precio_desc                                                                          3600000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-2d10e695cfeb-6afd-f6df8de9-8292-1f58
# Name: 3717, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 3750:
# precio                                                                                  5907494
# precio_desc                                                                          90749375.0
# url            https://www.lamudi.com.mx//detalle/41032-73-b03165af88f7-c73b-f595b24a-95f6-367c
# Name: 3750, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 4019:
# precio                                                                                  5668757
# precio_desc                                                                          47753502.0
# url            https://www.lamudi.com.mx//detalle/41032-73-45efe9f9a27b-b370-803026a1-af57-32d2
# Name: 4019, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Registro 4048:
# precio                                                                                  5700000
# precio_desc                                                                           5400000.0
# url            https://www.lamudi.com.mx//detalle/41032-73-3533bae4d7ab-cfbc-72289c39-8722-1f0d
# Name: 4048, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Registro 4270:
# precio                                                                                  5500000
# precio_desc                                                                           6400000.0
# url            https://www.lamudi.com.mx//detalle/41032-73-8c82315f6730-5caf-753da041-a591-35f2
# Name: 4270, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Registro 4366:
# precio                                                                                 5400000
# precio_desc                                                                           400000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-af1f4ec243f2-1322-b4598b68-9309-4f5b
# Name: 4366, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Registro 4379:
# precio                                                                                  5400000
# precio_desc                                                                          40000000.0
# url            https://www.lamudi.com.mx//detalle/41032-73-4f7b25a30079-dcf1-69357d9a-84da-49ad
# Name: 4379, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Registro 4396:
# precio                                                                                  5370357
# precio_desc                                                                          47753502.0
# url            https://www.lamudi.com.mx//detalle/41032-73-6c3a8144f19b-6589-c5d53a34-a952-39d3
# Name: 4396, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Registro 4449:
# precio                                                                                  5300000
# precio_desc                                                                          80000000.0
# url            https://www.lamudi.com.mx//detalle/41032-73-a0ec987aa613-f1de-5557fbdf-8ab1-503d
# Name: 4449, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Registro 4491:
# precio                                                                                 5300000
# precio_desc                                                                          5200000.0
# url            https://www.lamudi.com.mx//detalle/41032-73-e4ec3c2720d-175d-a847909c-8836-45a2
# Name: 4491, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Registro 4492:
# precio                                                                                5300000
# precio_desc                                                                         5200000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-e4ec3c2720d-175d-a847909c-8836-45a2
# Name: 4492, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Registro 4627:
# precio                                                                                 5100000
# precio_desc                                                                         10000000.0
# url            https://www.lamudi.com.mx//detalle/41032-73-dca6e8d68839-2332-2aa6e45-9038-3865
# Name: 4627, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Registro 4628:
# precio                                                                                  5100000
# precio_desc                                                                          10000000.0
# url            https://www.lamudi.com.mx//detalle/41032-73-468af588d2be-1e82-a7f0e5c5-9b6c-36f4
# Name: 4628, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Registro 4657:
# precio                                                                                  5185596
# precio_desc                                                                          18559602.0
# url            https://www.lamudi.com.mx//detalle/41032-73-1d70028edf8f-f151-a92a68d0-aac4-331a
# Name: 4657, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 4837:
# precio                                                                                  4116000
# precio_desc                                                                          37890000.0
# url            https://www.lamudi.com.mx//detalle/41032-73-812a024240e3-41d9-200eeb1a-baba-4c43
# Name: 4837, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Registro 4972:
# precio                                                                                4917000
# precio_desc                                                                         5000000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-30ae0b656ed9-10c5-a9e5276-8975-4528
# Name: 4972, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Registro 5086:
# precio                                                                                 4920000
# precio_desc                                                                         92000000.0
# url            https://www.lamudi.com.mx//detalle/41032-73-b1dde2858399-c713-ddfe39d-986c-3693
# Name: 5086, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Registro 5450:
# precio                                                                                  4600000
# precio_desc                                                                          60000000.0
# url            https://www.lamudi.com.mx//detalle/41032-73-7f3441f0fb3b-d6ac-ee055352-9eec-35ad
# Name: 5450, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Registro 5707:
# precio                                                                                  4464000
# precio_desc                                                                           4225000.0
# url            https://www.lamudi.com.mx//detalle/41032-73-c037ea040993-2f28-f169800f-9ac6-379d
# Name: 5707, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Registro 5708:
# precio                                                                                  4464000
# precio_desc                                                                           4225000.0
# url            https://www.lamudi.com.mx//detalle/41032-73-98da24034e29-66bb-a77d8812-b408-38c5
# Name: 5708, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Registro 5724:
# precio                                                                                  4500000
# precio_desc                                                                           5600000.0
# url            https://www.lamudi.com.mx//detalle/41032-73-bf84d5ca7509-f11a-f5592df2-a4ac-3cf3
# Name: 5724, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Registro 5727:
# precio                                                                                4500000
# precio_desc                                                                         3980121.0
# url            https://www.lamudi.com.mx/detalle/41032-73-5118134caec8-c34-9e72a7c4-9dad-3f00
# Name: 5727, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Registro 5741:
# precio                                                                                  4449415
# precio_desc                                                                          18960955.0
# url            https://www.lamudi.com.mx//detalle/41032-73-1519594aa0e9-2060-ecf75464-aa7d-3a31
# Name: 5741, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Registro 5861:
# precio                                                                                 5500000
# precio_desc                                                                         90000000.0
# url            https://www.lamudi.com.mx//detalle/41032-73-5b47bc1397bf-d887-95c694f-bdbd-31af
# Name: 5861, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Registro 5909:
# precio                                                                                  4895000
# precio_desc                                                                           8890000.0
# url            https://www.lamudi.com.mx//detalle/41032-73-d6afcab03a0c-4dd7-bdf4ed45-8644-4a4d
# Name: 5909, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Registro 5916:
# precio                                                                                 4349000
# precio_desc                                                                          2450000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-74236232009c-f0bf-9fbc7086-8cad-45a2
# Name: 5916, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Registro 5917:
# precio                                                                                  4349000
# precio_desc                                                                           2450000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-40d4bc173fc4-1002b-1abdf3e1-afa4-483a
# Name: 5917, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Registro 5918:
# precio                                                                                 4349000
# precio_desc                                                                          5000000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-7d8fa217e52b-6923-8935e338-a70d-4727
# Name: 5918, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Registro 5919:
# precio                                                                                 4349000
# precio_desc                                                                          2450000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-fd7f6474f4f2-afcf-74d7e532-9781-4c6c
# Name: 5919, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Registro 6002:
# precio                                                                                  4282890
# precio_desc                                                                           4485634.0
# url            https://www.lamudi.com.mx//detalle/41032-73-12b2d074ffe4-b6fe-d83389d2-a773-4908
# Name: 6002, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Registro 6108:
# precio                                                                                4250000
# precio_desc                                                                       250000000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-5fb81a01c95-5eb0-e7aa66d4-a187-44e6
# Name: 6108, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Registro 6134:
# precio                                                                                  4200000
# precio_desc                                                                            270000.0
# url            https://www.lamudi.com.mx//detalle/41032-73-1c9f202806d2-e018-17749d6b-9485-3b8a
# Name: 6134, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Registro 6179:
# precio                                                                                 4185000
# precio_desc                                                                          4540000.0
# url            https://www.lamudi.com.mx//detalle/41032-73
dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Registro 7929:
# precio                                                                                  6950000
# precio_desc                                                                            350000.0
# url            https://www.lamudi.com.mx//detalle/41032-73-65f30a9e4857-f076-8a559264-aa97-3139
# Name: 7929, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 8089:
# precio                                                                                 21850000
# precio_desc                                                                          85000000.0
# url            https://www.lamudi.com.mx//detalle/41032-73-3017c19b5016-e3c7-7a18982f-83c4-4651
# Name: 8089, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Registro 8265:
# precio                                                                                 7500000
# precio_desc                                                                          8360000.0
# url            https://www.lamudi.com.mx//detalle/41032-73-fbce850c5a55-eac-32774ad0-850c-45cd
# Name: 8265, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Registro 8309:
# precio                                                                                  9477535
# precio_desc                                                                          47753502.0
# url            https://www.lamudi.com.mx//detalle/41032-73-3ce879b9bc90-4595-d92474cc-9627-3ee0
# Name: 8309, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Registro 8332:
# precio                                                                                 10821214
# precio_desc                                                                          82121400.0
# url            https://www.lamudi.com.mx//detalle/41032-73-bdf929741e9d-97ac-28abf77e-8b2e-323e
# Name: 8332, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Registro 8467:
# precio                                                                                  6496416
# precio_desc                                                                           5000000.0
# url            https://www.lamudi.com.mx//detalle/41032-73-dccb361ae41f-3abd-d5317ecd-a670-3e51
# Name: 8467, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Registro 8657:
# precio                                                                                  6400000
# precio_desc                                                                          40000000.0
# url            https://www.lamudi.com.mx//detalle/41032-73-5d871e0e9059-970e-70ccca2d-8525-3bfd
# Name: 8657, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Registro 8776:
# precio                                                                                 9513000
# precio_desc                                                                          5000000.0
# url            https://www.lamudi.com.mx//detalle/41032-73-3ce5ba7d0a97-a34-2a8bd0bc-9a9f-3a00
# Name: 8776, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Registro 8882:
# precio                                                                                23164000
# precio_desc                                                                         28491720.0
# url            https://www.lamudi.com.mx/detalle/41032-73-ede4d8b9f99e-2e74-74501990-a26f-304c
# Name: 8882, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Registro 8911:
# precio                                                                                  6149623
# precio_desc                                                                          14962258.0
# url            https://www.lamudi.com.mx//detalle/41032-73-3e27400ce158-95c6-31cf3879-a021-3feb
# Name: 8911, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Registro 8957:
# precio                                                                                 8700000
# precio_desc                                                                         10000000.0
# url            https://www.lamudi.com.mx//detalle/41032-73-a602f5758367-2479-52a66b4-ac2a-502a
# Name: 8957, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Registro 8958:
# precio                                                                                8700000
# precio_desc                                                                        10000000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-a602f5758367-2479-52a66b4-ac2a-502a
# Name: 8958, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Registro 8959:
# precio                                                                                8700000
# precio_desc                                                                        10000000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-a602f5758367-2479-52a66b4-ac2a-502a
# Name: 8959, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Registro 9181:
# precio                                                                                 23234200
# precio_desc                                                                          24830000.0
# url            https://www.lamudi.com.mx//detalle/41032-73-5982a7b6e687-1f33-782a886a-81e7-4285
# Name: 9181, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Registro 9182:
# precio                                                                                 23234200
# precio_desc                                                                          24830000.0
# url            https://www.lamudi.com.mx//detalle/41032-73-ec421d5177f2-303d-219bb52b-9be3-4253
# Name: 9182, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Pasar al siguiente registro
# Proceso completado.

# %% [markdown]
# ## b) Denominación MXN

# %% [markdown]
# SI EXISTE UNA DENOMINACIÓN QUE NO SEA MXN, SE CONVIERTA EL PRECIO

# %%
import datetime
c = CurrencyConverter() # Instancia del convertidor de monedas
def convertir_a_mxn(precio, denominacion):
    if denominacion != 'MXN':
        return int(round(c.convert(precio, denominacion, 'MXN')))
    return precio

def convertir_a_usd(precio, denominacion):
    if denominacion != 'USD':
        return round(c.convert(precio, denominacion, 'USD'), 2)
    return precio

# Obtener la fecha actual
fecha_conversion = datetime.datetime.now().date()

# Aplicar la conversión a cada fila del DataFrame y agregar la fecha de conversión
df['precio_mxn'] = df.apply(lambda row: convertir_a_mxn(row['precio'], row['denominacion']), axis=1)
df['precio_usd'] = df.apply(lambda row: convertir_a_usd(row['precio'], row['denominacion']), axis=1)
#df['denominacion_mxn'] = 'MXN'
#df['denominacion_usd'] = 'USD'
df['fecha_conversion'] = fecha_conversion

print(df[['precio', 'denominacion', 'precio_mxn', 'precio_usd', 'fecha_conversion']].head())

# Mover las columnas 'precio_mxn' y 'precio_usd' al inicio del DataFrame
#cols = ['precio_mxn', 'precio_usd'] + [col for col in df.columns if col not in ['precio_mxn', 'precio_usd']]
#df = df[cols]
# Out:
#     precio denominacion  precio_mxn  precio_usd fecha_conversion
# 0  2640000          MXN     2640000   146849.88       2024-09-09
# 1  6950000          MXN     6950000   386593.44       2024-09-09
# 2  2908782          MXN     2908782   161800.87       2024-09-09
# 3   280000          MXN      280000    15574.99       2024-09-09
# 4   400000          MXN      400000    22249.98       2024-09-09

# %% [markdown]
# ## c) Precio fuera del estandar

# %% [markdown]
# IDENTIFICAR Y ELIMINAR PROPIEDADES QUE CUENTEN CON PRECIOS BAJOS y ALTOS AL ESTANDAR

# %%
# Eliminar los registros donde el precio es menor al estandar (250,000) y con precio_desc vacío
df = df[(df['precio'] >= 250000)] #& (df['precio_desc'].notna())]
# Eliminar los registros donde el precio es mayor al estandar (500,000,000) y con precio_desc vacío
df = df[(df['precio'] <= 500000000)] #& (df['precio_desc'].notna())] 
# Ordenar valores de manera ascendente
df['precio'].sort_values()
# Out:
# 3         280000
# 4         400000
# 6         464000
# 7         490000
# 8         490000
#           ...
# 7209    52500000
# 9282    54800000
# 9283    54800000
# 9284    58000000
# 8127    76460000
# Name: precio, Length: 9344, dtype: int64

# %% [markdown]
# ## D) Segmento o categoría

# %%
bins = [0, 500000, 750000, 1000000, 1250000, 1500000, 1750000, 2000000, 2250000, 2500000,
        2750000, 3000000, 3250000, 3500000, 3750000, 4000000, 6000000, 8000000, 12000000,
        14000000, 16000000, 18000000, 22000000, float('inf')]
labels = ["E1", "E2", "E3", "D1", "D2", "D3", "C1", "C2", "C3", "B1", "B2", "B3",
          "A1", "A2", "A3", "S1", "S2", "S3", "L1", "L2", "L3", "L+", "ELITE"]

# Utilizar pd.cut para clasificar los valores
df['categoria'] = pd.cut(df['precio'], bins=bins, labels=labels, right=False)
print(df['categoria'].unique())
# Out:
# ['B1', 'S2', 'B2', 'E1', 'E2', ..., 'L3', 'S3', 'L1', 'L+', 'L2']
# Length: 23
# Categories (23, object): ['E1' < 'E2' < 'E3' < 'D1' ... 'L2' < 'L3' < 'L+' < 'ELITE']

# %% [markdown]
# # 2. Meses transcurridos

# %% [markdown]
# Sacar el número de meses transcurridos desde la fecha de su publicación a la actual

# %%
df['tiempo_de_publicacion']
# Out:
# 0       2024-03-01 00:00:00
# 1       2023-11-25 00:00:00
# 2              22 ago. 2023
# 3              20 abr. 2023
# 4               1 dic. 2023
#                ...
# 9339           30 ene. 2024
# 9340    2023-10-07 00:00:00
# 9341    2024-02-12 00:00:00
# 9342           24 abr. 2023
# 9343           24 abr. 2023
# Name: tiempo_de_publicacion, Length: 9344, dtype: object

# %%
from datetime import datetime
# Convertir el mes abreviado en número
def month_to_int(month):
    months = ['ene', 'feb', 'mar', 'abr', 'may', 'jun', 'jul', 'ago', 'sep', 'oct', 'nov', 'dic']
    return months.index(month.lower()) + 1

# Estandarizar el formato de fecha
def standardize_date(date_str):
    # Caso 1: formato "20 abr. 2023" -> "2023-04-20"
    try:
        day, month, year = date_str.split(' ')
        month_int = month_to_int(month.replace('.', ''))  # Eliminar puntos si existen
        return f"{year}-{month_int:02d}-{int(day):02d}"
    except (ValueError, AttributeError):
        pass

    # Caso 2: formato "YYYY-MM-DD HH:MM:SS" o "YYYY-MM-DD"
    try:
        return pd.to_datetime(date_str).strftime('%Y-%m-%d')
    except (ValueError, TypeError):
        # Si no se puede convertir, devolver None
        return None

# Aplicar la función a la columna 'tiempo_de_publicacion'
df['fecha_estandarizada'] = df['tiempo_de_publicacion'].apply(standardize_date)

# Convertir a datetime y manejar errores
df['fecha_estandarizada'] = pd.to_datetime(df['fecha_estandarizada'], errors='coerce')

# Obtener la fecha actual
fecha_actual = datetime.now().date()

# Función para calcular la diferencia en meses
def calcular_meses(fecha):
    if pd.isnull(fecha):
        return None
    rd = relativedelta(fecha_actual, fecha.date())
    return rd.years * 12 + rd.months

# Aplicar la función para calcular los meses transcurridos
df['meses_transcurridos'] = df['fecha_estandarizada'].apply(calcular_meses)

# Mostrar el DataFrame con las fechas estandarizadas y meses transcurridos
print(df[['tiempo_de_publicacion', 'fecha_estandarizada', 'meses_transcurridos']])
# Out:
#      tiempo_de_publicacion fecha_estandarizada  meses_transcurridos
# 0      2024-03-01 00:00:00          2024-03-01                  6.0
# 1      2023-11-25 00:00:00          2023-11-25                  9.0
# 2             22 ago. 2023          2023-08-22                 12.0
# 3             20 abr. 2023          2023-04-20                 16.0
# 4              1 dic. 2023          2023-12-01                  9.0
# ...                    ...                 ...                  ...
# 9339          30 ene. 2024          2024-01-30                  7.0
# 9340   2023-10-07 00:00:00          2023-10-07                 11.0
# 9341   2024-02-12 00:00:00          2024-02-12                  6.0
# 9342          24 abr. 2023          2023-04-24                 16.0
# 9343          24 abr. 2023          2023-04-24                 16.0
#
# [9344 rows x 3 columns]

# %% [markdown]
# # 3. Tipo de propiedad

# %% [markdown]
# ## a) Lista de tipos deseados

# %%
# Filtrar los registros según los tipos especificados
tipos_permitidos = 'Casa|Casa en Fraccionamiento|Casa en Condominio|Departamento|Penthouse|Dúplex|Loft|Estudio|Condominio Horizontal'
df = df[df['tipo'].str.contains(tipos_permitidos, na=False)]
df['tipo'].unique()
# Out:
# array(['Casa', 'Departamento', 'Casa en Fraccionamiento', 'Dúplex',
#        'Condominio Horizontal', 'Casa en Condominio'], dtype=object)

# %% [markdown]
# ## b) Manejo de terrenos

# %% [markdown]
# Se buscan los registros que no sean las propiedades si no un solo terreno

# %%
# Filtrar los registros según las condiciones dadas
totales =df[df['descripcion'].str.contains('lotes', case=False)]
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# MANEJAR PROCESO DE ELIMINACIÓN 
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    print(row[['url']])#'descripcion',
    
    print("\n¿Te gustaría eliminar el registro?")
    # Solicitar la opción al usuario
    option = input("Elige una opción (si / no): ").strip().lower()
    
    if option == 'si':
        df.drop(idx, inplace=True)
        print(f"Registro eliminado.\n")
    else:
        print(f"Registro conservado.\n")
        print("\n---\n")
print("Proceso completado.")
# Out:
# Registro 1368:
# url    https://www.lamudi.com.mx//detalle/41032-73-9d044785283c-c487-3cbac49-8ab7-1237
# Name: 1368, dtype: object
#
# ¿Te gustaría eliminar el registro?
# Registro conservado.
#
#
# ---
#
# Registro
dtype: object
#
# ¿Te gustaría eliminar el registro?
# Registro conservado.
#
#
# ---
#
# Registro 7875:
# url    https://www.lamudi.com.mx/detalle/41032-73-e5ecc1f1406c-b699-5353fa83-8071-3882
# Name: 7875, dtype: object
#
# ¿Te gustaría eliminar el registro?
# Registro conservado.
#
#
# ---
#
# Registro 8285:
# url    https://www.lamudi.com.mx//detalle/41032-73-a9a772af8486-de0f-ea2a9b97-bd24-389b
# Name: 8285, dtype: object
#
# ¿Te gustaría eliminar el registro?
# Registro conservado.
#
#
# ---
#
# Registro 8534:
# url    https://www.lamudi.com.mx//detalle/41032-73-a24855d8eedb-db5b-c97f5a4e-b9a1-3d98
# Name: 8534, dtype: object
#
# ¿Te gustaría eliminar el registro?
# Registro conservado.
#
#
# ---
#
# Registro 8819:
# url    https://www.lamudi.com.mx/detalle/41032-73-dba084047e07-c73a-bddd7b8d-b6fa-386a
# Name: 8819, dtype: object
#
# ¿Te gustaría eliminar el registro?
# Registro conservado.
#
#
# ---
#
# Registro 8820:
# url    https://www.lamudi.com.mx/detalle/41032-73-dba084047e07-c73a-bddd7b8d-b6fa-386a
# Name: 8820, dtype: object
#
# ¿Te gustaría eliminar el registro?
# Registro conservado.
#
#
# ---
#
# Registro 8821:
# url    https://www.lamudi.com.mx/detalle/41032-73-d6cddc7ca082-676c-a81fdfe2-b6bf-3955
# Name: 8821, dtype: object
#
# ¿Te gustaría eliminar el registro?
# Registro conservado.
#
#
# ---
#
# Registro 8822:
# url    https://www.lamudi.com.mx/detalle/41032-73-d6cddc7ca082-676c-a81fdfe2-b6bf-3955
# Name: 8822, dtype: object
#
# ¿Te gustaría eliminar el registro?
# Registro conservado.
#
#
# ---
#
# Registro 8823:
# url    https://www.lamudi.com.mx/detalle/41032-73-df4589fd6a66-a8c6-efca3927-a263-33f3
# Name: 8823, dtype: object
#
# ¿Te gustaría eliminar el registro?
# Registro conservado.
#
#
# ---
#
# Registro 8845:
# url    https://www.lamudi.com.mx/detalle/41032-73-7f92941de5d-ca2b-bfe6cdcf-9901-3630
# Name: 8845, dtype: object
#
# ¿Te gustaría eliminar el registro?
# Registro conservado.
#
#
# ---
#
# Registro 8949:
# url    https://www.lamudi.com.mx//detalle/41032-73-786ead5e992b-73e1-d0e203b4-902b-35aa
# Name: 8949, dtype: object
#
# ¿Te gustaría eliminar el registro?
# Registro conservado.
#
#
# ---
#
# Registro 8954:
# url    https://www.lamudi.com.mx//detalle/41032-73-a0d1b263114c-53fd-4e24210f-8ee4-3806
# Name: 8954, dtype: object
#
# ¿Te gustaría eliminar el registro?
# Registro conservado.
#
#
# ---
#
# Registro 8955:
# url    https://www.lamudi.com.mx/detalle/41032-73-a0d1b263114c-53fd-4e24210f-8ee4-3806
# Name: 8955, dtype: object
#
# ¿Te gustaría eliminar el registro?
# Registro conservado.
#
#
# ---
#
# Registro 8957:
# url    https://www.lamudi.com.mx//detalle/41032-73-a602f5758367-2479-52a66b4-ac2a-502a
# Name: 8957, dtype: object
#
# ¿Te gustaría eliminar el registro?
# Registro conservado.
#
#
# ---
#
# Registro 8958:
# url    https://www.lamudi.com.mx/detalle/41032-73-a602f5758367-2479-52a66b4-ac2a-502a
# Name: 8958, dtype: object
#
# ¿Te gustaría eliminar el registro?
# Registro conservado.
#
#
# ---
#
# Registro 8959:
# url    https://www.lamudi.com.mx/detalle/41032-73-a602f5758367-2479-52a66b4-ac2a-502a
# Name: 8959, dtype: object
#
# ¿Te gustaría eliminar el registro?
# Registro conservado.
#
#
# ---
#
# Registro 8962:
# url    https://www.lamudi.com.mx//detalle/41032-73-a52cf77da957-3029-931a335f-a2dc-3f99
# Name: 8962, dtype: object
#
# ¿Te gustaría eliminar el registro?
# Registro conservado.
#
#
# ---
#
# Registro 9100:
# url    https://www.lamudi.com.mx//detalle/41032-73-743a61a2f6e6-98d9-7e58f877-9ced-38cd
# Name: 9100, dtype: object
#
# ¿Te gustaría eliminar el registro?
# Registro conservado.
#
#
# ---
#
# Registro 9101:
# url    https://www.lamudi.com.mx//detalle/41032-73-e99e48026f59-70a8-4d6e0b1b-9c49-368f
# Name: 9101, dtype: object
#
# ¿Te gustaría eliminar el registro?
# Registro conservado.
#
#
# ---
#
# Registro 9239:
# url    https://www.lamudi.com.mx//detalle/41032-73-cc16f8d4fdce-b860-e6a1178f-a74a-3ef8
# Name: 9239, dtype: object
#
# ¿Te gustaría eliminar el registro?
# Registro conservado.
#
#
# ---
#
# Proceso completado.

# %% [markdown]
# # 4. Metros totales

# %% [markdown]
# ## a) Metros en descripción

# %%
# Función para extraer totales de la descripción
def extraer_totales(descripcion):
    descripcion = descripcion.lower()
    # Buscar patrones de totales
    totales = re.findall(r'\b(\d+[\.,]?\d*)\s*(metros|totales|mt2)\b', descripcion)
    total = None
    for match in totales:
        numero, _ = match
        numero = numero.replace(',', '').replace("'", '')
        try:
            total = float(numero)
        except ValueError:
            continue
        if total:
            break
    return total

# Aplicar la función al DataFrame
df['totales_desc'] = df['descripcion'].apply(extraer_totales)

# %% [markdown]
# ### Metros [0 / 0]

# %%
# Filtrar los registros según las condiciones dadas
totales = df[( (df['metros_total'] == 0 ) & (df['totales_desc'].isna() | df['totales_desc']==0) )] 
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# Iterar sobre los registros filtrados
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    print(row[['metros_total', 'totales_desc', 'url']])
    print("\n¿Qué acción te gustaría realizar?")
    print("1. Sustituir el valor manualmente")
    print("2. Sustituir el valor de 'metros_total' por el de 'totales_desc'")
    print("3. Pasar al siguiente registro")

    # Solicitar la opción al usuario
    option = input("Elige una opción (1, 2, 3): ")

    if option == '1':
        # Sustituir el valor manualmente
        new_value = input("Introduce el nuevo valor para 'metros_total': ")
        df.at[idx, 'metros_total'] = float(new_value)
    elif option == '2':
        # Sustituir el valor de 'metros_total' por 'totales_desc'
        df.at[idx, 'metros_total'] = df.at[idx, 'totales_desc']
    elif option == '3':
        # Pasar al siguiente registro
        continue
    else:
        print("Opción no válida. Pasando al siguiente registro...")
    
    print("\n---\n")

print("Proceso completado.")
# Out:
# Proceso completado.

# %% [markdown]
# ### Metros [0 / #]

# %%
# Filtrar los registros según las condiciones dadas
totales = df[( (df['metros_total'] == 0 ) & (df['totales_desc'].notna()) )] 
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# Iterar sobre los registros filtrados
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    print(row[['metros_total', 'totales_desc', 'url']])
    print("\n¿Qué acción te gustaría realizar?")
    print("1. Sustituir el valor manualmente")
    print("2. Sustituir el valor de 'metros_total' por el de 'totales_desc'")
    print("3. Pasar al siguiente registro")

    # Solicitar la opción al usuario
    option = input("Elige una opción (1, 2, 3): ")

    if option == '1':
        # Sustituir el valor manualmente
        new_value = input("Introduce el nuevo valor para 'metros_total': ")
        df.at[idx, 'metros_total'] = float(new_value)
    elif option == '2':
        # Sustituir el valor de 'metros_total' por 'totales_desc'
        df.at[idx, 'metros_total'] = df.at[idx, 'totales_desc']
    elif option == '3':
        # Pasar al siguiente registro
        continue
    else:
        print("Opción no válida. Pasando al siguiente registro...")
    
    print("\n---\n")

print("Proceso completado.")
# Out:
# Proceso completado.

# %% [markdown]
# ### Metros [# / #]

# %%
# Filtrar los registros según las condiciones dadas
totales = df[( ((df['metros_total']!= 0) & (df['totales_desc'].notna())) & (df['metros_total'] != df['totales_desc']) )] 
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# Iterar sobre los registros filtrados
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    print(f"metros_total: {row['metros_total']}")
    print(f"totales_desc: {row['totales_desc']}")
    print(f"url: {row['url']}")
    
    print("\n¿Qué acción te gustaría realizar?")
    print("1. Sustituir el valor manualmente")
    print("2. Sustituir el valor de 'metros_total' por el de 'totales_desc'")
    print("3. Pasar al siguiente registro")

    # Solicitar la opción al usuario
    option = input("Elige una opción (1, 2, 3): ")

    if option == '1':
        # Sustituir el valor manualmente
        while True:
            try:
                new_value = float(input("Introduce el nuevo valor para 'metros_total': "))
                df.at[idx, 'metros_total'] = new_value
                break
            except ValueError:
                print("Por favor, introduce un número válido (entero o decimal).")
    elif option == '2':
        # Sustituir el valor de 'metros_total' por 'totales_desc'
        df.at[idx, 'metros_total'] = df.at[idx, 'totales_desc']
    elif option == '3':
        # Pasar al siguiente registro
        continue
    else:
        print("Opción no válida. Pasando al siguiente registro...")
    print("\n---\n")

print("Proceso completado.")
# Out:
# Registro 144:
# metros_total: 98
# totales_desc: 62.0
# url: https://www.lamudi.com.mx//detalle/41032-73-92df250cdc82-e8da-5c83126a-9d82-3842
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Registro 170:
# metros_total: 134
# totales_desc: 0.0
# url: https://www.lamudi.com.mx//detalle/41032-73-3e713fb07eab-9e59-ddbeb82f-aa33-4d40
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Registro 182:
# metros_total: 130
# totales_desc: 0.0
# url: https://www.lamudi.com.mx//detalle/41032-73-dec2ffad4e4a-462f-8845403-852f-434d
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Registro 203:
# metros_total: 105
# totales_desc: 0.0
# url: https://www.lamudi.com.mx/detalle/41032-73-87727839c13b-d626-d8c3bf42-97f1-4797
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Registro 296:
# metros_total: 515
# totales_desc: 0.0
# url: https://www.lamudi.com.mx//detalle/41032-73-1c7dc44ada99-84a3-aa369ef8-9f5e-49f3
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# C:\Users\yoe11\AppData\Local\Temp\ipykernel_20860\929714313.py:24: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '515.18' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.at[idx, 'metros_total'] = new_value
# ---
#
# Registro 329:
# metros_total: 155
# totales_desc: 0.0
# url: https://www.lamudi.com.mx//detalle/41032-73-4c63706e247b-9f0e-ed6c285f-88f9-4599
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Registro 386:
# metros_total: 204
# totales_desc: 0.0
# url: https://www.lamudi.com.mx/detalle/41032-73-baa68ede8f38-2abd-645b23fe-b4e6-418f
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Registro 394:
# metros_total: 79
# totales_desc: 57.66
# url: https://www.lamudi.com.mx//detalle/41032-73-e9436a301644-a2b2-72eab11c-a413-3f7a
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Registro 497:
# metros_total: 70
# totales_desc: 7000.0
# url: https://www.lamudi.com.mx//detalle/41032-73-7610fa19e614-db8f-ad5c8b55-adb9-48aa
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Registro 500:
# metros_total: 75
# totales_desc: 7000.0
# url: https://www.lamudi.com.mx//detalle/41032-73-13b132a1de42-3bfa-376fc860-ab14-438e
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Registro 504:
# metros_total: 110
# totales_desc: 0.0
# url: https://www.lamudi.com.mx//detalle/41032-73-44ae6beea308-638f-c404249a-a36b-4820
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Registro 548:
# metros_total: 84
# totales_desc: 84.57
# url: https://www.lamudi.com.mx//detalle/41032-73-2c20ed0bf325-ec8a-1f7e0f54-841c-37c1
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 560:
# metros_total: 108
# totales_desc: 96.0
# url: https://www.lamudi.com.mx//detalle/41032-73-4bb9280c646d-55fe-bcbcab91-bbbd-3138
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 593:
# metros_total: 123
# totales_desc: 0.0
# url: https://www.lamudi.com.mx/detalle/41032-73-85bc36bf8eaf-6efb-327a921b-859e-4c09
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 727:
# metros_total: 81
# totales_desc: 4.5
# url: https://www.lamudi.com.mx//detalle/41032-73-4f5e2ff28299-6910-1639212-b80c-3b14
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Registro 849:
# metros_total: 200
# totales_desc: 14.0
# url: https://www.lamudi.com.mx/detalle/41032-73-9a66a6c61eb4-78df-71c0c7b7-bc27-3f1c
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Registro 865:
# metros_total: 85
# totales_desc: 85.8
# url: https://www.lamudi.com.mx/detalle/41032-73-b56f96c0511a-c34-d92735bc-a2b1-370e
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Registro 866:
# metros_total: 85
# totales_desc: 85.8
# url: https://www.lamudi.com.mx/detalle/41032-73-b56f96c0511a-c34-d92735bc-a2b1-370e
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Registro 971:
# metros_total: 90
# totales_desc: 3.0
# url: https://www.lamudi.com.mx//detalle/41032-73-ad9c1e3d83dd-7472-3493cfdb-b63f-3130
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Registro 1138:
# metros_total: 92
# totales_desc: 92.17
# url: https://www.lamudi.com.mx//detalle/41032-73-6854840e0ad3-62e1-347d69a0-9bf5-376f
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 1139:
# metros_total: 116
# totales_desc: 1000.0
# url: https://www.lamudi.com.mx/detalle/41032-73-f6afa08c86fd-4a98-bd8014c2-9724-42b3
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Registro 1225:
# metros_total: 112
# totales_desc: 3.0
# url: https://www.lamudi.com.mx//detalle/41032-73-60157012624-7ab5-83e73bb0-8fef-34dc
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Registro 1236:
# metros_total: 108
# totales_desc: 126.0
# url: https://www.lamudi.com.mx//detalle/41032-73-c03858657015-ac9c-9254e96-ac92-33d5
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 1269:
# metros_total: 120
# totales_desc: 2.0
# url: https://www.lamudi.com.mx//detalle/41032-73-c03ef5b36766-b9a1-34c8d70c-a001-373a
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Registro 1284:
# metros_total: 108
# totales_desc: 151.0
# url: https://www.lamudi.com.mx//detalle/41032-73-d8c43e084e87-cd93-8321a7a8-83ad-38c5
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Registro 1293:
# metros_total: 105
# totales_desc: 15.0
# url: https://www.lamudi.com.mx/detalle/41032-73-98657fa95fe1-5ebb-c94a7aac-abf1-3a73
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Registro 1357:
# metros_total: 228
# totales_desc: 1.4
# url: https://www.lamudi.com.mx//detalle/41032-73-9404db2d5840-3bb1-d38f8af9-99d6-31bc
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Registro 1415:
# metros_total: 162
# totales_desc: 100.0
# url: https://www.lamudi.com.mx//detalle/41032-73-135ce93a6014-629c-ef65ae59-af12-1237
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 1459:
# metros_total: 149
# totales_desc: 48.0
# url: https://www.lamudi.com.mx//detalle/41032-73-189256eac1a4-cb12-b121527e-a475-4147
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Registro 1460:
# metros_total: 149
# totales_desc: 48.0
# url: https://www.lamudi.com.mx//detalle/41032-73-b8a0d091da41-95e6-e1121bd-9014-448c
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Registro 1462:
# metros_total: 148
# totales_desc: 9.0
# url: https://www.lamudi.com.mx//detalle/41032-73-317b358800d4-dbbf-b42e6154-8677-363c
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Registro 1518:
# metros_total: 137
# totales_desc: 1.0
# url: https://www.lamudi.com.mx//detalle/41032-73-7a76709e66eb-fd73-677aefad-8cc8-3a9b
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Registro 1527:
# metros_total: 136
# totales_desc: 1.0
# url: https://www.lamudi.com.mx//detalle/41032-73-2062f960d803-a8b3-cffc5e3d-bdc2-34d1
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Registro 1567:
# metros_total: 131
# totales_desc: 800.0
# url: https://www.lamudi.com.mx//detalle/41032-73-7da6d8e62886-9dc4-66ea5ad7-a7ae-371e
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Registro 1619:
# metros_total: 125
# totales_desc: 2000.0
# url: https://www.lamudi.com.mx//detalle/41032-73-56c01f75c9b6-266a-58bdb1c6-9364-383f
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Registro 1621:
# metros_total: 125
# totales_desc: 2000.0
# url: https://www.lamudi.com.mx//detalle/41032-73-b15eff4db62e-52a3-6626ee20-8591-380f
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Registro 1657:
# metros_total: 120
# totales_desc: 8.0
# url: https://www.lamudi.com.mx//detalle/41032-73-866b48abeeeb-f66f-46690bd4-ad59-3ec4
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Registro 1787:
# metros_total: 108
# totales_desc: 1.0
# url: https://www.lamudi.com.mx//detalle/41032-73-b06cd1f11ce4-ca1c-d0f6c3b0-9853-384d
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Registro 1797:
# metros_total: 108
# totales_desc: 58.0
# url: https://www.lamudi.com.mx//detalle/41032-73-91ebe2fdee90-4fab-89d9d204-8620-44ca
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Registro 1832:
# metros_total: 106
# totales_desc: 100.0
# url: https://www.lamudi.com.mx//detalle/41032-73-daed79ba71d-bf2f-2e652da3-9fbb-31ee
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Registro 1963:
# metros_total: 99
# totales_desc: 25.0
# url: https://www.lamudi.com.mx//detalle/41032-73-24edf246bc1d-c860-35c99ad5-bb8a-374d
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 2140:
# metros_total: 81
# totales_desc: 80.0
# url: https://www.lamudi.com.mx//detalle/41032-73-a4d00471e718-407e-bbfd9dfd-a00e-3491
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Registro 2194:
# metros_total: 55
# totales_desc: 2.6
# url: https://www.lamudi.com.mx//detalle/41032-73-eb329778052f-142b-79bfc16e-b75e-32a3
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Registro 2206:
# metros_total: 76
# totales_desc: 3763.0
# url: https://www.lamudi.com.mx//detalle/41032-73-fc6537da3677-f311-3a16031e-9365-3ce4
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Registro 2215:
# metros_total: 84
# totales_desc: 83.0
# url: https://www.lamudi.com.mx//detalle/41032-73-ca388512fc37-3453-f17afa51-8821-3f92
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Registro 2331:
# metros_total: 106
# totales_desc: 2.0
# url: https://www.lamudi.com.mx/detalle/41032-73-31081d712410-f5bf-287b19ed-9809-3603
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Registro 2336:
# metros_total: 106
# totales_desc: 1200.0
# url: https://www.lamudi.com.mx//detalle/41032-73-5f854602ec57-95ba-c98ff660-828a-3abc
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Registro 2339:
# metros_total: 108
# totales_desc: 142.0
# url: https://www.lamudi.com.mx//detalle/41032-73-70557acf613d-23f0-7eb8b0d2-88cf-46bf
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Registro 2340:
# metros_total: 108
# totales_desc: 142.0
# url: https://www.lamudi.com.mx//detalle/41032-73-d00ca5ac0a39-8297-d97d872f-8b73-4a24
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Registro 2341:
# metros_total: 108
# totales_desc: 142.0
# url: https://www.lamudi.com.mx//detalle/41032-73-71bde0d9803a-825a-40827097-a743-4585
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Registro 2342:
# metros_total: 108
# totales_desc: 142.0
# url: https://www.lamudi.com.mx/detalle/41032-73-cb244c796ce5-a23-4d2f1f64-a8d1-4d0e
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Registro 2423:
# metros_total: 110
# totales_desc: 15.0
# url: https://www.lamudi.com.mx//detalle/41032-73-11de46cac4a5-5c3f-6b07b641-9634-3ab6
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Registro 2479:
# metros_total: 115
# totales_desc: 127.0
# url: https://www.lamudi.com.mx/detalle/41032-73-80c5a4a8b92b-6f6a-9d1ad132-bde4-360f
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Registro 2493:
# metros_total: 117
# totales_desc: 26.0
# url: https://www.lamudi.com.mx//detalle/41032-73-f16b4dfcc175-984b-fa8cc7b7-bd09-3fa4
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Registro 2564:
# metros_total: 123
# totales_desc: 247.0
# url: https://www.lamudi.com.mx//detalle/41032-73-575917c2c1d2-9a24-594853b7-ac5b-4e54
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Registro 2710:
# metros_total: 128
# totales_desc: 8.0
# url: https://www.lamudi.com.mx//detalle/41032-73-a06e12958d21-f088-4ecdafd2-b47f-3141
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Registro 2799:
# metros_total: 130
# totales_desc: 145.0
# url: https://www.lamudi.com.mx//detalle/41032-73-1156c02262a0-1d4-60679939-82be-3afe
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Registro 2807:
# metros_total: 131
# totales_desc: 145.0
# url: https://www.lamudi.com.mx//detalle/41032-73-8929f6a59b1b-b959-41f006d7-b3e5-3bae
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Registro 2923:
# metros_total: 140
# totales_desc: 152.64
# url: https://www.lamudi.com.mx//detalle/41032-73-314fd6652b7c-9fa4-d9077b3e-8e4c-3bbb
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Registro 2943:
# metros_total: 140
# totales_desc: 500.0
# url: https://www.lamudi.com.mx//detalle/41032-73-3af923b4322-ca03-f6e58989-9bef-1f51
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Registro 2963:
# metros_total: 143
# totales_desc: 800.0
# url: https://www.lamudi.com.mx//detalle/41032-73-4f41e02315b9-19e8-29f58cf1-93de-3ffe
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Registro 2969:
# metros_total: 144
# totales_desc: 27.0
# url: https://www.lamudi.com.mx//detalle/41032-73-a121d68dbb91-f47-69a9ccd8-bdd6-42a8
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Registro 3010:
# metros_total: 144
# totales_desc: 2.0
# url: https://www.lamudi.com.mx/detalle/41032-73-d47e9a1ffdd4-8971-7680443a-b19d-3f8b
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Registro 3011:
# metros_total: 144
# totales_desc: 2.0
# url: https://www.lamudi.com.mx/detalle/41032-73-941dc75e0fc7-729e-153b7562-8e20-3976
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Registro 3075:
# metros_total: 149
# totales_desc: 2.0
# url: https://www.lamudi.com.mx/detalle/41032-73-cbacb612381e-5e9c-f5f4d7ac-af6c-3a1e
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Registro 3076:
# metros_total: 149
# totales_desc: 2.0
# url: https://www.lamudi.com.mx/detalle/41032-73-2505d711ab2a-94e2-bee8e20e-88aa-3134
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Registro 3414:
# metros_total: 180
# totales_desc: 54.0
# url: https://www.lamudi.com.mx//detalle/41032-73-581ed66fbce8-63d6-258e5e1f-b144-37a7
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Registro 3466:
# metros_total: 187
# totales_desc: 4.0
# url: https://www.lamudi.com.mx/detalle/41032-73-cbfe70625468-2881-bd2ca789-8309-1f7c
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Registro 3496:
# metros_total: 190
# totales_desc: 228.0
# url: https://www.lamudi.com.mx//detalle/41032-73-636b6814f3cd-4a2a-e9ffa27c-a679-3310
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Registro 3524:
# metros_total: 195
# totales_desc: 50.0
# url: https://www.lamudi.com.mx//detalle/41032-73-9c0dbff1571d-7b6b-ae7c8d44-98f7-3fed
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Registro 3525:
# metros_total: 195
# totales_desc: 50.0
# url: https://www.lamudi.com.mx//detalle/41032-73-2ee22c87e026-332b-635fd57c-9e50-331b
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Registro 3529:
# metros_total: 197
# totales_desc: 151.0
# url: https://www.lamudi.com.mx//detalle/41032-73-3c5f35560b0e-1178-fbacc09d-ae1a-366d
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Registro 3574:
# metros_total: 202
# totales_desc: 2202.0
# url: https://www.lamudi.com.mx//detalle/41032-73-dd15c75147cf-12f2-441b599a-84e8-3cdf
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 3635:
# metros_total: 232
# totales_desc: 150.0
# url: https://www.lamudi.com.mx//detalle/41032-73-323b9dc1447f-814b-d8bba3f9-8121-34ac
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 3772:
# metros_total: 360
# totales_desc: 2.0
# url: https://www.lamudi.com.mx/detalle/41032-73-4529c4d7b212-9c16-74d23ab0-a04e-33d3
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 3796:
# metros_total: 350
# totales_desc: 60.0
# url: https://www.lamudi.com.mx//detalle/41032-73-ea71c251131-db14-131de7e7-896b-3890
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 3812:
# metros_total: 339
# totales_desc: 340.0
# url: https://www.lamudi.com.mx//detalle/41032-73-3193db047088-e781-48e6c65-b512-4db4
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 3903:
# metros_total: 313
# totales_desc: 80.0
# url: https://www.lamudi.com.mx/detalle/41032-73-6f316d2d2a05-2420-703e0b6f-a7c6-3e2d
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 3918:
# metros_total: 310
# totales_desc: 3.0
# url: https://www.lamudi.com.mx//detalle/41032-73-94b0364b7a6a-664f-3334c80-b840-3336
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 3936:
# metros_total: 307
# totales_desc: 6.0
# url: https://www.lamudi.com.mx//detalle/41032-73-d3e6711d9c63-f399-ac4ef5f1-9d5f-3fec
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 3978:
# metros_total: 300
# totales_desc: 2.0
# url: https://www.lamudi.com.mx/detalle/41032-73-350e7de5299d-21cf-91339b10-a5ee-36c1
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 4036:
# metros_total: 300
# totales_desc: 2.6
# url: https://www.lamudi.com.mx//detalle/41032-73-7134858725cc-5602-de96a793-9126-4b0e
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 4113:
# metros_total: 295
# totales_desc: 6.0
# url: https://www.lamudi.com.mx/detalle/41032-73-d3e6711d9c63-f399-ac4ef5f1-9d5f-3fec
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 4126:
# metros_total: 292
# totales_desc: 150.0
# url: https://www.lamudi.com.mx//detalle/41032-73-8103ec383820-3b08-fbe514cd-b39f-3abd
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 4152:
# metros_total: 290
# totales_desc: 50.0
# url: https://www.lamudi.com.mx//detalle/41032-73-33ee97d4902d-1bdf-eaf6d990-9d52-360f
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 4181:
# metros_total: 285
# totales_desc: 6.0
# url: https://www.lamudi.com.mx//detalle/41032-73-3203f371a1ff-c104-ee2388ab-a68b-39a9
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 4363:
# metros_total: 270
# totales_desc: 3.0
# url: https://www.lamudi.com.mx/detalle/41032-73-be3cbce48b73-2dd8-c5a10b4f-8895-3dae
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 4445:
# metros_total: 260
# totales_desc: 200.0
# url: https://www.lamudi.com.mx//detalle/41032-73-64131975ed1c-d877-a97f86e7-b448-4607
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 4452:
# metros_total: 260
# totales_desc: 180.0
# url: https://www.lamudi.com.mx//detalle/41032-73-e2e4d1e80b53-9352-80fc4b5e-b155-4d64
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 4480:
# metros_total: 257
# totales_desc: 310.0
# url: https://www.lamudi.com.mx/detalle/41032-73-96aec569427e-be16-13bacb47-b93f-329a
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 4503:
# metros_total: 256
# totales_desc: 300.0
# url: https://www.lamudi.com.mx/detalle/41032-73-99f83a4ccc57-5659-3648b8dd-88fc-4a4e
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 4514:
# metros_total: 255
# totales_desc: 300.0
# url: https://www.lamudi.com.mx/detalle/41032-73-30efa41c60a0-dcfb-64c88b15-b327-4b3e
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 4515:
# metros_total: 255
# totales_desc: 300.0
# url: https://www.lamudi.com.mx/detalle/41032-73-c9795684c7ef-ca52-7a88a6b6-a16f-3291
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 4545:
# metros_total: 253
# totales_desc: 219.0
# url: https://www.lamudi.com.mx//detalle/41032-73-1a1e6b14a3f7-695c-8db3ba44-a1c8-3382
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 4658:
# metros_total: 250
# totales_desc: 180.0
# url: https://www.lamudi.com.mx//detalle/41032-73-177be7bb2734-a7ff-6834a5fe-8e93-3dc5
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 4660:
# metros_total: 250
# totales_desc: 20.0
# url: https://www.lamudi.com.mx//detalle/41032-73-9a0fcbb1ffb8-bc83-138d94c3-8c8e-44b9
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 4684:
# metros_total: 250
# totales_desc: 213.0
# url: https://www.lamudi.com.mx/detalle/41032-73-fd7bbc23b4d6-266f-86ec1efd-87bf-3fc7
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 4708:
# metros_total: 250
# totales_desc: 12.0
# url: https://www.lamudi.com.mx//detalle/41032-73-2d4f28e8d1e9-4b3b-f4e04ed1-a38e-311f
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 4773:
# metros_total: 250
# totales_desc: 80.0
# url: https://www.lamudi.com.mx//detalle/41032-73-1f7bc2224b29-1dec-1927917e-acb0-37d5
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 4777:
# metros_total: 250
# totales_desc: 1350.0
# url: https://www.lamudi.com.mx/detalle/41032-73-18eeec6f41fa-4dfa-9a8b9c18-be96-3086
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 4781:
# metros_total: 250
# totales_desc: 12.0
# url: https://www.lamudi.com.mx//detalle/41032-73-e3a0f451ffcd-d30a-62a183a5-83b4-4ad7
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 4799:
# metros_total: 250
# totales_desc: 20.0
# url: https://www.lamudi.com.mx//detalle/41032-73-424a3fe85d38-87d-be3f1378-bd45-453a
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 4872:
# metros_total: 242
# totales_desc: 2.0
# url: https://www.lamudi.com.mx/detalle/41032-73-740790997003-d6c2-dd0f1e41-9d66-3285
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 4972:
# metros_total: 231
# totales_desc: 0.0
# url: https://www.lamudi.com.mx/detalle/41032-73-30ae0b656ed9-10c5-a9e5276-8975-4528
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 5052:
# metros_total: 220
# totales_desc: 2.0
# url: https://www.lamudi.com.mx//detalle/41032-73-7b084dc54904-e8b0-904a273-8b16-3ba6
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 5112:
# metros_total: 216
# totales_desc: 0.0
# url: https://www.lamudi.com.mx/detalle/41032-73-f0c5c8da00c8-b8ed-67b6b41b-a152-450f
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 5119:
# metros_total: 215
# totales_desc: 3.8
# url: https://www.lamudi.com.mx/detalle/41032-73-f4b01f755545-aa0d-5a5bef84-a121-3457
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 5120:
# metros_total: 215
# totales_desc: 3.8
# url: https://www.lamudi.com.mx/detalle/41032-73-dd2349423dbd-c042-5a5feae6-b9e5-386b
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 5121:
# metros_total: 215
# totales_desc: 3.8
# url: https://www.lamudi.com.mx/detalle/41032-73-bab9ad777c49-45e1-c5ad2362-84e3-3da0
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 5185:
# metros_total: 210
# totales_desc: 0.0
# url: https://www.lamudi.com.mx//detalle/41032-73-f0c5c8da00c8-b8ed-67b6b41b-a152-450f
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 5232:
# metros_total: 205
# totales_desc: 8500.0
# url: https://www.lamudi.com.mx//detalle/41032-73-b7cbbbdf0ecc-d007-524b3429-bc1d-3511
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 5245:
# metros_total: 203
# totales_desc: 382.0
# url: https://www.lamudi.com.mx//detalle/41032-73-103d5c7d42ad-ea95-2c857a09-af80-3ecb
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 5246:
# metros_total: 203
# totales_desc: 382.0
# url: https://www.lamudi.com.mx//detalle/41032-73-a34b3ffcd4a-d032-b47fb59d-9d4d-3317
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 5349:
# metros_total: 200
# totales_desc: 9.0
# url: https://www.lamudi.com.mx//detalle/41032-73-cad0a4c2330f-63a6-1b7f2631-a539-41e0
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 5450:
# metros_total: 190
# totales_desc: 317.0
# url: https://www.lamudi.com.mx//detalle/41032-73-7f3441f0fb3b-d6ac-ee055352-9eec-35ad
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 5504:
# metros_total: 185
# totales_desc: 3500.0
# url: https://www.lamudi.com.mx//detalle/41032-73-51e88412c61c-f667-2a88f6f6-9d00-3957
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 5505:
# metros_total: 185
# totales_desc: 3500.0
# url: https://www.lamudi.com.mx//detalle/41032-73-7af5b73f701f-117-455609d1-8ffb-3ab6
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 5578:
# metros_total: 183
# totales_desc: 100.0
# url: https://www.lamudi.com.mx//detalle/41032-73-687834c4f80f-bb6b-ab828764-ad88-3b32
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 5580:
# metros_total: 183
# totales_desc: 70.0
# url: https://www.lamudi.com.mx//detalle/41032-73-431e42fc2e5a-8939-dea2c8c9-89f4-3b68
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 5655:
# metros_total: 180
# totales_desc: 238.0
# url: https://www.lamudi.com.mx//detalle/41032-73-b105a54b8040-fdb1-3557f828-87c5-35d5
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 5694:
# metros_total: 180
# totales_desc: 2.0
# url: https://www.lamudi.com.mx//detalle/41032-73-b3f0b2b7bc3b-35d1-91127bcd-ab8d-3510
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 5717:
# metros_total: 180
# totales_desc: 4.2
# url: https://www.lamudi.com.mx//detalle/41032-73-8811ac9ae66f-c754-7ae038f3-86ff-3452
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 5718:
# metros_total: 180
# totales_desc: 4.2
# url: https://www.lamudi.com.mx//detalle/41032-73-fee01b936234-20eb-6181a093-a20b-3294
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 5847:
# metros_total: 175
# totales_desc: 251.0
# url: https://www.lamudi.com.mx//detalle/41032-73-533db3cdc36e-5f44-82d15691-ab32-3edc
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 5887:
# metros_total: 172
# totales_desc: 35.0
# url: https://www.lamudi.com.mx//detalle/41032-73-e332c2ba47ed-d517-6a476d1d-bf91-3808
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 5905:
# metros_total: 171
# totales_desc: 178.0
# url: https://www.lamudi.com.mx//detalle/41032-73-fc32586e1f6f-8a8e-271f00cb-b100-3bc7
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 5911:
# metros_total: 170
# totales_desc: 2.0
# url: https://www.lamudi.com.mx/detalle/41032-73-ce1702de0280-6af7-566ab9b-bc1c-3d85
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 5915:
# metros_total: 170
# totales_desc: 178.0
# url: https://www.lamudi.com.mx//detalle/41032-73-5586ff57edad-297e-702fb364-8f65-35f8
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 5942:
# metros_total: 166
# totales_desc: 25.0
# url: https://www.lamudi.com.mx//detalle/41032-73-f20cb1f0c6ba-e8f1-a69ac5fe-bceb-3262
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 5976:
# metros_total: 163
# totales_desc: 181.0
# url: https://www.lamudi.com.mx/detalle/41032-73-728d06584133-919a-df06874-9ea1-5030
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 5993:
# metros_total: 162
# totales_desc: 25.0
# url: https://www.lamudi.com.mx/detalle/41032-73-c17beab252c8-e08e-a5105c3a-a8fa-3628
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 5999:
# metros_total: 162
# totales_desc: 3700.0
# url: https://www.lamudi.com.mx//detalle/41032-73-a61cd62d5d0e-6b5c-c2a903a7-8ec7-4a28
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 6030:
# metros_total: 161
# totales_desc: 2.0
# url: https://www.lamudi.com.mx//detalle/41032-73-8ec47b32b6f5-9f53-685b6ebd-9648-3f2a
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 6080:
# metros_total: 160
# totales_desc: 3763.0
# url: https://www.lamudi.com.mx//detalle/41032-73-5a5c5c2da2b8-bfc4-421f72c1-b2d9-400c
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 6086:
# metros_total: 160
# totales_desc: 145.0
# url: https://www.lamudi.com.mx//detalle/41032-73-f73bb2b3dff9-4c1b-fe594047-901b-3388
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 6090:
# metros_total: 160
# totales_desc: 90.0
# url: https://www.lamudi.com.mx/detalle/41032-73-bc490a56b95b-c50a-ff82a88d-9d57-340e
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 6197:
# metros_total: 152
# totales_desc: 2.0
# url: https://www.lamudi.com.mx//detalle/41032-73-379bd566188d-ab89-737bc08a-a92b-36be
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 6210:
# metros_total: 151
# totales_desc: 128.0
# url: https://www.lamudi.com.mx//detalle/41032-73-258ba89dc0fc-82cd-1c9a335d-b98e-3dcf
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 6257:
# metros_total: 147
# totales_desc: 124.0
# url: https://www.lamudi.com.mx//detalle/41032-73-2acf80032a46-88bb-692280a2-850f-35c0
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 6275:
# metros_total: 145
# totales_desc: 3763.0
# url: https://www.lamudi.com.mx//detalle/41032-73-32b92346f1cc-ad60-e20fc084-a3d5-3578
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 6347:
# metros_total: 140
# totales_desc: 139.0
# url: https://www.lamudi.com.mx//detalle/41032-73-f8ea96e2fdf4-3563-8446956f-abc0-3103
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 6442:
# metros_total: 128
# totales_desc: 10.0
# url: https://www.lamudi.com.mx/detalle/41032-73-68f9d07b439c-bc58-200eee63-9419-3b57
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 6459:
# metros_total: 126
# totales_desc: 65.0
# url: https://www.lamudi.com.mx//detalle/41032-73-33d96b083443-2f60-2e059c68-a15c-43cb
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 6475:
# metros_total: 123
# totales_desc: 2.0
# url: https://www.lamudi.com.mx//detalle/41032-73-a24b95f3d110-ab36-bab754b0-9986-38c8
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# ...
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 8163:
# metros_total: 250
# totales_desc: 3.5
# url: https://www.lamudi.com.mx//detalle/41032-73-191d4c27c3fd-376-5589af69-9345-32b9
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 8174:
# metros_total: 265
# totales_desc: 60.0
# url: https://www.lamudi.com.mx//detalle/41032-73-e8797bf25a0b-859-1f97e5fa-9c43-33f7
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 8287:
# metros_total: 203
# totales_desc: 4.5
# url: https://www.lamudi.com.mx//detalle/41032-73-e2bff320fb6c-f1ca-fa97393a-a391-372b
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 8288:
# metros_total: 203
# totales_desc: 4.5
# url: https://www.lamudi.com.mx//detalle/41032-73-486785655948-aed0-e4cc1d85-9df3-3e91
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 8289:
# metros_total: 203
# totales_desc: 4.5
# url: https://www.lamudi.com.mx//detalle/41032-73-fe70385a37a0-22e2-68a980ae-b007-30cf
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 8306:
# metros_total: 1000
# totales_desc: 700.0
# url: https://www.lamudi.com.mx/detalle/41032-73-ed237a73e8a4-3911-8ae5fdee-a596-3bfb
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 8374:
# metros_total: 570
# totales_desc: 4.0
# url: https://www.lamudi.com.mx/detalle/41032-73-7abf2eaad318-6aee-61b1e92a-a0e4-3e2e
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 8392:
# metros_total: 318
# totales_desc: 310.0
# url: https://www.lamudi.com.mx//detalle/41032-73-1849dc775cb7-6b40-30927e1c-8b80-3c04
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 8426:
# metros_total: 243
# totales_desc: 10.0
# url: https://www.lamudi.com.mx/detalle/41032-73-c5ca7ceaa923-8533-b1f76663-be36-4dac
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 8453:
# metros_total: 280
# totales_desc: 80.0
# url: https://www.lamudi.com.mx//detalle/41032-73-6f316d2d2a05-2420-703e0b6f-a7c6-3e2d
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 8462:
# metros_total: 250
# totales_desc: 80.0
# url: https://www.lamudi.com.mx//detalle/41032-73-c91e67707ac-47af-fb366b8a-a502-364e
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 8506:
# metros_total: 412
# totales_desc: 160.0
# url: https://www.lamudi.com.mx//detalle/41032-73-27674f1925d0-5637-59fe6f1c-8466-4934
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 8507:
# metros_total: 412
# totales_desc: 160.0
# url: https://www.lamudi.com.mx//detalle/41032-73-5ca65f436c5-72f7-49034dde-81d3-47dd
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 8535:
# metros_total: 490
# totales_desc: 2.0
# url: https://www.lamudi.com.mx/detalle/41032-73-aa194886df75-eed-28b46bc3-81c0-312a
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 8554:
# metros_total: 315
# totales_desc: 7.0
# url: https://www.lamudi.com.mx//detalle/41032-73-ef6bab30627-27dc-bdbbd3a3-8917-3975
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 8555:
# metros_total: 315
# totales_desc: 7.0
# url: https://www.lamudi.com.mx//detalle/41032-73-6a835f78426a-48cf-2a7a76ef-bf4d-3d8b
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 8556:
# metros_total: 315
# totales_desc: 7.0
# url: https://www.lamudi.com.mx/detalle/41032-73-ef6bab30627-27dc-bdbbd3a3-8917-3975
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 8557:
# metros_total: 315
# totales_desc: 7.0
# url: https://www.lamudi.com.mx/detalle/41032-73-6a835f78426a-48cf-2a7a76ef-bf4d-3d8b
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 8569:
# metros_total: 300
# totales_desc: 2.0
# url: https://www.lamudi.com.mx/detalle/41032-73-31f1fdac30d-6a3c-cc074da9-ad7b-32ae
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 8570:
# metros_total: 300
# totales_desc: 2.0
# url: https://www.lamudi.com.mx/detalle/41032-73-39fd3a5cbd50-2f13-78f5c35b-b5af-3c4b
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 8571:
# metros_total: 350
# totales_desc: 2.0
# url: https://www.lamudi.com.mx/detalle/41032-73-a7ffb962649b-e982-923a395f-8842-33f0
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 8588:
# metros_total: 303
# totales_desc: 2.7
# url: https://www.lamudi.com.mx//detalle/41032-73-cddf9d2449d1-64a5-76e6a54a-8b84-339c
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 8589:
# metros_total: 333
# totales_desc: 2.0
# url: https://www.lamudi.com.mx/detalle/41032-73-25800aa56633-cfa8-5adb3276-b70a-3b46
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 8590:
# metros_total: 333
# totales_desc: 2.0
# url: https://www.lamudi.com.mx/detalle/41032-73-229ed9a83179-1812-b61a21b6-8d0e-3960
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 8604:
# metros_total: 468
# totales_desc: 468.3
# url: https://www.lamudi.com.mx//detalle/41032-73-7f52f4d8832d-1868-62f46ae9-80f7-3b30
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 8636:
# metros_total: 323
# totales_desc: 100.0
# url: https://www.lamudi.com.mx//detalle/41032-73-26ebbe3dfadd-81df-2619aec3-887c-433d
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 8637:
# metros_total: 323
# totales_desc: 100.0
# url: https://www.lamudi.com.mx/detalle/41032-73-26ebbe3dfadd-81df-2619aec3-887c-433d
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 8648:
# metros_total: 323
# totales_desc: 21.0
# url: https://www.lamudi.com.mx//detalle/41032-73-85c7d74602d1-2315-beb1a177-8c0a-39e0
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 8649:
# metros_total: 323
# totales_desc: 100.0
# url: https://www.lamudi.com.mx//detalle/41032-73-5a1cd9b556e0-b7c-9fc54bcf-9319-4933
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 8650:
# metros_total: 323
# totales_desc: 100.0
# url: https://www.lamudi.com.mx//detalle/41032-73-a82b2a18607d-f8c9-166b91b9-9f7c-5006
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 8651:
# metros_total: 323
# totales_desc: 21.0
# url: https://www.lamudi.com.mx/detalle/41032-73-85c7d74602d1-2315-beb1a177-8c0a-39e0
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 8652:
# metros_total: 323
# totales_desc: 100.0
# url: https://www.lamudi.com.mx/detalle/41032-73-5a1cd9b556e0-b7c-9fc54bcf-9319-4933
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 8653:
# metros_total: 323
# totales_desc: 100.0
# url: https://www.lamudi.com.mx/detalle/41032-73-a82b2a18607d-f8c9-166b91b9-9f7c-5006
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 8669:
# metros_total: 250
# totales_desc: 3.0
# url: https://www.lamudi.com.mx//detalle/41032-73-22a072ae1235-6277-fe821f79-b9ea-393e
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 8780:
# metros_total: 315
# totales_desc: 25.0
# url: https://www.lamudi.com.mx//detalle/41032-73-7d919b7c1446-696a-b4219f4a-9a9e-30b3
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 8851:
# metros_total: 607
# totales_desc: 2.0
# url: https://www.lamudi.com.mx//detalle/41032-73-14e4e8e0390c-1558-530dfe-850d-37fa
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 8891:
# metros_total: 800
# totales_desc: 4.0
# url: https://www.lamudi.com.mx//detalle/41032-73-ffce4d9b79c5-2225-2102ccee-9fc4-39e5
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 8924:
# metros_total: 203
# totales_desc: 6.0
# url: https://www.lamudi.com.mx/detalle/41032-73-b3aacfa8d28-9a77-f716832b-9209-4703
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 9159:
# metros_total: 509
# totales_desc: 2.0
# url: https://www.lamudi.com.mx//detalle/41032-73-31c6b98214f-ff36-34ee4bc8-86a7-314d
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 9160:
# metros_total: 509
# totales_desc: 2.0
# url: https://www.lamudi.com.mx/detalle/41032-73-8db79bc721d8-fcba-4c4fa156-8580-38c5
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 9241:
# metros_total: 160
# totales_desc: 15.0
# url: https://www.lamudi.com.mx//detalle/41032-73-361aa9aa8011-eaa3-ae6bbe84-93f5-4465
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 9261:
# metros_total: 600
# totales_desc: 3.0
# url: https://www.lamudi.com.mx/detalle/41032-73-c01d83032709-b0be-163ab78c-bc64-3e3c
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 9262:
# metros_total: 600
# totales_desc: 3.0
# url: https://www.lamudi.com.mx/detalle/41032-73-22f3400f2875-2a3c-1fba75f8-b3d8-3357
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 9342:
# metros_total: 535
# totales_desc: 60.0
# url: https://www.lamudi.com.mx//detalle/41032-73-ad1150ed5b6-de73-7ad161aa-b0d8-3525
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Proceso completado.

# %% [markdown]
# ## b) Manejo por rangos de UMA

# %% [markdown]
# Paso opcional por si no se espera cambiar el precio por el que se tenga en descripción

# %% [markdown]
# Rangos
# * 118 UMAS = 40m2
# * 118.1-200 = 50m2
# * 200.1-350 = 71m2
# * 350.1-750 = 102m2
# * 750.1-1500 = 156m2

# %% [markdown]
# ### DF cuando ambas columnas son 0 o vacíos

# %%
# Rangos de UMAs y sus equivalencias en m²
umas_to_m2 = [
    (118, 40),
    (200, 50),
    (350, 71),
    (750, 102),
    (1500, 156)
]
valor_uma = 108.57

# Convertir MXN a UMAs
def precio_a_umas(precio, valor_uma):
    return precio / valor_uma

# Asignar m² basado en el precio en UMAs
def asignar_m2(precio_umas):
    for upper_bound, m2 in umas_to_m2:
        if precio_umas <= upper_bound:
            return m2
    return None  # En caso de que el precio en UMAs sea mayor al máximo definido

# Actualizar los registros con 'metros_total' igual a 0 y 'totales_desc' es NaN
def actualizar_metros_total(row):
    if row['metros_total'] == 0 and pd.isna(row['totales_desc']):
        precio_umas = precio_a_umas(row['precio'], valor_uma)
        row['metros_total'] = asignar_m2(precio_umas)
    return row

totales = df[( (df['metros_total'] == 0 ) & (df['totales_desc'].isna() | df['totales_desc']==0) )] 
totales = df.apply(actualizar_metros_total, axis=1)
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

#df = df.apply(actualizar_metros_total, axis=1)
print(totales[['metros_total', 'totales_desc', 'url']])
# Out:
#       metros_total  totales_desc  \
# 6            100.0           NaN
# 13           350.0           NaN
# 18           500.0           NaN
# 31           483.0           NaN
# 37           277.0           NaN
# ...            ...           ...
# 9285         900.0           NaN
# 9317         634.0           NaN
# 9321        1047.0           NaN
# 9327         750.0           NaN
# 9332        1047.0           NaN
#
#                                                                                   url
# 6     https://www.lamudi.com.mx/detalle/41032-73-7470e7c0f69b-8f03-1adcb58d-9a14-405d
# 13    https://www.lamudi.com.mx/detalle/41032-73-bd5a86939b0e-2cb6-83bc8753-80aa-49c5
# 18     https://www.lamudi.com.mx/detalle/41032-73-1db2d29a0f95-16c-34653316-be19-4b01
# 31     https://www.lamudi.com.mx/detalle/41032-73-93d194dc33d-d035-bf07501c-825e-4a4a
# 37    https://www.lamudi.com.mx/detalle/41032-73-27915b7692e9-3bc0-67bbfd01-9453-4608
# ...                                                                               ...
# 9285  https://www.lamudi.com.mx/detalle/41032-73-abcff9f31f91-9b42-df0a9f46-965b-364d
# 9317   https://www.lamudi.com.mx/detalle/41032-73-b3dd7ee02da2-77a-8d0d4cd6-a067-3355
# 9321  https://www.lamudi.com.mx/detalle/41032-73-42a5d7276768-fca6-536261bd-b26e-33af
# 9327   https://www.lamudi.com.mx/detalle/41032-73-2ba25b8df524-7fc-97af003c-aa2f-339c
# 9332  https://www.lamudi.com.mx/detalle/41032-73-125ba1cd9739-e9b5-77b6a502-b769-3fcf
#
# [327 rows x 3 columns]

# %%
# Si se aceptan los cambios:
df = df.apply(actualizar_metros_total, axis=1)

# %% [markdown]
# # 5. M2 construidos

# %% [markdown]
# ## a) M-construidos en descripción

# %%
# Función para extraer totales de la descripción
def extraer_totales(descripcion):
    descripcion = descripcion.lower()
    # Buscar patrones de totales
    totales = re.findall(r'\b(\d+[\.,]?\d*)\s*(metros|construidos)\b', descripcion)
    total = None
    for match in totales:
        numero, _ = match
        numero = numero.replace(',', '').replace("'", '')
        try:
            total = float(numero)
        except ValueError:
            continue
        if total:
            break
    return total

# Aplicar la función al DataFrame
df['construidos_desc'] = df['descripcion'].apply(extraer_totales)

# %% [markdown]
# ### Metros [0 / 0]

# %%
# Filtrar los registros según las condiciones dadas
totales = df[( (df['metros_construido'] == 0 ) & (df['construidos_desc'].isna() | df['construidos_desc']==0) )] 
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# Iterar sobre los registros filtrados
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    print(row[['metros_construido', 'construidos_desc', 'url']])
    print("\n¿Qué acción te gustaría realizar?")
    print("1. Sustituir el valor manualmente")
    print("2. Sustituir el valor de 'metros_construido' por el de 'construidos_desc'")
    print("3. Pasar al siguiente registro")

    # Solicitar la opción al usuario
    option = input("Elige una opción (1, 2, 3): ")

    if option == '1':
        # Sustituir el valor manualmente
        new_value = input("Introduce el nuevo valor para 'metros_construido': ")
        df.at[idx, 'metros_construido'] = float(new_value)
    elif option == '2':
        # Sustituir el valor de 'metros_construido' por 'construidos_desc'
        df.at[idx, 'metros_construido'] = df.at[idx, 'construidos_desc']
    elif option == '3':
        # Pasar al siguiente registro
        continue
    else:
        print("Opción no válida. Pasando al siguiente registro...")
    
    print("\n---\n")

print("Proceso completado.")
# Out:
# Proceso completado.

# %% [markdown]
# ### Metros [0 / #]

# %%
# Filtrar los registros según las condiciones dadas
totales = df[( (df['metros_construido'] == 0 ) & (df['construidos_desc'].notna()) )] 
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# Iterar sobre los registros filtrados
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    print(row[['metros_construido', 'construidos_desc', 'url']])
    print("\n¿Qué acción te gustaría realizar?")
    print("1. Sustituir el valor manualmente")
    print("2. Sustituir el valor de 'metros_construido' por el de 'construidos_desc'")
    print("3. Pasar al siguiente registro")

    # Solicitar la opción al usuario
    option = input("Elige una opción (1, 2, 3): ")

    if option == '1':
        # Sustituir el valor manualmente
        new_value = input("Introduce el nuevo valor para 'metros_construido': ")
        df.at[idx, 'metros_construido'] = float(new_value)
    elif option == '2':
        # Sustituir el valor de 'metros_construido' por 'construidos_desc'
        df.at[idx, 'metros_construido'] = df.at[idx, 'construidos_desc']
    elif option == '3':
        # Pasar al siguiente registro
        continue
    else:
        print("Opción no válida. Pasando al siguiente registro...")
    
    print("\n---\n")

print("Proceso completado.")
# Out:
# Proceso completado.

# %% [markdown]
# ### Metros [# / #]

# %%
# Filtrar los registros según las condiciones dadas
totales = df[( ((df['metros_construido']!= 0) & (df['construidos_desc'].notna())) & (df['metros_construido'] != df['construidos_desc']) )] 
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# Iterar sobre los registros filtrados
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    print(row[['metros_construido', 'construidos_desc', 'url']])
    print("\n¿Qué acción te gustaría realizar?")
    print("1. Sustituir el valor manualmente")
    print("2. Sustituir el valor de 'metros_construido' por el de 'construidos_desc'")
    print("3. Pasar al siguiente registro")

    # Solicitar la opción al usuario
    option = input("Elige una opción (1, 2, 3): ")

    if option == '1':
        # Sustituir el valor manualmente
        new_value = input("Introduce el nuevo valor para 'metros_construido': ")
        try:
            df.at[idx, 'metros_construido'] = float(new_value)
        except ValueError:
            print("Valor no válido. Debe ser un número. Pasando al siguiente registro...")
    elif option == '2':
        # Sustituir el valor de 'metros_construido' por 'construidos_desc'
        df.at[idx, 'metros_construido'] = df.at[idx, 'construidos_desc']
    elif option == '3':
        # Pasar al siguiente registro
        continue
    else:
        print("Opción no válida. Pasando al siguiente registro...")
    
    print("\n---\n")

print("Proceso completado.")
# Out:
# Registro 593:
# metros_construido                                                                                123
# construidos_desc                                                                                 0.0
# url                  https://www.lamudi.com.mx/detalle/41032-73-85bc36bf8eaf-6efb-327a921b-859e-4c09
# Name: 593, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_construido' por el de 'construidos_desc'
# 3. Pasar al siguiente registro
# Registro 849:
# metros_construido                                                                                200
# construidos_desc                                                                                14.0
# url                  https://www.lamudi.com.mx/detalle/41032-73-9a66a6c61eb4-78df-71c0c7b7-bc27-3f1c
# Name: 849, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_construido' por el de 'construidos_desc'
# 3. Pasar al siguiente registro
# Registro 866:
# metros_construido                                                                                85
# construidos_desc                                                                               85.8
# url                  https://www.lamudi.com.mx/detalle/41032-73-b56f96c0511a-c34-d92735bc-a2b1-370e
# Name: 866, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_construido' por el de 'construidos_desc'
# 3. Pasar al siguiente registro
# Registro 1293:
# metros_construido                                                                                114
# construidos_desc                                                                                15.0
# url                  https://www.lamudi.com.mx/detalle/41032-73-98657fa95fe1-5ebb-c94a7aac-abf1-3a73
# Name: 1293, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_construido' por el de 'construidos_desc'
# 3. Pasar al siguiente registro
# Registro 2347:
# metros_construido                                                                                133
# construidos_desc                                                                               108.0
# url                  https://www.lamudi.com.mx/detalle/41032-73-ab676eaa234c-9a31-e1cb029a-869a-3106
# Name: 2347, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_construido' por el de 'construidos_desc'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 2350:
# metros_construido                                                                                133
# construidos_desc                                                                               108.0
# url                  https://www.lamudi.com.mx/detalle/41032-73-e3dfc2fea653-9763-ac93dc96-af2d-3b79
# Name: 2350, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_construido' por el de 'construidos_desc'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 5119:
# metros_construido                                                                                250
# construidos_desc                                                                                 3.8
# url                  https://www.lamudi.com.mx/detalle/41032-73-f4b01f755545-aa0d-5a5bef84-a121-3457
# Name: 5119, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_construido' por el de 'construidos_desc'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 5120:
# metros_construido                                                                                250
# construidos_desc                                                                                 3.8
# url                  https://www.lamudi.com.mx/detalle/41032-73-dd2349423dbd-c042-5a5feae6-b9e5-386b
# Name: 5120, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_construido' por el de 'construidos_desc'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 7531:
# metros_construido                                                                                357
# construidos_desc                                                                                 3.0
# url                  https://www.lamudi.com.mx/detalle/41032-73-c1bffd0f8050-c932-75e3d847-a19c-3a33
# Name: 7531, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_construido' por el de 'construidos_desc'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 7633:
# metros_construido                                                                                450
# construidos_desc                                                                               230.0
# url                  https://www.lamudi.com.mx/detalle/41032-73-32136f09e862-3f6b-1ede5903-aa8c-4468
# Name: 7633, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_construido' por el de 'construidos_desc'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 7635:
# metros_construido                                                                                450
# construidos_desc                                                                               230.0
# url                  https://www.lamudi.com.mx/detalle/41032-73-3f39f26c11d7-462c-2c736d7f-a4a3-4d44
# Name: 7635, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_construido' por el de 'construidos_desc'
# 3. Pasar al siguiente registro
# Registro 7836:
# metros_construido                                                                              1000
# construidos_desc                                                                                6.2
# url                  https://www.lamudi.com.mx/detalle/41032-73-1bba0dde0337-5af-4bc07cd5-9b78-3920
# Name: 7836, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_construido' por el de 'construidos_desc'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 7865:
# metros_construido                                                                                361
# construidos_desc                                                                              1000.0
# url                  https://www.lamudi.com.mx/detalle/41032-73-91dcaf260934-461a-e88c5b54-b49d-3b71
# Name: 7865, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_construido' por el de 'construidos_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 7873:
# metros_construido                                                                                456
# construidos_desc                                                                                12.0
# url                  https://www.lamudi.com.mx/detalle/41032-73-62267eff3285-fcfa-9e7eebef-a311-3aa4
# Name: 7873, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_construido' por el de 'construidos_desc'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 7900:
# metros_construido                                                                                411
# construidos_desc                                                                                 4.0
# url                  https://www.lamudi.com.mx/detalle/41032-73-b32e9c979750-6ec8-d5084a2b-bf6b-3f5a
# Name: 7900, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_construido' por el de 'construidos_desc'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 8374:
# metros_construido                                                                               1131
# construidos_desc                                                                                 4.0
# url                  https://www.lamudi.com.mx/detalle/41032-73-7abf2eaad318-6aee-61b1e92a-a0e4-3e2e
# Name: 8374, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'metros_construido' por el de 'construidos_desc'
# 3. Pasar al siguiente registro
#
# ---
#
# Proceso completado.

# %% [markdown]
# # 6. Precio / m2

# %% [markdown]
# ## M2 Totales (terreno)

# %%
# Calcular precio por metro cuadrado del terreno
df['precio_m2_terreno'] = df['precio']/df['metros_total']

# %% [markdown]
# ## M2 Construidos

# %%
# Calcular precio por metro cuadrado de la cosntrucción
df['precio_m2_construido'] = df['precio']/df['metros_construido']

# %% [markdown]
# # 7. Estacionamientos

# %% [markdown]
# ## a) Estacionamientos descritos

# %% [markdown]
# Asigna las diferentes maneras en las que puede encontrarse descrito el espacio de estacionamientos

# %%
# Función para extraer estacionamientos de la descripción
def extraer_coches(descripcion):
    descripcion = descripcion.lower()
    # Buscar patrones de totales
    totales = re.findall(r'\b(\d+[\.,]?\d*)\s*(|cochera|garage|carros|carro|coche|coches|autos|automóviles|automóvil|auto|lugares de estacionamiento)\b', descripcion)
    total = None
    for match in totales:
        numero, _ = match
        numero = numero.replace(',', '').replace("'", '').replace('.','')
        try:
            total = float(numero)
        except ValueError:
            continue
        if total:
            break
    return total

# Aplicar la función al DataFrame
df['estacionamiento_desc'] = df['descripcion'].apply(extraer_coches)

# %% [markdown]
# ### Estacionamientos [0 / 0]

# %%
# Filtrar los registros según las condiciones dadas
totales = df[( (df['estacionamientos']==0) & (df['estacionamiento_desc'].isna()) )] 
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# Iterar sobre los registros filtrados
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    print(row[['url']])
    print("\n¿Qué acción te gustaría realizar?")
    print("1. Sustituir el valor manualmente")
    print("2. Pasar al siguiente registro")

    # Solicitar la opción al usuario
    option = input("Elige una opción (1 | 2): ")

    if option == '1':
        # Sustituir el valor manualmente
        new_value = input("Introduce el nuevo valor para 'estacionamientos': ")
        df.at[idx, 'estacionamientos'] = float(new_value)    
    elif option == '2':
        # Pasar al siguiente registro
        continue
    else:
        print("Opción no válida. Pasando al siguiente registro...")
    
    print("\n---\n")

print("Proceso completado.")
# Out:
# Proceso completado.

# %% [markdown]
# ### Estacionamientos [0 / #]

# %%
# Filtrar los registros según las condiciones dadas
totales = df[( (df['estacionamientos']==0) & (df['estacionamiento_desc'].notna()) )] 
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# Iterar sobre los registros filtrados
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    print(row[['estacionamientos', 'estacionamiento_desc', 'url']])
    print("\n¿Qué acción te gustaría realizar?")
    print("1. Sustituir el valor manualmente")
    print("2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'")
    print("3. Pasar al siguiente registro")

    # Solicitar la opción al usuario
    option = input("Elige una opción (1, 2, 3): ")

    if option == '1':
        # Sustituir el valor manualmente
        new_value = input("Introduce el nuevo valor para 'estacionamientos': ")
        df.at[idx, 'estacionamientos'] = float(new_value)
    elif option == '2':
        # Sustituir el valor de 'metros_total' por 'totales_desc'
        df.at[idx, 'estacionamientos'] = df.at[idx, 'estacionamiento_desc']
    elif option == '3':
        # Pasar al siguiente registro
        continue
    else:
        print("Opción no válida. Pasando al siguiente registro...")
    
    print("\n---\n")

print("Proceso completado.")
# Out:
# Proceso completado.

# %% [markdown]
# ### Estacionamientos [# / #]

# %%
# Filtrar los registros según las condiciones dadas
totales = df[( ((df['estacionamientos']!=0) & (df['estacionamiento_desc'].notna())) & (df['estacionamientos'] != df['estacionamiento_desc']) )] 
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# Iterar sobre los registros filtrados
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    print(row[['estacionamientos', 'estacionamiento_desc', 'url']])
    print("\n¿Qué acción te gustaría realizar?")
    print("1. Sustituir el valor manualmente")
    print("2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'")
    print("3. Pasar al siguiente registro")

    # Solicitar la opción al usuario
    option = input("Elige una opción (1, 2, 3): ")

    if option == '1':
        # Sustituir el valor manualmente
        new_value = input("Introduce el nuevo valor para 'estacionamientos': ")
        df.at[idx, 'estacionamientos'] = float(new_value)
    elif option == '2':
        # Sustituir el valor de 'metros_total' por 'totales_desc'
        df.at[idx, 'estacionamientos'] = df.at[idx, 'estacionamiento_desc']
    elif option == '3':
        # Pasar al siguiente registro
        continue
    else:
        print("Opción no válida. Pasando al siguiente registro...")
    
    print("\n---\n")

print("Proceso completado.")
# Out:
# Registro 0:
# estacionamientos                                                        2
# estacionamiento_desc                                               2890.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-1e...
# Name: 0, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Registro 1:
# estacionamientos                                                        2
# estacionamiento_desc                                                 24.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-a6...
# Name: 1, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Registro 4:
# estacionamientos                                                        2
# estacionamiento_desc                                                  3.0
# url                     https://www.lamudi.com.mx/detalle/41032-73-9a6...
# Name: 4, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Registro 5:
# estacionamientos                                                        2
# estacionamiento_desc                                                  3.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-5b...
# Name: 5, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Registro 6:
# estacionamientos                                                        2
# estacionamiento_desc                                                  3.0
# url                     https://www.lamudi.com.mx/detalle/41032-73-747...
# Name: 6, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Registro 8:
# estacionamientos                                                        2
# estacionamiento_desc                                                 18.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-e5...
# Name: 8, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Registro 9:
# estacionamientos                                                        1
# estacionamiento_desc                                                  2.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-ee...
# Name: 9, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Registro 10:
# estacionamientos                                                        1
# estacionamiento_desc                                                  2.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-a3...
# Name: 10, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Registro 13:
# estacionamientos                                                        2
# estacionamiento_desc                                                  4.0
# url                     https://www.lamudi.com.mx/detalle/41032-73-bd5...
# Name: 13, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Registro 16:
# estacionamientos                                                        2
# estacionamiento_desc                                                  4.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-28...
# Name: 16, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Registro 17:
# estacionamientos                                                        2
# estacionamiento_desc                                                 21.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-22...
# Name: 17, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Registro 18:
# estacionamientos                                                        2
# estacionamiento_desc                                                  4.0
# url                     https://www.lamudi.com.mx/detalle/41032-73-1db...
# Name: 18, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 19:
# estacionamientos                                                        2
# estacionamiento_desc                                                  1.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-e8...
# Name: 19, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 22:
# estacionamientos                                                        2
# estacionamiento_desc                                                  8.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-67...
# Name: 22, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 23:
# estacionamientos                                                        2
# estacionamiento_desc                                                 30.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-58...
# Name: 23, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 24:
# estacionamientos                                                        2
# estacionamiento_desc                                                 30.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-d4...
# Name: 24, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 25:
# estacionamientos                                                        2
# estacionamiento_desc                                                100.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-87...
# Name: 25, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 27:
# estacionamientos                                                        2
# estacionamiento_desc                                                 46.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-4c...
# Name: 27, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 31:
# estacionamientos                                                        2
# estacionamiento_desc                                                  3.0
# url                     https://www.lamudi.com.mx/detalle/41032-73-93d...
# Name: 31, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 32:
# estacionamientos                                                        2
# estacionamiento_desc                                                  5.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-18...
# Name: 32, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 33:
# estacionamientos                                                        2
# estacionamiento_desc                                                  3.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-fe...
# Name: 33, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 39:
# estacionamientos                                                        2
# estacionamiento_desc                                                  5.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-d3...
# Name: 39, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 43:
# estacionamientos                                                        2
# estacionamiento_desc                                                 21.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-10...
# Name: 43, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 44:
# estacionamientos                                                        2
# estacionamiento_desc                                                 21.0
# url                     https://www.lamudi.com.mx/detalle/41032-73-10c...
# Name: 44, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 45:
# estacionamientos                                                        2
# estacionamiento_desc                                                  3.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-fc...
# Name: 45, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 46:
# estacionamientos                                                        2
# estacionamiento_desc                                                  4.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-60...
# Name: 46, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 47:
# estacionamientos                                                        2
# estacionamiento_desc                                                  4.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-a7...
# Name: 47, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 48:
# estacionamientos                                                        2
# estacionamiento_desc                                                  4.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-87...
# Name: 48, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 49:
# estacionamientos                                                        2
# estacionamiento_desc                                                  4.0
# url                     https://www.lamudi.com.mx/detalle/41032-73-a76...
# Name: 49, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 50:
# estacionamientos                                                        2
# estacionamiento_desc                                                  4.0
# url                     https://www.lamudi.com.mx/detalle/41032-73-87c...
# Name: 50, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 51:
# estacionamientos                                                        2
# estacionamiento_desc                                                 80.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-b7...
# Name: 51, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 52:
# estacionamientos                                                        1
# estacionamiento_desc                                                 15.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-50...
# Name: 52, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 54:
# estacionamientos                                                        2
# estacionamiento_desc                                                  3.0
# url                     https://www.lamudi.com.mx/detalle/41032-73-1c0...
# Name: 54, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 56:
# estacionamientos                                                        2
# estacionamiento_desc                                                 15.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-e3...
# Name: 56, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 57:
# estacionamientos                                                        2
# estacionamiento_desc                                                  4.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-83...
# Name: 57, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 59:
# estacionamientos                                                        2
# estacionamiento_desc                                                  7.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-fc...
# Name: 59, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 61:
# estacionamientos                                                        2
# estacionamiento_desc                                                  3.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-df...
# Name: 61, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 62:
# estacionamientos                                                        2
# estacionamiento_desc                                                  3.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-25...
# Name: 62, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 63:
# estacionamientos                                                        1
# estacionamiento_desc                                                  2.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-ac...
# Name: 63, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 64:
# estacionamientos                                                        1
# estacionamiento_desc                                                100.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-a6...
# Name: 64, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 65:
# estacionamientos                                                        2
# estacionamiento_desc                                         5538002825.0
# url                     https://www.lamudi.com.mx/detalle/41032-73-c71...
# Name: 65, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 67:
# estacionamientos                                                        2
# estacionamiento_desc                                                  4.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-8d...
# Name: 67, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 68:
# estacionamientos                                                        2
# estacionamiento_desc                                         5539513946.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-73...
# Name: 68, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 69:
# estacionamientos                                                        2
# estacionamiento_desc                                                  3.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-59...
# Name: 69, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 70:
# estacionamientos                                                        2
# estacionamiento_desc                                                  3.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-fb...
# Name: 70, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 71:
# estacionamientos                                                        2
# estacionamiento_desc                                                  3.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-b0...
# Name: 71, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 72:
# estacionamientos                                                        2
# estacionamiento_desc                                                  8.0
# url                     https://www.lamudi.com.mx/detalle/41032-73-dac...
# Name: 72, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 73:
# estacionamientos                                                        2
# estacionamiento_desc                                         5536695856.0
# url                     https://www.lamudi.com.mx/detalle/41032-73-2ea...
# Name: 73, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 75:
# estacionamientos                                                        1
# estacionamiento_desc                                                  2.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-d6...
# Name: 75, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 76:
# estacionamientos                                                        2
# estacionamiento_desc                                                  3.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-a5...
# Name: 76, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 77:
# estacionamientos                                                        2
# estacionamiento_desc                                                144.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-e3...
# Name: 77, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 78:
# estacionamientos                                                        2
# estacionamiento_desc                                                  8.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-37...
# Name: 78, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 79:
# estacionamientos                                                        2
# estacionamiento_desc                                                  8.0
# url                     https://www.lamudi.com.mx/detalle/41032-73-a24...
# Name: 79, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 80:
# estacionamientos                                                        2
# estacionamiento_desc                                                  8.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-25...
# Name: 80, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 81:
# estacionamientos                                                        2
# estacionamiento_desc                                                  8.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-cb...
# Name: 81, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 83:
# estacionamientos                                                        2
# estacionamiento_desc                                                  6.0
# url                     https://www.lamudi.com.mx/detalle/41032-73-592...
# Name: 83, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 84:
# estacionamientos                                                        1
# estacionamiento_desc                                                  2.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-5c...
# Name: 84, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 86:
# estacionamientos                                                        2
# estacionamiento_desc                                                  5.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-1c...
# Name: 86, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 87:
# estacionamientos                                                        2
# estacionamiento_desc                                                  5.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-4f...
# Name: 87, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 88:
# estacionamientos                                                        2
# estacionamiento_desc                                                  5.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-cb...
# Name: 88, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 89:
# estacionamientos                                                        2
# estacionamiento_desc                                                  5.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-9a...
# Name: 89, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 90:
# estacionamientos                                                        2
# estacionamiento_desc                                                  5.0
# url                     https://www.lamudi.com.mx/detalle/41032-73-9a0...
# Name: 90, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 91:
# estacionamientos                                                        2
# estacionamiento_desc                                                  5.0
# url                     https://www.lamudi.com.mx/detalle/41032-73-cbd...
# Name: 91, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 92:
# estacionamientos                                                        2
# estacionamiento_desc                                                 50.0
# url                     https://www.lamudi.com.mx/detalle/41032-73-98d...
# Name: 92, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 93:
# estacionamientos                                                        2
# estacionamiento_desc                                                  5.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-ca...
# Name: 93, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 94:
# estacionamientos                                                        2
# estacionamiento_desc                                                  5.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-a6...
# Name: 94, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 95:
# estacionamientos                                                        2
# estacionamiento_desc                                                  8.0
# url                     https://www.lamudi.com.mx/detalle/41032-73-ece...
# Name: 95, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 96:
# estacionamientos                                                        2
# estacionamiento_desc                                                 80.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-1c...
# Name: 96, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 97:
# estacionamientos                                                        2
# estacionamiento_desc                                                  4.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-da...
# Name: 97, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 98:
# estacionamientos                                                        1
# estacionamiento_desc                                                 10.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-7c...
# Name: 98, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 100:
# estacionamientos                                                        2
# estacionamiento_desc                                         5586812967.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-68...
# Name: 100, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 101:
# estacionamientos                                                        2
# estacionamiento_desc                                         5538002825.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-1d...
# Name: 101, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 102:
# estacionamientos                                                        2
# estacionamiento_desc                                                  3.0
# url                     https://www.lamudi.com.mx/detalle/41032-73-ba2...
# Name: 102, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 103:
# estacionamientos                                                        2
# estacionamiento_desc                                                  3.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-e2...
# Name: 103, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 104:
# estacionamientos                                                        2
# estacionamiento_desc                                                  4.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-a9...
# Name: 104, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 105:
# estacionamientos                                                        2
# estacionamiento_desc                                               5921.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-65...
# Name: 105, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 107:
# estacionamientos                                                        2
# estacionamiento_desc                                                  3.0
# url                     https://www.lamudi.com.mx/detalle/41032-73-916...
# Name: 107, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 109:
# estacionamientos                                                        2
# estacionamiento_desc                                                150.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-f8...
# Name: 109, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 110:
# estacionamientos                                                        2
# estacionamiento_desc                                                150.0
# url                     https://www.lamudi.com.mx/detalle/41032-73-f8a...
# Name: 110, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 113:
# estacionamientos                                                        2
# estacionamiento_desc                                                  8.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-c8...
# Name: 113, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 114:
# estacionamientos                                                        2
# estacionamiento_desc                                                  3.0
# url                     https://www.lamudi.com.mx/detalle/41032-73-b50...
# Name: 114, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 115:
# estacionamientos                                                        2
# estacionamiento_desc                                                  4.0
# url                     https://www.lamudi.com.mx/detalle/41032-73-9e1...
# Name: 115, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 116:
# estacionamientos                                                        2
# estacionamiento_desc                                                 12.0
# url                     https://www.lamudi.com.mx/detalle/41032-73-fc3...
# Name: 116, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 117:
# estacionamientos                                                        2
# estacionamiento_desc                                                  3.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-e1...
# Name: 117, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 118:
# estacionamientos                                                        2
# estacionamiento_desc                                                  3.0
# url                     https://www.lamudi.com.mx/detalle/41032-73-27d...
# Name: 118, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 119:
# estacionamientos                                                        2
# estacionamiento_desc                                                  3.0
# url                     https://www.lamudi.com.mx/detalle/41032-73-871...
# Name: 119, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 120:
# estacionamientos                                                        2
# estacionamiento_desc                                                  3.0
# url                     https://www.lamudi.com.mx/detalle/41032-73-a92...
# Name: 120, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 121:
# estacionamientos                                                        2
# estacionamiento_desc                                                  3.0
# url                     https://www.lamudi.com.mx/detalle/41032-73-ef2...
# Name: 121, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 122:
# estacionamientos                                                        2
# estacionamiento_desc                                                  3.0
# url                     https://www.lamudi.com.mx/detalle/41032-73-9d7...
# Name: 122, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 123:
# estacionamientos                                                        2
# estacionamiento_desc                                                  3.0
# url                     https://www.lamudi.com.mx/detalle/41032-73-f0e...
# Name: 123, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 124:
# estacionamientos                                                        2
# estacionamiento_desc                                                  4.0
# url                     https://www.lamudi.com.mx/detalle/41032-73-511...
# Name: 124, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 125:
# estacionamientos                                                        2
# estacionamiento_desc                                                  3.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-d1...
# Name: 125, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 133:
# estacionamientos                                                        2
# estacionamiento_desc                                                  3.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-d2...
# Name: 133, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 134:
# estacionamientos                                                        1
# estacionamiento_desc                                                  3.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-47...
# Name: 134, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 135:
# estacionamientos                                                        2
# estacionamiento_desc                                                  3.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-21...
# Name: 135, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 136:
# estacionamientos                                                        2
# estacionamiento_desc                                                162.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-4c...
# Name: 136, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 137:
# estacionamientos                                                        2
# estacionamiento_desc                                                  1.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-6a...
# Name: 137, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 138:
# estacionamientos                                                        2
# estacionamiento_desc                                                 60.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-ed...
# Name: 138, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 139:
# estacionamientos                                                        2
# estacionamiento_desc                                                 60.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-1f...
# Name: 139, dtype: object
#
# ...
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2150:
# estacionamientos                                                        2
# estacionamiento_desc                                                  5.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-79...
# Name: 2150, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2152:
# estacionamientos                                                        1
# estacionamiento_desc                                               3350.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-11...
# Name: 2152, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2153:
# estacionamientos                                                        1
# estacionamiento_desc                                                  3.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-9e...
# Name: 2153, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2156:
# estacionamientos                                                        2
# estacionamiento_desc                                                 15.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-d8...
# Name: 2156, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2158:
# estacionamientos                                                        2
# estacionamiento_desc                                                112.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-59...
# Name: 2158, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2160:
# estacionamientos                                                        2
# estacionamiento_desc                                                 20.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-33...
# Name: 2160, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2161:
# estacionamientos                                                        1
# estacionamiento_desc                                                 10.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-60...
# Name: 2161, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2162:
# estacionamientos                                                        2
# estacionamiento_desc                                               7503.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-5a...
# Name: 2162, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2163:
# estacionamientos                                                        2
# estacionamiento_desc                                                112.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-2d...
# Name: 2163, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2164:
# estacionamientos                                                        2
# estacionamiento_desc                                               2800.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-36...
# Name: 2164, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2165:
# estacionamientos                                                        2
# estacionamiento_desc                                                 14.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-dc...
# Name: 2165, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2166:
# estacionamientos                                                        2
# estacionamiento_desc                                                 11.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-97...
# Name: 2166, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2167:
# estacionamientos                                                        2
# estacionamiento_desc                                                 15.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-e9...
# Name: 2167, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2168:
# estacionamientos                                                        2
# estacionamiento_desc                                                 70.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-66...
# Name: 2168, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2169:
# estacionamientos                                                        2
# estacionamiento_desc                                                  1.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-ef...
# Name: 2169, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2170:
# estacionamientos                                                        2
# estacionamiento_desc                                                  1.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-aa...
# Name: 2170, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2171:
# estacionamientos                                                        2
# estacionamiento_desc                                                  1.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-f7...
# Name: 2171, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2172:
# estacionamientos                                                        2
# estacionamiento_desc                                                  1.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-e8...
# Name: 2172, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2174:
# estacionamientos                                                        1
# estacionamiento_desc                                                132.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-30...
# Name: 2174, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2175:
# estacionamientos                                                        2
# estacionamiento_desc                                                 68.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-45...
# Name: 2175, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2176:
# estacionamientos                                                        1
# estacionamiento_desc                                                 10.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-cb...
# Name: 2176, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2177:
# estacionamientos                                                        2
# estacionamiento_desc                                                  1.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-28...
# Name: 2177, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2179:
# estacionamientos                                                        2
# estacionamiento_desc                                                  4.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-44...
# Name: 2179, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2180:
# estacionamientos                                                        2
# estacionamiento_desc                                                  3.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-f3...
# Name: 2180, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2181:
# estacionamientos                                                        2
# estacionamiento_desc                                                  1.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-b0...
# Name: 2181, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2182:
# estacionamientos                                                        2
# estacionamiento_desc                                                  1.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-5e...
# Name: 2182, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2184:
# estacionamientos                                                        2
# estacionamiento_desc                                                  1.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-90...
# Name: 2184, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2185:
# estacionamientos                                                        2
# estacionamiento_desc                                                 56.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-4b...
# Name: 2185, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2186:
# estacionamientos                                                        2
# estacionamiento_desc                                                  1.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-f6...
# Name: 2186, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2188:
# estacionamientos                                                        2
# estacionamiento_desc                                                  1.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-f8...
# Name: 2188, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2189:
# estacionamientos                                                        2
# estacionamiento_desc                                                 18.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-20...
# Name: 2189, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2190:
# estacionamientos                                                        1
# estacionamiento_desc                                                 24.0
# url                     https://www.lamudi.com.mx//detalle/41032-73-c5...
# Name: 2190, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'
# 3. Pasar al siguiente registro

# %% [markdown]
# ## b) Mantener rango de estacionamientos < 5 (mínimo 1)

# %%
df_filtrado = df[df['estacionamientos'] <= 5]
df_filtrado[['estacionamientos','estacionamiento_desc','url']]

# %%
df = df[df['estacionamientos'] <= 5]

# %% [markdown]
# # 8. Recámaras

# %% [markdown]
# ## a) Recámaras en descripción

# %%
# Función para extraer cantidad de recamaras en descripción
def extraer_recamaras(descripcion):
    descripcion = descripcion.lower()
    # Buscar patrones de totales
    totales = re.findall(r'\b(\d+[\.,]?\d*)\s*(recamara|recamaras|habitaciones|dormitorio|dormitorios)\b', descripcion)
    total = None
    for match in totales:
        numero, _ = match
        numero = numero.replace(',', '').replace("'", '')
        try:
            total = float(numero)
        except ValueError:
            continue
        if total:
            break
    return total

# Aplicar la función al DataFrame
df['recamaras_desc'] = df['descripcion'].apply(extraer_recamaras)

# %% [markdown]
# ### Recámaras [0 / 0]

# %%
# Filtrar los registros según las condiciones dadas
totales = df[ (df['recamaras'] == 0 ) & (df['recamaras_desc'].isna()) ] 
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# Iterar sobre los registros filtrados
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    print(row[['url']])
    print("\n¿Qué acción te gustaría realizar?")
    print("1. Sustituir el valor manualmente")
    print("2. Pasar al siguiente registro")

    # Solicitar la opción al usuario
    option = input("Elige una opción (1 | 2): ")

    if option == '1':
        # Sustituir el valor manualmente
        new_value = input("Introduce el nuevo valor para 'recamaras': ")
        df.at[idx, 'recamaras'] = float(new_value)
    elif option == '2':
        # Pasar al siguiente registro
        continue
    else:
        print("Opción no válida. Pasando al siguiente registro...")
    
    print("\n---\n")

print("Proceso completado.")
# Out:
# Proceso completado.

# %% [markdown]
# ### Recámaras [0 / #]

# %%
# Filtrar los registros según las condiciones dadas
totales = df[( (df['recamaras']==0) & (df['recamaras_desc'].notna()) )] 
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# Iterar sobre los registros filtrados
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    print(row[['recamaras', 'recamaras_desc', 'url']])
    print("\n¿Qué acción te gustaría realizar?")
    print("1. Sustituir el valor manualmente")
    print("2. Sustituir el valor de 'recamaras' por el de 'recamaras_desc'")
    print("3. Pasar al siguiente registro")

    # Solicitar la opción al usuario
    option = input("Elige una opción (1, 2, 3): ")

    if option == '1':
        # Sustituir el valor manualmente
        new_value = input("Introduce el nuevo valor para 'recamaras': ")
        df.at[idx, 'recamaras'] = float(new_value)
    elif option == '2':
        # Sustituir el valor de 'metros_total' por 'totales_desc'
        df.at[idx, 'recamaras'] = df.at[idx, 'recamaras_desc']
    elif option == '3':
        # Pasar al siguiente registro
        continue
    else:
        print("Opción no válida. Pasando al siguiente registro...")
    
    print("\n---\n")

print("Proceso completado.")
# Out:
# Proceso completado.

# %% [markdown]
# ### Recámaras [# / #]

# %%
# Filtrar los registros según las condiciones dadas
totales = df[( (df['recamaras']!=0) & (df['recamaras_desc'].notna()) ) & (df['recamaras'] != df['recamaras_desc'])] 
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# Iterar sobre los registros filtrados
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    print(row[['recamaras', 'recamaras_desc', 'url']])
    print("\n¿Qué acción te gustaría realizar?")
    print("1. Sustituir el valor manualmente")
    print("2. Sustituir el valor de 'recamaras' por el de 'recamaras_desc'")
    print("3. Pasar al siguiente registro")

    # Solicitar la opción al usuario
    option = input("Elige una opción (1, 2, 3): ")

    if option == '1':
        # Sustituir el valor manualmente
        new_value = input("Introduce el nuevo valor para 'recamaras': ")
        df.at[idx, 'recamaras'] = float(new_value)
    elif option == '2':
        # Sustituir el valor de 'metros_total' por 'totales_desc'
        df.at[idx, 'recamaras'] = df.at[idx, 'recamaras_desc']
    elif option == '3':
        # Pasar al siguiente registro
        continue
    else:
        print("Opción no válida. Pasando al siguiente registro...")
    
    print("\n---\n")

print("Proceso completado.")

# %% [markdown]
# ## b) Mantener rango de recámaras <= 7

# %%
df['recamaras'].unique()

# %%
dentro = df[(df['recamaras'] <= 7)] 
print(dentro[['recamaras','recamaras_desc','url']])

# %% [markdown]
# # 9. Baños

# %% [markdown]
# ## a) Baños en descripción

# %% [markdown]
# Manejando tanto los completos como los medios

# %%
# Extraer la cantidad de baños y medios baños en la descripción
def extraer_baños(descripcion):
    descripcion = descripcion.lower()
    
    # Buscar patrones de baños completos
    completos = re.findall(r'\b(\d+[\.,]?\d*)\s*baños?\b', descripcion)
    total_completos = sum([float(match.replace(',', '').replace("'", '')) for match in completos])
    
    # Buscar patrones de medios baños (1/2 baño)
    medios = re.findall(r'\b(\d+[\.,]?\d*)\s*medios?\s*baños?\b', descripcion)
    total_medios = sum([float(match.replace(',', '').replace("'", '')) for match in medios])
    
    # Retornar como un diccionario o una tupla
    return {'completos': total_completos, 'medios': total_medios}

# Aplicar la función al DataFrame
df['baños_desc'] = df['descripcion'].apply(extraer_baños)

# Si deseas separar en dos columnas distintas:
df['baños_completos'] = df['baños_desc'].apply(lambda x: x['completos'] if x else 0)
df['medios_baños'] = df['baños_desc'].apply(lambda x: x['medios'] if x else 0)

# %% [markdown]
# ### Baños

# %% [markdown]
# #### [0 / 0]

# %% [markdown]
# Poner como mínimo para el registro 1 en baños, pero si cuenta con medio baño en descripción que se le asigne ese valor.

# %%
# Filtrar los registros según las condiciones dadas
totales = df[(df['banos'] == 0) & (df['baños_completos'].isna())]
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# Iterar sobre los registros filtrados
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    print(row[['url']])
    print("\n¿Qué acción te gustaría realizar?")
    print("1. Sustituir el valor manualmente")
    #print("2. Asignar 1 como mínimo y pasar al siguiente registro")
    print("2. Pasar al siguiente registro")

    # Solicitar la opción al usuario
    option = input("Elige una opción (1 | 2): ")

    if option == '1':
        # Sustituir el valor manualmente
        new_value = input("Introduce el nuevo valor para 'banos': ")
        df.at[idx, 'banos'] = float(new_value)
    #elif option == '2':
        # Asignar valor de 1 como mínimo
        #df.at[idx, 'banos'] = 1
        #continue  # Pasar al siguiente registro
    else:
        continue  # Pasar al siguiente registro

    print("\n---\n")

print("Proceso completado.")
# Out:
# Proceso completado.

# %% [markdown]
# #### [0 / #]

# %%
# Filtrar los registros según las condiciones dadas
totales = df[( (df['banos']==0) & (df['baños_completos'].notna()) )] 
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# Iterar sobre los registros filtrados
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    print(row[['banos']])
    print(row[['baños_completos']])
    print(row[['url']])
    print("\n¿Qué acción te gustaría realizar?")
    print("1. Sustituir el valor manualmente")
    print("2. Sustituir el valor de 'banos' por el de 'baños_completos'")
    #print("3. Asignar 1 como mínimo y pasar al siguiente registro")
    print("3. Pasar al siguiente registro")

    # Solicitar la opción al usuario
    option = input("Elige una opción (1 | 2 | 3): ")

    if option == '1':
        # Sustituir el valor manualmente
        new_value = input("Introduce el nuevo valor para 'banos': ")
        df.at[idx, 'banos'] = float(new_value)
    elif option == '2':
        # Sustituir el valor de 'banos' por 'baños_completos'
        df.at[idx, 'banos'] = df.at[idx, 'baños_completos']
    #elif option == '3':
        # Asignar valor de 1 como mínimo
        #df.at[idx, 'banos'] = 1
        #continue  # Pasar al siguiente registro
    else:
        continue  # Pasar al siguiente registro

    print("\n---\n")

print("Proceso completado.")
# Out:
# Registro 236:
# banos    0.0
# Name: 236, dtype: object
# baños_completos    0.0
# Name: 236, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-a3ee8bf8fc9d-524a-1f3db509-83cd-4b7b
# Name: 236, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# ---------------------------------------------------------------------------
#
# KeyboardInterrupt                         Traceback (most recent call last)
#
# ~\AppData\Local\Temp\ipykernel_10972\779107267.py in <module>
#
#      15
#
#      16     # Solicitar la opción al usuario
#
# ---> 17     option = input("Elige una opción (1 | 2 | 3): ")
#
#      18
#
#      19     if option == '1':
#
#
#
# c:\Users\yoe11\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#
#    1173                 "raw_input was called, but this frontend does not support input requests."
#
#    1174             )
#
# -> 1175         return self._input_request(
#
#    1176             str(prompt),
#
#    1177             self._parent_ident["shell"],
#
#
#
# c:\Users\yoe11\anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#
#    1215             except KeyboardInterrupt:
#
#    1216                 # re-raise KeyboardInterrupt, to truncate traceback
#
# -> 1217                 raise KeyboardInterrupt("Interrupted by user") from None
#
#    1218             except Exception:
#
#    1219                 self.log.warning("Invalid Message:", exc_info=True)
#
#
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# #### [# / #]

# %%
# Filtrar los registros según las condiciones dadas
totales = df[( ((df['banos']!=0) & (df['baños_completos'].notna())) & (df['banos'] != df['baños_completos']))] 
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# Iterar sobre los registros filtrados
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    print(row[['banos']])
    print(row[['baños_completos']])    
    print(row[['url']])
    
    print("\n¿Qué acción te gustaría realizar?")
    print("1. Sustituir el valor manualmente")
    print("2. Sustituir el valor de 'banos' por el de 'baños_completos'")
    #print("3. Asignar 1 como mínimo y pasar al siguiente registro")
    print("3. Pasar al siguiente registro")

    # Solicitar la opción al usuario
    option = input("Elige una opción (1 | 2 | 3): ")

    if option == '1':
        # Sustituir el valor manualmente
        new_value = input("Introduce el nuevo valor para 'banos': ")
        df.at[idx, 'banos'] = float(new_value)
    elif option == '2':
        # Sustituir el valor de 'banos' por 'baños_completos'
        df.at[idx, 'banos'] = df.at[idx, 'baños_completos']
    #elif option == '3':
        # Asignar valor de 1 como mínimo
        #df.at[idx, 'banos'] = 1
        #continue  # Pasar al siguiente registro
    else:
        continue  # Pasar al siguiente registro

    print("\n---\n")

print("Proceso completado.")
# Out:
# Registro 31:
# banos    2
# Name: 31, dtype: object
# baños_completos    5.0
# Name: 31, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-93d194dc33d-d035-bf07501c-825e-4a4a
# Name: 31, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 37:
# banos    3
# Name: 37, dtype: object
# baños_completos    0.0
# Name: 37, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-27915b7692e9-3bc0-67bbfd01-9453-4608
# Name: 37, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 65:
# banos    1
# Name: 65, dtype: object
# baños_completos    0.0
# Name: 65, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-c7136c4c8f36-cb2f-fd601220-8b1e-4305
# Name: 65, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 91:
# banos    1
# Name: 91, dtype: object
# baños_completos    4.0
# Name: 91, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-cbd89c1181eb-6233-72e52972-be96-4e29
# Name: 91, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 95:
# banos    3
# Name: 95, dtype: object
# baños_completos    0.0
# Name: 95, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-ece532a1de91-7596-9cfd993-b6d6-5038
# Name: 95, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 114:
# banos    1
# Name: 114, dtype: object
# baños_completos    2.0
# Name: 114, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-b508efd58246-532d-db9a6d07-89c7-49ad
# Name: 114, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 140:
# banos    1
# Name: 140, dtype: object
# baños_completos    0.0
# Name: 140, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-5e3154762f91-b464-3c3d91c2-b0fb-4e72
# Name: 140, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 143:
# banos    3
# Name: 143, dtype: object
# baños_completos    0.0
# Name: 143, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-9f8416fe7d20-4558-6fedd2c1-b3af-3a95
# Name: 143, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 145:
# banos    2
# Name: 145, dtype: object
# baños_completos    0.0
# Name: 145, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-1380b23a017b-eb33-179baee1-baca-3af7
# Name: 145, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 146:
# banos    2
# Name: 146, dtype: object
# baños_completos    0.0
# Name: 146, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-54c9a76db762-9d8c-bfbd3eaf-b2e0-47ba
# Name: 146, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 153:
# banos    1
# Name: 153, dtype: object
# baños_completos    0.0
# Name: 153, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-b52ebb7e062a-1c16-282bc937-92dd-4559
# Name: 153, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 179:
# banos    3
# Name: 179, dtype: object
# baños_completos    0.0
# Name: 179, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-edb7d9699a45-bf79-71f1ad94-8d6e-354c
# Name: 179, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 181:
# banos    2
# Name: 181, dtype: object
# baños_completos    0.0
# Name: 181, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-f75d6780630b-8d42-297f81a9-b296-4751
# Name: 181, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 188:
# banos    2
# Name: 188, dtype: object
# baños_completos    0.0
# Name: 188, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-ad88958b7e4b-2bb2-c0c7e785-a185-4bf5
# Name: 188, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 195:
# banos    1
# Name: 195, dtype: object
# baños_completos    0.0
# Name: 195, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-2574f4ca7595-b1a2-a87e072b-9825-435a
# Name: 195, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 198:
# banos    1
# Name: 198, dtype: object
# baños_completos    2.0
# Name: 198, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-693603a35ed7-4722-ec4a245b-9482-4c8e
# Name: 198, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 201:
# banos    1
# Name: 201, dtype: object
# baños_completos    2.0
# Name: 201, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-18fe349753c6-ff0f-eaa172a9-85dc-4b6f
# Name: 201, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 233:
# banos    3
# Name: 233, dtype: object
# baños_completos    0.0
# Name: 233, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-c2dd6927fde4-1b1f-5b749227-9f3b-410e
# Name: 233, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 235:
# banos    1
# Name: 235, dtype: object
# baños_completos    3.0
# Name: 235, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-2e47451c060f-da81-a84f117-bd93-4bce
# Name: 235, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 236:
# banos    2
# Name: 236, dtype: object
# baños_completos    0.0
# Name: 236, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-a3ee8bf8fc9d-524a-1f3db509-83cd-4b7b
# Name: 236, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 322:
# banos    3
# Name: 322, dtype: object
# baños_completos    0.0
# Name: 322, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-caf342ff5ab1-bf9e-2aa3e70e-b9fc-4bee
# Name: 322, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 347:
# banos    1
# Name: 347, dtype: object
# baños_completos    0.0
# Name: 347, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-704fd025bb38-1e15-97349991-9551-455f
# Name: 347, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 392:
# banos    1
# Name: 392, dtype: object
# baños_completos    0.0
# Name: 392, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-90b676e4ac53-bc36-f7eb833-8e6b-4924
# Name: 392, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 431:
# banos    1
# Name: 431, dtype: object
# baños_completos    0.0
# Name: 431, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-f6235560e31a-1749-a0081ec8-a824-4bdd
# Name: 431, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 434:
# banos    2
# Name: 434, dtype: object
# baños_completos    0.0
# Name: 434, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-33235dedb4ed-ac9e-fcaba94c-b874-4181
# Name: 434, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 448:
# banos    1
# Name: 448, dtype: object
# baños_completos    0.0
# Name: 448, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-1d57a30e2009-c097-848a0f8b-94dd-4a10
# Name: 448, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 454:
# banos    1
# Name: 454, dtype: object
# baños_completos    0.0
# Name: 454, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-f11931ad4504-6d50-57fbeead-805b-478d
# Name: 454, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 457:
# banos    1
# Name: 457, dtype: object
# baños_completos    0.0
# Name: 457, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-3431de6259b7-7af9-a113c8ce-bc30-47fd
# Name: 457, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 516:
# banos    1
# Name: 516, dtype: object
# baños_completos    0.0
# Name: 516, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-50d17c00c137-4c06-e7fc02eb-ba22-4912
# Name: 516, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 552:
# banos    2
# Name: 552, dtype: object
# baños_completos    0.0
# Name: 552, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-6945048fb219-fa03-43aa7a74-bab9-4364
# Name: 552, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 565:
# banos    3
# Name: 565, dtype: object
# baños_completos    0.0
# Name: 565, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-ffef1447fcb-2a77-43df6de7-9b68-42d0
# Name: 565, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 591:
# banos    1
# Name: 591, dtype: object
# baños_completos    4.0
# Name: 591, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-1f5bce4bef3-3e4e-b37badba-a9ab-4b4f
# Name: 591, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 593:
# banos    1
# Name: 593, dtype: object
# baños_completos    0.0
# Name: 593, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-85bc36bf8eaf-6efb-327a921b-859e-4c09
# Name: 593, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 603:
# banos    1
# Name: 603, dtype: object
# baños_completos    0.0
# Name: 603, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-40e021068c65-d03f-f0bfbcf3-83f9-333c
# Name: 603, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 681:
# banos    1
# Name: 681, dtype: object
# baños_completos    0.0
# Name: 681, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-cdc4cefa2500-fbb7-b04903b2-b071-344e
# Name: 681, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 683:
# banos    3
# Name: 683, dtype: object
# baños_completos    0.0
# Name: 683, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-c489ef03a162-8ed1-3db9227a-98a2-39c9
# Name: 683, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 687:
# banos    1
# Name: 687, dtype: object
# baños_completos    0.0
# Name: 687, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-56ab4fd0779b-3a2c-9d4dac41-b4d1-4132
# Name: 687, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 703:
# banos    2
# Name: 703, dtype: object
# baños_completos    2.5
# Name: 703, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-c99c82f29f03-d903-b606018d-ba70-365d
# Name: 703, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 705:
# banos    3
# Name: 705, dtype: object
# baños_completos    0.0
# Name: 705, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-667d9cb29bd6-4b6d-28f2ba3d-a07e-3313
# Name: 705, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 715:
# banos    2
# Name: 715, dtype: object
# baños_completos    0.0
# Name: 715, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-7ec904ade2ad-729e-b98841f5-bbdb-477f
# Name: 715, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 805:
# banos    1
# Name: 805, dtype: object
# baños_completos    0.0
# Name: 805, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-355f1f2508e4-e726-3b85c981-a39f-4300
# Name: 805, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 825:
# banos    1
# Name: 825, dtype: object
# baños_completos    0.0
# Name: 825, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-9b82da76bcac-a572-9c71140c-98f9-3d1a
# Name: 825, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 829:
# banos    1
# Name: 829, dtype: object
# baños_completos    0.0
# Name: 829, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-f1aeaaf44ccf-2367-85c8ac0e-b631-3341
# Name: 829, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 849:
# banos    2
# Name: 849, dtype: object
# baños_completos    0.0
# Name: 849, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-9a66a6c61eb4-78df-71c0c7b7-bc27-3f1c
# Name: 849, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 872:
# banos    1
# Name: 872, dtype: object
# baños_completos    2.5
# Name: 872, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-513d40a5f259-4d1d-e9064450-9e9f-3b7d
# Name: 872, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 873:
# banos    1
# Name: 873, dtype: object
# baños_completos    0.0
# Name: 873, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-526d8529bbba-e36a-841c587f-9b4d-4fcd
# Name: 873, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 878:
# banos    1
# Name: 878, dtype: object
# baños_completos    0.0
# Name: 878, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-66f77b4c2b00-d505-8be28d26-8c82-4711
# Name: 878, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 879:
# banos    1
# Name: 879, dtype: object
# baños_completos    0.0
# Name: 879, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-af5162cc88fb-ae7a-9ad7d266-a260-40aa
# Name: 879, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 880:
# banos    1
# Name: 880, dtype: object
# baños_completos    0.0
# Name: 880, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-251e52dffce8-274d-377b437c-a29e-4e89
# Name: 880, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 888:
# banos    1
# Name: 888, dtype: object
# baños_completos    0.0
# Name: 888, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-a2012c98622d-6203-ae93989d-a1bc-4a48
# Name: 888, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 897:
# banos    2
# Name: 897, dtype: object
# baños_completos    0.0
# Name: 897, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-9f0a085fc26f-17cb-e04cccfb-9c6c-33d6
# Name: 897, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 899:
# banos    2
# Name: 899, dtype: object
# baños_completos    0.0
# Name: 899, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-bdf7c0be02f8-20d5-982e27eb-8839-4bba
# Name: 899, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 948:
# banos    1
# Name: 948, dtype: object
# baños_completos    2.0
# Name: 948, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-4d3b789263c4-8ccb-53957f26-af9f-4f01
# Name: 948, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 965:
# banos    1
# Name: 965, dtype: object
# baños_completos    0.0
# Name: 965, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-efb4a7889912-7154-757fb66a-9a5a-43d7
# Name: 965, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 990:
# banos    1
# Name: 990, dtype: object
# baños_completos    0.0
# Name: 990, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-439dca51c554-f56-8c37417-a4bb-4a8d
# Name: 990, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 999:
# banos    1
# Name: 999, dtype: object
# baños_completos    3.0
# Name: 999, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-24f8d8a95d18-a620-51d2dcea-bf05-4ec6
# Name: 999, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 1016:
# banos    1
# Name: 1016, dtype: object
# baños_completos    0.0
# Name: 1016, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-5aa92dbf3480-cd3b-bddd263e-9166-397e
# Name: 1016, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 1036:
# banos    2
# Name: 1036, dtype: object
# baños_completos    0.0
# Name: 1036, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-f33c5602b15e-9729-179864f1-a192-3e19
# Name: 1036, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 1053:
# banos    1
# Name: 1053, dtype: object
# baños_completos    2.0
# Name: 1053, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-69eae9389044-a328-4db845ba-8373-3a33
# Name: 1053, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 1247:
# banos    2
# Name: 1247, dtype: object
# baños_completos    0.0
# Name: 1247, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-1f7479da9cb8-6713-e41a7b17-b6df-43b3
# Name: 1247, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 1267:
# banos    1
# Name: 1267, dtype: object
# baños_completos    2.5
# Name: 1267, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-d8550f2c0e7c-ca78-b962a5eb-92ac-3842
# Name: 1267, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 1293:
# banos    2
# Name: 1293, dtype: object
# baños_completos    3.0
# Name: 1293, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-98657fa95fe1-5ebb-c94a7aac-abf1-3a73
# Name: 1293, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 2347:
# banos    1
# Name: 2347, dtype: object
# baños_completos    0.0
# Name: 2347, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-ab676eaa234c-9a31-e1cb029a-869a-3106
# Name: 2347, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 2350:
# banos    1
# Name: 2350, dtype: object
# baños_completos    0.0
# Name: 2350, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-e3dfc2fea653-9763-ac93dc96-af2d-3b79
# Name: 2350, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 2360:
# banos    2
# Name: 2360, dtype: object
# baños_completos    0.0
# Name: 2360, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-e05a703b5128-4614-2bc30816-832e-4f81
# Name: 2360, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 2455:
# banos    1
# Name: 2455, dtype: object
# baños_completos    0.0
# Name: 2455, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-10bceccb677b-4d41-615714ab-b6a6-3d7c
# Name: 2455, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 2510:
# banos    1
# Name: 2510, dtype: object
# baños_completos    2.0
# Name: 2510, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-30002a0c30e6-7a80-f6651e89-9302-4d13
# Name: 2510, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 2603:
# banos    1
# Name: 2603, dtype: object
# baños_completos    6.0
# Name: 2603, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-6b6e82c6da71-e540-f308cd9b-a27b-3e64
# Name: 2603, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 2623:
# banos    2
# Name: 2623, dtype: object
# baños_completos    0.0
# Name: 2623, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-175b8797ae68-adb8-c207b80c-ba28-30e3
# Name: 2623, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 2631:
# banos    1
# Name: 2631, dtype: object
# baños_completos    0.0
# Name: 2631, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-3c82f0d39ab-3635-c54b684d-a3ae-4475
# Name: 2631, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 2654:
# banos    1
# Name: 2654, dtype: object
# baños_completos    3.5
# Name: 2654, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-25e2bc985874-e619-5b2fdd90-bc72-3698
# Name: 2654, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 2658:
# banos    1
# Name: 2658, dtype: object
# baños_completos    0.0
# Name: 2658, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-163eb44a2f36-122f-aa0caf9-9555-4982
# Name: 2658, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 2677:
# banos    1
# Name: 2677, dtype: object
# baños_completos    0.0
# Name: 2677, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-6fe169562924-73c8-d4069bc5-9e17-344f
# Name: 2677, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 2685:
# banos    1
# Name: 2685, dtype: object
# baños_completos    0.0
# Name: 2685, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-a61ac2bfb733-c165-8ac0a757-8799-462f
# Name: 2685, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 2758:
# banos    3
# Name: 2758, dtype: object
# baños_completos    1.0
# Name: 2758, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-b5de9c15a734-7700-cf0b66c9-905f-328e
# Name: 2758, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 2767:
# banos    1
# Name: 2767, dtype: object
# baños_completos    0.0
# Name: 2767, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-6f94edfc37cf-88cc-5e0685e4-b1f9-47ee
# Name: 2767, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 2901:
# banos    5
# Name: 2901, dtype: object
# baños_completos    0.0
# Name: 2901, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-eac6bb37ade9-6fa5-81abbe41-80b7-3e42
# Name: 2901, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 2902:
# banos    1
# Name: 2902, dtype: object
# baños_completos    3.5
# Name: 2902, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-abf59cacd162-e4e-ceac70db-8d4c-31cf
# Name: 2902, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 2987:
# banos    1
# Name: 2987, dtype: object
# baños_completos    0.0
# Name: 2987, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-f4c19132bc91-73c3-40b01e03-979a-3080
# Name: 2987, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 2989:
# banos    3
# Name: 2989, dtype: object
# baños_completos    0.0
# Name: 2989, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-b8f0d57e9590-2a67-cbde93af-8a6a-3c8b
# Name: 2989, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 3054:
# banos    1
# Name: 3054, dtype: object
# baños_completos    0.0
# Name: 3054, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-17538019971d-8068-f9565e19-940d-31e5
# Name: 3054, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 3099:
# banos    4
# Name: 3099, dtype: object
# baños_completos    0.0
# Name: 3099, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-1e4c23eab18f-cf36-e1db5550-a2c0-364d
# Name: 3099, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 3109:
# banos    1
# Name: 3109, dtype: object
# baños_completos    0.0
# Name: 3109, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-8ff9c113cb88-c749-1fdb5535-ba03-4e7c
# Name: 3109, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 3135:
# banos    5
# Name: 3135, dtype: object
# baños_completos    0.0
# Name: 3135, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-16a908d3bf55-748b-2d71be40-a9b7-3fef
# Name: 3135, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 3154:
# banos    1
# Name: 3154, dtype: object
# baños_completos    0.0
# Name: 3154, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-d24c10b55e38-80e5-66cb3bec-8b29-36fd
# Name: 3154, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 3155:
# banos    1
# Name: 3155, dtype: object
# baños_completos    3.5
# Name: 3155, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-9fb07810e62-f0e3-398e92dc-b2b8-30c7
# Name: 3155, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 3164:
# banos    1
# Name: 3164, dtype: object
# baños_completos    0.0
# Name: 3164, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-5162c94cb157-3589-d9345eb0-a684-314b
# Name: 3164, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 3221:
# banos    1
# Name: 3221, dtype: object
# baños_completos    0.0
# Name: 3221, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-1b7765ec29c1-d5dc-f1c3395f-91a7-3e27
# Name: 3221, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 3233:
# banos    1
# Name: 3233, dtype: object
# baños_completos    0.0
# Name: 3233, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-381ac6595599-ab2d-c78299a8-9204-3b9c
# Name: 3233, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 3281:
# banos    3
# Name: 3281, dtype: object
# baños_completos    0.0
# Name: 3281, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-8d1b496b8685-e007-608ddc70-8099-3d71
# Name: 3281, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 3286:
# banos    1
# Name: 3286, dtype: object
# baños_completos    9.0
# Name: 3286, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-f3f4c22386bf-d301-f1f05549-b343-3df4
# Name: 3286, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 3321:
# banos    3
# Name: 3321, dtype: object
# baños_completos    0.0
# Name: 3321, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-8a23014f49d5-c4b3-b24c83ef-9d65-34a9
# Name: 3321, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 3381:
# banos    1
# Name: 3381, dtype: object
# baños_completos    3.0
# Name: 3381, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-bb08859d4a90-2894-fda48353-936f-4c6c
# Name: 3381, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 3390:
# banos    4
# Name: 3390, dtype: object
# baños_completos    0.0
# Name: 3390, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-23521da68416-cc7f-cbbe44b8-a985-3749
# Name: 3390, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 3436:
# banos    1
# Name: 3436, dtype: object
# baños_completos    0.0
# Name: 3436, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-fe6ae7d88a31-1bad-7cb3a288-808e-39a1
# Name: 3436, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 3441:
# banos    1
# Name: 3441, dtype: object
# baños_completos    3.5
# Name: 3441, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-23ac3093f9e1-1afb-51c3d517-b0be-37b0
# Name: 3441, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 3477:
# banos    1
# Name: 3477, dtype: object
# baños_completos    3.0
# Name: 3477, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-f8187db14223-36a5-5fdaeed8-be86-3224
# Name: 3477, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 3495:
# banos    1
# Name: 3495, dtype: object
# baños_completos    0.0
# Name: 3495, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-38225f2fdcfa-7058-440d1408-b1cf-3400
# Name: 3495, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 3557:
# banos    3
# Name: 3557, dtype: object
# baños_completos    0.0
# Name: 3557, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-8307b34890fe-9baf-22629867-a752-3a19
# Name: 3557, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 3606:
# banos    1
# Name: 3606, dtype: object
# baños_completos    3.5
# Name: 3606, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-55910417fdba-6a9-33486daf-b0c1-4490
# Name: 3606, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 3624:
# banos    1
# Name: 3624, dtype: object
# baños_completos    0.0
# Name: 3624, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-a07a98bcca71-d158-f080605a-a4a9-3ac0
# Name: 3624, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 3642:
# banos    2
# Name: 3642, dtype: object
# baños_completos    0.0
# Name: 3642, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-9f31bc543e1-9f61-ba7b696b-b72a-379b
# Name: 3642, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 3648:
# banos    4
# Name: 3648, dtype: object
# baños_completos    0.0
# Name: 3648, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-1df6e297e8c5-2ccf-4d299739-8467-368d
# Name: 3648, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 3695:
# banos    1
# Name: 3695, dtype: object
# baños_completos    0.0
# Name: 3695, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-69219a0e3330-5144-392daa7b-bc26-3c7d
# Name: 3695, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 3712:
# banos    3
# Name: 3712, dtype: object
# baños_completos    5.5
# Name: 3712, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-38f95b1e57ed-1033-feddd240-9255-3a1e
# Name: 3712, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 3729:
# banos    1
# Name: 3729, dtype: object
# baños_completos    2.5
# Name: 3729, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-93f425db615e-c044-afca3b32-863a-3746
# Name: 3729, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 3748:
# banos    4
# Name: 3748, dtype: object
# baños_completos    0.0
# Name: 3748, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-20b5d7a14f6f-c9bd-934ca425-89f1-3abd
# Name: 3748, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 3786:
# banos    4
# Name: 3786, dtype: object
# baños_completos    0.0
# Name: 3786, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-e8253545563f-c279-9c8a2ca-9ca6-32df
# Name: 3786, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 3790:
# banos    3
# Name: 3790, dtype: object
# baños_completos    0.0
# Name: 3790, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-60cdf2d13516-558b-8d5edb69-a9fc-3ee0
# Name: 3790, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 3800:
# banos    1
# Name: 3800, dtype: object
# baños_completos    0.0
# Name: 3800, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-35a0937ceafc-fa2-4b80f4f7-80c4-3d7d
# Name: 3800, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 3877:
# banos    2
# Name: 3877, dtype: object
# baños_completos    3.0
# Name: 3877, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-325bd803ea2d-7464-a1e25950-a2b9-422d
# Name: 3877, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 3950:
# banos    1
# Name: 3950, dtype: object
# baños_completos    0.0
# Name: 3950, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-a36ad8234b82-89b3-f998373c-818a-4c34
# Name: 3950, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 3951:
# banos    1
# Name: 3951, dtype: object
# baños_completos    0.0
# Name: 3951, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-7b52bd8a4d6d-bcbe-ff078c60-a788-488f
# Name: 3951, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 3952:
# banos    1
# Name: 3952, dtype: object
# baños_completos    0.0
# Name: 3952, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-693dff2b0386-f6a3-24e241ee-80dd-4df4
# Name: 3952, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 4001:
# banos    3
# Name: 4001, dtype: object
# baños_completos    2.0
# Name: 4001, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-cdcd15d3455d-f2b4-86854254-91bc-3d3d
# Name: 4001, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 4060:
# banos    1
# Name: 4060, dtype: object
# baños_completos    0.0
# Name: 4060, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-4c135c3023ca-ea1e-50139c9e-ae46-38c3
# Name: 4060, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 4108:
# banos    1
# Name: 4108, dtype: object
# baños_completos    0.0
# Name: 4108, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-c4706d21dbf9-9f72-eca7cb3c-ac21-3dcc
# Name: 4108, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 4110:
# banos    1
# Name: 4110, dtype: object
# baños_completos    0.0
# Name: 4110, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-b0a2e6240cd6-75e5-ca3b0663-9f25-3b9c
# Name: 4110, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 4115:
# banos    4
# Name: 4115, dtype: object
# baños_completos    0.0
# Name: 4115, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-9a4a7a5ffeb7-41e8-4a2a2b4e-9de3-4e4e
# Name: 4115, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 4147:
# banos    4
# Name: 4147, dtype: object
# baños_completos    0.0
# Name: 4147, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-351ea48a26bf-8654-dc02ee24-a37a-36bb
# Name: 4147, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 4196:
# banos    1
# Name: 4196, dtype: object
# baños_completos    0.0
# Name: 4196, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-1f52b3f4d65-10a2-c639a5af-8423-3998
# Name: 4196, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 4253:
# banos    1
# Name: 4253, dtype: object
# baños_completos    0.0
# Name: 4253, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-c8a51191bb58-dc98-72b68300-941c-447e
# Name: 4253, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 4407:
# banos    2
# Name: 4407, dtype: object
# baños_completos    0.0
# Name: 4407, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-8546b1f44055-f475-a3f36f-bdbe-3bf0
# Name: 4407, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 4419:
# banos    1
# Name: 4419, dtype: object
# baños_completos    0.0
# Name: 4419, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-ae0fff79ba3c-1996-896c993d-95e3-3e61
# Name: 4419, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 4430:
# banos    4
# Name: 4430, dtype: object
# baños_completos    0.0
# Name: 4430, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-8e7dadcbd10a-7928-49ded9e9-9391-4930
# Name: 4430, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 4431:
# banos    1
# Name: 4431, dtype: object
# baños_completos    4.0
# Name: 4431, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-6666b534d99c-93e-d98f43e3-9841-3fe7
# Name: 4431, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 4496:
# banos    1
# Name: 4496, dtype: object
# baños_completos    4.5
# Name: 4496, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-ca2829c6cec7-9218-63f6169c-b88d-3298
# Name: 4496, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 4498:
# banos    1
# Name: 4498, dtype: object
# baños_completos    0.0
# Name: 4498, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-a326385500a-9c2b-b4287daf-9f2a-452b
# Name: 4498, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# ...
# Name: 8406, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 8466:
# banos    4
# Name: 8466, dtype: object
# baños_completos    0.0
# Name: 8466, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-29ffa279aa7b-917-40d7c958-a898-31ae
# Name: 8466, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 8512:
# banos    4
# Name: 8512, dtype: object
# baños_completos    0.0
# Name: 8512, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-61e7c263eacc-7f97-225a7bc7-8cbc-3d39
# Name: 8512, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 8567:
# banos    4
# Name: 8567, dtype: object
# baños_completos    0.0
# Name: 8567, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-9cdcca64a108-62bd-feabfe7-8477-3153
# Name: 8567, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 8619:
# banos    4
# Name: 8619, dtype: object
# baños_completos    0.0
# Name: 8619, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-5d2a740f705a-57d3-196c2e9c-a264-3904
# Name: 8619, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 8645:
# banos    4
# Name: 8645, dtype: object
# baños_completos    0.0
# Name: 8645, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-a8880f6413c8-5054-ce8d8082-b840-3da8
# Name: 8645, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 8655:
# banos    4
# Name: 8655, dtype: object
# baños_completos    0.0
# Name: 8655, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-f8d7b83dcd8b-5836-900e73cc-b079-3f05
# Name: 8655, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 8729:
# banos    4
# Name: 8729, dtype: object
# baños_completos    0.0
# Name: 8729, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-192d03dfd899-d4b1-5a145dc9-84f8-4c08
# Name: 8729, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 8739:
# banos    4
# Name: 8739, dtype: object
# baños_completos    0.0
# Name: 8739, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-deb5b29b5a39-2086-e24672ae-9203-3e4f
# Name: 8739, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 8796:
# banos    4
# Name: 8796, dtype: object
# baños_completos    0.0
# Name: 8796, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-2508059d6cb4-d2ef-9616ca88-898f-31dd
# Name: 8796, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 8797:
# banos    4
# Name: 8797, dtype: object
# baños_completos    0.0
# Name: 8797, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-30574cffd8c8-d90-3a2378fb-9324-4038
# Name: 8797, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 8802:
# banos    4
# Name: 8802, dtype: object
# baños_completos    2.0
# Name: 8802, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-efb269c3b939-7202-d9c942f3-8be6-442a
# Name: 8802, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 8807:
# banos    4
# Name: 8807, dtype: object
# baños_completos    0.0
# Name: 8807, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-10140b855147-65d0-77d9d707-a081-35ec
# Name: 8807, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 8809:
# banos    4
# Name: 8809, dtype: object
# baños_completos    0.0
# Name: 8809, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-990116b708bb-b87f-48c33ea4-9dc2-34a0
# Name: 8809, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 8820:
# banos    4
# Name: 8820, dtype: object
# baños_completos    0.0
# Name: 8820, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-dba084047e07-c73a-bddd7b8d-b6fa-386a
# Name: 8820, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 8822:
# banos    4
# Name: 8822, dtype: object
# baños_completos    0.0
# Name: 8822, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-d6cddc7ca082-676c-a81fdfe2-b6bf-3955
# Name: 8822, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 8823:
# banos    4
# Name: 8823, dtype: object
# baños_completos    0.0
# Name: 8823, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-df4589fd6a66-a8c6-efca3927-a263-33f3
# Name: 8823, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 8829:
# banos    4
# Name: 8829, dtype: object
# baños_completos    0.0
# Name: 8829, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-35aa8a4a9751-1533-276d726e-ba83-3fe0
# Name: 8829, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 8847:
# banos    4
# Name: 8847, dtype: object
# baños_completos    0.0
# Name: 8847, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-9214f103d28a-b6f0-22422320-99dd-3b82
# Name: 8847, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 8861:
# banos    4
# Name: 8861, dtype: object
# baños_completos    0.0
# Name: 8861, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-6e8baaa35015-202f-e2d70726-8fe8-316e
# Name: 8861, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 8910:
# banos    5
# Name: 8910, dtype: object
# baños_completos    0.0
# Name: 8910, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-908ffa94aec0-969b-760c2bc0-8ea0-316c
# Name: 8910, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 8959:
# banos    5
# Name: 8959, dtype: object
# baños_completos    0.0
# Name: 8959, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-a602f5758367-2479-52a66b4-ac2a-502a
# Name: 8959, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 8979:
# banos    5
# Name: 8979, dtype: object
# baños_completos    0.0
# Name: 8979, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-d44ad15d9c74-4684-ee11361d-a205-4f65
# Name: 8979, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 8980:
# banos    5
# Name: 8980, dtype: object
# baños_completos    0.0
# Name: 8980, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-1ba5fee63d72-3c22-a6d61bff-bccf-4e80
# Name: 8980, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 8981:
# banos    5
# Name: 8981, dtype: object
# baños_completos    0.0
# Name: 8981, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-c2d024963647-2959-5bf1783d-b160-41fc
# Name: 8981, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 8982:
# banos    5
# Name: 8982, dtype: object
# baños_completos    0.0
# Name: 8982, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-a2f047faf9a2-4a27-34550499-a69d-44c9
# Name: 8982, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 8999:
# banos    5
# Name: 8999, dtype: object
# baños_completos    3.0
# Name: 8999, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-c36043a4a711-ad77-ac7d0c7d-b3d1-43b6
# Name: 8999, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 9000:
# banos    5
# Name: 9000, dtype: object
# baños_completos    3.0
# Name: 9000, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-e9a7d6ade2aa-d326-a216620b-be34-4c2a
# Name: 9000, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 9003:
# banos    5
# Name: 9003, dtype: object
# baños_completos    3.0
# Name: 9003, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-aec8a71e84b5-7a1f-4e7191a9-aeae-4ece
# Name: 9003, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 9037:
# banos    5
# Name: 9037, dtype: object
# baños_completos    0.0
# Name: 9037, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-80258b5dcc4f-db53-4b0676b8-8763-3bcf
# Name: 9037, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 9120:
# banos    5
# Name: 9120, dtype: object
# baños_completos    3.0
# Name: 9120, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-cb8d32683bd0-516c-8f242dd6-b989-3241
# Name: 9120, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 9134:
# banos    5
# Name: 9134, dtype: object
# baños_completos    0.0
# Name: 9134, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-1cb6e95e0bc1-44f4-61762d86-91f5-3235
# Name: 9134, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 9154:
# banos    5
# Name: 9154, dtype: object
# baños_completos    0.0
# Name: 9154, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-f88747ff4a61-36fd-3e8ab050-87de-3aa5
# Name: 9154, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 9166:
# banos    5
# Name: 9166, dtype: object
# baños_completos    0.0
# Name: 9166, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-786b1b1b97b9-282d-1b6e8f7e-a08a-363a
# Name: 9166, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 9188:
# banos    5
# Name: 9188, dtype: object
# baños_completos    0.0
# Name: 9188, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-287f9528609d-3863-6de42d53-ac14-3674
# Name: 9188, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 9255:
# banos    6
# Name: 9255, dtype: object
# baños_completos    0.0
# Name: 9255, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-55ee224bbca7-2e4b-443c8af1-a707-3abe
# Name: 9255, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 9266:
# banos    6
# Name: 9266, dtype: object
# baños_completos    12.0
# Name: 9266, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-69b26b89a98c-6d50-b77dacc9-be44-3fb5
# Name: 9266, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 9271:
# banos    6
# Name: 9271, dtype: object
# baños_completos    2.0
# Name: 9271, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-c26391c201d7-d8c4-b8b377f0-b71d-3f74
# Name: 9271, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 9285:
# banos    6
# Name: 9285, dtype: object
# baños_completos    0.0
# Name: 9285, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-abcff9f31f91-9b42-df0a9f46-965b-364d
# Name: 9285, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 9317:
# banos    7
# Name: 9317, dtype: object
# baños_completos    2.0
# Name: 9317, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-b3dd7ee02da2-77a-8d0d4cd6-a067-3355
# Name: 9317, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 9321:
# banos    8
# Name: 9321, dtype: object
# baños_completos    1.5
# Name: 9321, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-42a5d7276768-fca6-536261bd-b26e-33af
# Name: 9321, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 9327:
# banos    8
# Name: 9327, dtype: object
# baños_completos    0.0
# Name: 9327, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-2ba25b8df524-7fc-97af003c-aa2f-339c
# Name: 9327, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Registro 9332:
# banos    9
# Name: 9332, dtype: object
# baños_completos    0.0
# Name: 9332, dtype: object
# url    https://www.lamudi.com.mx/detalle/41032-73-125ba1cd9739-e9b5-77b6a502-b769-3fcf
# Name: 9332, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'banos' por el de 'baños_completos'
# 3. Pasar al siguiente registro
# Proceso completado.

# %% [markdown]
# ### Medio baños

# %% [markdown]
# #### [0 / 0]

# %% [markdown]
# Poner como mínimo para el registro 1 en baños, pero si cuenta con valor en descripción que se le asigne ese valor.

# %%
# Filtrar los registros según las condiciones dadas
totales = df[(df['medio_baños'] == 0) & (df['medios_baños'].isna())]
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# Iterar sobre los registros filtrados
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    print(row[['url']])
    print("\n¿Qué acción te gustaría realizar?")
    print("1. Sustituir el valor manualmente")
    #print("2. Asignar 1 como mínimo y pasar al siguiente registro")
    print("2. Pasar al siguiente registro")

    # Solicitar la opción al usuario
    option = input("Elige una opción (1 | 2): ")

    if option == '1':
        # Sustituir el valor manualmente
        new_value = input("Introduce el nuevo valor para 'banos': ")
        df.at[idx, 'banos'] = float(new_value)
    #elif option == '2':
        # Asignar valor de 1 como mínimo
        #df.at[idx, 'banos'] = 1
        #continue  # Pasar al siguiente registro
    else:
        continue  # Pasar al siguiente registro

    print("\n---\n")

print("Proceso completado.")
# Out:
# ---------------------------------------------------------------------------
#
# KeyError                                  Traceback (most recent call last)
#
# c:\Users\yoe11\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key)
#
#    3804         try:
#
# -> 3805             return self._engine.get_loc(casted_key)
#
#    3806         except KeyError as err:
#
#
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
#
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
#
#
# pandas\\_libs\\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
#
#
# pandas\\_libs\\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
#
#
# KeyError: 'medio_baños'
#
#
#
# The above exception was the direct cause of the following exception:
#
#
#
# KeyError                                  Traceback (most recent call last)
#
# ~\AppData\Local\Temp\ipykernel_10972\2625185884.py in <module>
#
#       1 # Filtrar los registros según las condiciones dadas
#
# ----> 2 totales = df[(df['medio_baños'] == 0) & (df['medios_baños'].isna())]
#
#       3
#
#       4 # Iterar sobre los registros filtrados
#
#       5 for idx, row in totales.iterrows():
#
#
#
# c:\Users\yoe11\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#
#    4100             if self.columns.nlevels > 1:
#
#    4101                 return self._getitem_multilevel(key)
#
# -> 4102             indexer = self.columns.get_loc(key)
#
#    4103             if is_integer(indexer):
#
#    4104                 indexer = [indexer]
#
#
#
# c:\Users\yoe11\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key)
#
#    3810             ):
#
#    3811                 raise InvalidIndexError(key)
#
# -> 3812             raise KeyError(key) from err
#
#    3813         except TypeError:
#
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
#
#
# KeyError: 'medio_baños'

# %% [markdown]
# #### [0 / #]

# %%
# Filtrar los registros según las condiciones dadas
totales = df[( (df['medio_baños']==0) & (df['medios_baños'].notna()) )] 
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# Iterar sobre los registros filtrados
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    print(row[['url']])
    print("\n¿Qué acción te gustaría realizar?")
    print("1. Sustituir el valor manualmente")
    print("2. Sustituir el valor de 'medio_baños' por el de 'medios_baños'")
    #print("3. Asignar 1 como mínimo y pasar al siguiente registro")
    print("3. Pasar al siguiente registro")

    # Solicitar la opción al usuario
    option = input("Elige una opción (1 | 2 | 3): ")

    if option == '1':
        # Sustituir el valor manualmente
        new_value = input("Introduce el nuevo valor para 'medio_baños': ")
        df.at[idx, 'medio_baños'] = float(new_value)
    elif option == '2':
        # Sustituir el valor de 'medio_baños' por 'medios_baños'
        df.at[idx, 'medio_baños'] = df.at[idx, 'medios_baños']
    #elif option == '3':
        # Asignar valor de 1 como mínimo
        #df.at[idx, 'medio_baños'] = 1
        #continue  # Pasar al siguiente registro
    else:
        continue  # Pasar al siguiente registro

    print("\n---\n")

print("Proceso completado.")

# %% [markdown]
# #### [# / #]

# %%
# Filtrar los registros según las condiciones dadas
totales = df[( ((df['medio_baños']!=0) & (df['medios_baños'].notna())) & (df['medio_baños'] != df['medios_baños']))] 
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# Iterar sobre los registros filtrados
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    print(row[['url']])
    print("\n¿Qué acción te gustaría realizar?")
    print("1. Sustituir el valor manualmente")
    print("2. Sustituir el valor de 'medio_baños' por el de 'medios_baños'")
    #print("3. Asignar 1 como mínimo y pasar al siguiente registro")
    print("3. Pasar al siguiente registro")

    # Solicitar la opción al usuario
    option = input("Elige una opción (1 | 2 | 3): ")

    if option == '1':
        # Sustituir el valor manualmente
        new_value = input("Introduce el nuevo valor para 'medio_baños': ")
        df.at[idx, 'medio_baños'] = float(new_value)
    elif option == '2':
        # Sustituir el valor de 'medio_baños' por 'medios_baños'
        df.at[idx, 'medio_baños'] = df.at[idx, 'medios_baños']
    #elif option == '3':
        # Asignar valor de 1 como mínimo
        #df.at[idx, 'medio_baños'] = 1
        #continue  # Pasar al siguiente registro
    else:
        continue  # Pasar al siguiente registro

    print("\n---\n")

print("Proceso completado.")

# %% [markdown]
# ### B) Total de baños

# %%
# Make the medio_baños and banos sum
# 'medio_baños', divididos entre 2 para representar medios
df['bano_total'] = df['banos'] + (df['medio_banos'] / 2)
df['bano_total'] = df['bano_total'].round(1)  # Round the total, not just 'banos'
print(df[['banos', 'medio_banos', 'bano_total']].head())
# Out:
#    banos  medio_banos  bano_total
# 0      2            1         2.5
# 1      3            1         3.5
# 2      2            1         2.5
# 3      1            0         1.0
# 4      3            0         3.0

# %% [markdown]
# # 10. Ubicación

# %% [markdown]
# ## a) Desde descripción
# #### Todavía en espera de estructura de código

# %%
# Función para extraer ubicación de la descripción
def extraer_ubicacion(descripcion):
    descripcion = descripcion.lower()
    # Patrones para buscar ubicaciones comunes
    patrones = [
        r'(?:ubicad[oa] en|en) ([\w\s]+(?:,\s*[\w\s]+){0,2})',
        r'(?:calle|avenida|av\.) ([\w\s]+(?:,\s*[\w\s]+){0,2})',
        r'(?:colonia|col\.) ([\w\s]+(?:,\s*[\w\s]+){0,2})',
        r'(?:fraccionamiento|fracc\.) ([\w\s]+(?:,\s*[\w\s]+){0,2})'
    ]
    
    for patron in patrones:
        match = re.search(patron, descripcion)
        if match:
            return match.group(1).strip().title()
    
    return None

# Aplicar la función al DataFrame
df['ubicacion_desc'] = df['descripcion'].apply(extraer_ubicacion)

# %%
df['ubicacion_desc'].unique()
# Out:
# array(['Gran Reserva Juriquilla',
#        'La Colonia Cimatario Muy Amplia En Una Excelente Colonia De Queretaro Dentro De Fraccionamiento Privado Con Vigilancia Las 24 Hrs Y Muy Centrica Con Acceso A Avenidas Principales Muy Cerca De Centros Comerciales, Escuelas Y Hospitales, La Casa Cuenta Con',
#        'Fraccionamiento Privado En Av', ..., 'Todos Los Espacios',
#        'Colinas Del Cimatario 535 M2 De Terreno Y 534 M2 De Construcción, Con Excelente Ubicación A Una Cuadra De Boulevard Centro Sur',
#        'Varios Niveles En \xa0Esquina Col'], dtype=object)

# %% [markdown]
# #### Cuando la ubicación dice centro:

# %%
# Filtrar los registros donde la ubicación contiene la palabra "centro"
df_centro = df[df['ubicacion'].str.contains('centro', case=False, na=False)]
num_registros_centro = len(df_centro)

print(f"Número de registros que contienen 'centro' en la ubicación: {num_registros_centro}")
# Out:
# Número de registros que contienen 'centro' en la ubicación: 823

# %%
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# Iterar sobre los registros filtrados
for idx, row in df_centro.iterrows():
    print(f"Registro {idx}:")
    print(row[['ubicacion', 'ubicacion_desc', 'url']])
    print("\n¿Qué acción te gustaría realizar?")
    print("1. Sustituir el valor manualmente")
    print("2. Sustituir el valor de 'ubicacion' por el de 'ubicacion_desc'")
    print("3. Pasar al siguiente registro")

    # Solicitar la opción al usuario
    option = input("Elige una opción (1, 2, 3): ")

    if option == '1':
        # Sustituir el valor manualmente
        new_value = input("Introduce el nuevo valor para 'ubicacion': ")
        df.at[idx, 'ubicacion'] = new_value  
    elif option == '2':
        # Sustituir el valor de 'ubicacion' por 'ubicacion_desc'
        df.at[idx, 'ubicacion'] = df.at[idx, 'ubicacion_desc']
    elif option == '3':
        # Pasar al siguiente registro
        continue
    else:
        print("Opción no válida. Pasando al siguiente registro...")
    
    print("\n---\n")

print("Proceso completado.")
# Out:
# Registro 5:
# ubicacion                                          Residencial Centro Sur Condominio I, Querétaro, Querétaro
# ubicacion_desc    Cuanto A La Propiedad En Sí, Cuenta Con Todo Lo Que Necesitas Y Más Para Vivir Cómodamente
# url                         https://www.lamudi.com.mx//detalle/41032-73-5b038591d2b2-2867-4a0a3194-ae81-4856
# Name: 5, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'ubicacion' por el de 'ubicacion_desc'
# 3. Pasar al siguiente registro
# ---
#
# Registro 28:
# ubicacion                                                   Querétaro Centro, Querétaro, Querétaro
# ubicacion_desc                                                                                None
# url               https://www.lamudi.com.mx//detalle/41032-73-17a1b1c74088-3e68-be5ac63a-b459-4288
# Name: 28, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'ubicacion' por el de 'ubicacion_desc'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 117:
# ubicacion                                                   Querétaro Centro, Querétaro, Querétaro
# ubicacion_desc                            Bienes Raíces De Kioto Service Y Asegura Tu Futuro Hogar
# url               https://www.lamudi.com.mx//detalle/41032-73-e1bcd19eec35-4036-b7fad8f4-b9a1-4f12
# Name: 117, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'ubicacion' por el de 'ubicacion_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 128:
# ubicacion                                                  Querétaro Centro, Querétaro, Querétaro
# ubicacion_desc                                                                            Privada
# url               https://www.lamudi.com.mx/detalle/41032-73-29e46c386a29-d5c3-b0d2aaa0-a297-49a7
# Name: 128, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'ubicacion' por el de 'ubicacion_desc'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 155:
# ubicacion                                                  Querétaro Centro, Querétaro, Querétaro
# ubicacion_desc                    Una Excelente Ubicacion, Cerca De Centros Comerciales, Mercados
# url               https://www.lamudi.com.mx/detalle/41032-73-32623d5fcfaf-6529-2dc241d7-bb03-477f
# Name: 155, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'ubicacion' por el de 'ubicacion_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 250:
# ubicacion                                                   Colonia Centro, Querétaro, Querétaro
# ubicacion_desc                  Excelente Estado Y Buen Retorno Capital Para  Inversión  O Vivir
# url               https://www.lamudi.com.mx//detalle/41032-73-e8c6942abb29-df-5e91a873-84d2-3cd1
# Name: 250, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'ubicacion' por el de 'ubicacion_desc'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 335:
# ubicacion                                                  Querétaro Centro, Querétaro, Querétaro
# ubicacion_desc                                                                               None
# url               https://www.lamudi.com.mx//detalle/41032-73-eb83d4fef17-d68a-68792966-bfe8-4b82
# Name: 335, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'ubicacion' por el de 'ubicacion_desc'
# 3. Pasar al siguiente registro
#
# ---
#
# Registro 363:
# ubicacion                                                  Querétaro Centro, Querétaro, Querétaro
# ubicacion_desc                                    Esquina, Cuenta Con Pasillo Lateral De Servicio
# url               https://www.lamudi.com.mx/detalle/41032-73-e18de82e345b-3183-6826afb4-9398-3380
# Name: 363, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'ubicacion' por el de 'ubicacion_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro
dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'ubicacion' por el de 'ubicacion_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 9342:
# ubicacion                                                                                                       Centro Sur, Querétaro, Querétaro
# ubicacion_desc    Colinas Del Cimatario 535 M2 De Terreno Y 534 M2 De Construcción, Con Excelente Ubicación A Una Cuadra De Boulevard Centro Sur
# url                                                              https://www.lamudi.com.mx//detalle/41032-73-ad1150ed5b6-de73-7ad161aa-b0d8-3525
# Name: 9342, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Sustituir el valor manualmente
# 2. Sustituir el valor de 'ubicacion' por el de 'ubicacion_desc'
# 3. Pasar al siguiente registro
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Proceso completado.

# %% [markdown]
# ## b) Separación

# %% [markdown]
# Se divide la ubicación por
# * Colonia
# * Municipio
# * Estado

# %%
# Dividir 'ubicacion' en un máximo de 3 partes y manejar valores faltantes
df[['Colonia', 'Municipio', 'Estado']] = df['ubicacion'].str.split(',', expand=True, n=2)

# Limpiar espacios alrededor de los valores
df['Colonia'] = df['Colonia'].str.strip()
df['Municipio'] = df['Municipio'].str.strip()
df['Estado'] = df['Estado'].str.strip()

# Rellenar valores NaN o faltantes con valores predeterminados específicos
df['Colonia'] = df['Colonia'].fillna('Sin_colonia')
df['Municipio'] = df['Municipio'].fillna('Sin_municipio')
df['Estado'] = df['Estado'].fillna('Sin_estado')
df[['ubicacion', 'Colonia', 'Municipio', 'Estado']]
# Out:
#                                                    ubicacion  \
# 0           Fraccionamiento San Isidro, Querétaro, Querétaro
# 1                            Cimatario, Querétaro, Querétaro
# 2                           El Refugio, Querétaro, Querétaro
# 3                   Andadores Satélite, Querétaro, Querétaro
# 4     Fraccionamiento Juriquilla Grand, Querétaro, Querétaro
# ...                                                      ...
# 9339     Fraccionamiento El Campanario, Querétaro, Querétaro
# 9340     Fraccionamiento El Campanario, Querétaro, Querétaro
# 9341     Fraccionamiento El Campanario, Querétaro, Querétaro
# 9342                        Centro Sur, Querétaro, Querétaro
# 9343                      Niños Héroes, Querétaro, Querétaro
#
#                                Colonia  Municipio     Estado
# 0           Fraccionamiento San Isidro  Querétaro  Querétaro
# 1                            Cimatario  Querétaro  Querétaro
# 2                           El Refugio  Querétaro  Querétaro
# 3                   Andadores Satélite  Querétaro  Querétaro
# 4     Fraccionamiento Juriquilla Grand  Querétaro  Querétaro
# ...                                ...        ...        ...
# 9339     Fraccionamiento El Campanario  Querétaro  Querétaro
# 9340     Fraccionamiento El Campanario  Querétaro  Querétaro
# 9341     Fraccionamiento El Campanario  Querétaro  Querétaro
# 9342                        Centro Sur  Querétaro  Querétaro
# 9343                      Niños Héroes  Querétaro  Querétaro
#
# [9344 rows x 4 columns]

# %% [markdown]
# #### Separación de tipo de lugar del nombre de la colonia

# %%
tipos = ['Condominio', 'Fraccionamiento', 'Residencial', 'Colonia']
def obtener_tipo_lugar(nombre):
    for tipo in tipos:
        if tipo in nombre:
            return tipo
    return None

df['TIPO_LUGAR'] = df['Colonia'].apply(obtener_tipo_lugar)
# Eliminar el tipo de lugar de la columna 'colonia'
df['Colonia'] = df.apply(lambda row: row['Colonia'].replace(row['TIPO_LUGAR'], '').strip() if row['TIPO_LUGAR'] else row['Colonia'], axis=1)
print(df[['Colonia','TIPO_LUGAR','ubicacion']])
# Out:
#                  Colonia       TIPO_LUGAR  \
# 0             San Isidro  Fraccionamiento
# 1              Cimatario             None
# 2             El Refugio             None
# 3     Andadores Satélite             None
# 4       Juriquilla Grand  Fraccionamiento
# ...                  ...              ...
# 9339       El Campanario  Fraccionamiento
# 9340       El Campanario  Fraccionamiento
# 9341       El Campanario  Fraccionamiento
# 9342          Centro Sur             None
# 9343        Niños Héroes             None
#
#                                                    ubicacion
# 0           Fraccionamiento San Isidro, Querétaro, Querétaro
# 1                            Cimatario, Querétaro, Querétaro
# 2                           El Refugio, Querétaro, Querétaro
# 3                   Andadores Satélite, Querétaro, Querétaro
# 4     Fraccionamiento Juriquilla Grand, Querétaro, Querétaro
# ...                                                      ...
# 9339     Fraccionamiento El Campanario, Querétaro, Querétaro
# 9340     Fraccionamiento El Campanario, Querétaro, Querétaro
# 9341     Fraccionamiento El Campanario, Querétaro, Querétaro
# 9342                        Centro Sur, Querétaro, Querétaro
# 9343                      Niños Héroes, Querétaro, Querétaro
#
# [9344 rows x 3 columns]

# %% [markdown]
# ## c) Estandarizar valores Colonia

# %%
# Convierte todos los valores a strings, maneja NaN o None como cadenas vacías
df['Colonia'] = df['Colonia'].astype(str)
# Convertir a minúsculas
df['Colonia'] = df['Colonia'].str.lower()

import unicodedata# Función para eliminar acentos
def eliminar_acentos(texto):
    # Normaliza y elimina los acentos
    texto_normalizado = unicodedata.normalize('NFKD', texto)
    return ''.join(char for char in texto_normalizado if unicodedata.category(char) != 'Mn')

# Aplicar la función de eliminación de acentos
df['Colonia'] = df['Colonia'].apply(eliminar_acentos)

# Reemplazar Ñ
df['Colonia'] = df['Colonia'].str.replace('ñ', 'n')
df['Colonia'] = df['Colonia'].str.replace(r'[^a-zA-Z0-9\s]', '', regex=True)

# %% [markdown]
# ## d) Mapeo de CP y tipo de lugar por diccionario

# %%
# Cargar todas las hojas del archivo Excel en un diccionario de DataFrames
ruta_excel = 'D:\yoe11\Documents\TESEO\Modelo Factible\Scraplining\oficial\cp_dictionary.xlsx'  
hojas = pd.read_excel(ruta_excel, sheet_name=None)

# Obtener combinaciones únicas de Estado, Municipio y Colonia
combinaciones_unicas = df[['Estado', 'Municipio', 'Colonia']].drop_duplicates()

# Crear un diccionario para almacenar los códigos postales y tipos de asentamiento encontrados
codigos_postales = {}
tipos_asentamiento = {}

# Buscar el código postal y tipo de asentamiento para cada combinación única
for _, row in combinaciones_unicas.iterrows():
    estado = row['Estado'].strip()
    municipio = row['Municipio'].strip()
    colonia = row['Colonia'].strip()

    # Verificar si el estado existe en las hojas del Excel
    if estado in hojas:
        df_estado = hojas[estado]

        # Filtrar por municipio y colonia
        df_filtrado = df_estado[
            (df_estado['D_mnpio'].str.strip().str.lower() == municipio.lower()) &
            (df_estado['d_asenta'].str.strip().str.lower() == colonia.lower())
        ]

        # Si hay coincidencias, almacenar el primer código postal y tipo de asentamiento en los diccionarios
        if not df_filtrado.empty:
            codigos_postales[(estado, municipio, colonia)] = df_filtrado['d_codigo'].iloc[0]
            tipos_asentamiento[(estado, municipio, colonia)] = df_filtrado['d_tipo_asenta'].iloc[0]
        else:
            codigos_postales[(estado, municipio, colonia)] = None
            tipos_asentamiento[(estado, municipio, colonia)] = None
    else:
        codigos_postales[(estado, municipio, colonia)] = None
        tipos_asentamiento[(estado, municipio, colonia)] = None

# Crear columnas 'Codigo_Postal' y 'Tipo_Asentamiento' en el DataFrame original usando los diccionarios
df['Codigo_Postal'] = df.apply(lambda x: codigos_postales.get((x['Estado'].strip(), x['Municipio'].strip(), x['Colonia'].strip())), axis=1)
df['Tipo_Asentamiento'] = df.apply(lambda x: tipos_asentamiento.get((x['Estado'].strip(), x['Municipio'].strip(), x['Colonia'].strip())), axis=1)

# Obtener las combinaciones únicas de las columnas 'Colonia', 'Municipio', 'Estado', 'Codigo_Postal', 'Tipo_Asentamiento'
combinaciones_unicas = df[['Colonia', 'Municipio', 'Estado', 'Codigo_Postal', 'Tipo_Asentamiento']].drop_duplicates()
for idx, row in combinaciones_unicas.iterrows():
    print(f"Combinación {idx + 1}:")
    print(f"Colonia: {row['Colonia']}, Municipio: {row['Municipio']}, Estado: {row['Estado']}, Codigo_Postal: {row['Codigo_Postal']}, Tipo_Asentamiento: {row['Tipo_Asentamiento']}")
    print("---")
# Out:
# Combinación 1:
# Colonia: san isidro, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76226.0, Tipo_Asentamiento: Fraccionamiento
# ---
# Combinación 2:
# Colonia: cimatario, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76030.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 3:
# Colonia: el refugio, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 4:
# Colonia: andadores satelite, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 5:
# Colonia: juriquilla grand, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 6:
# Colonia: el mirador, Municipio: El Marqués, Estado: Querétaro Arteaga, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 7:
# Colonia: parque santiago, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76115.0, Tipo_Asentamiento: Fraccionamiento
# ---
# Combinación 8:
# Colonia: felipe carrillo puerto, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76138.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 10:
# Colonia: fracc mision cimatario, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 11:
# Colonia: monte blanco iii, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76087.0, Tipo_Asentamiento: Fraccionamiento
# ---
# Combinación 12:
# Colonia: milenio 3ra seccion, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 13:
# Colonia: juriquilla santa fe, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76230.0, Tipo_Asentamiento: Fraccionamiento
# ---
# Combinación 14:
# Colonia: fracc jurica san francisco, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 15:
# Colonia: sendero del sol, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 17:
# Colonia: jurica, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76100.0, Tipo_Asentamiento: Pueblo
# ---
# Combinación 18:
# Colonia: cumbres del lago, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76230.0, Tipo_Asentamiento: Fraccionamiento
# ---
# Combinación 19:
# Colonia: villas del meson, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 20:
# Colonia: queretaro, Municipio: Querétaro, Estado: Sin_estado, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 21:
# Colonia: fracc las quintas 3ra seccion, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 26:
# Colonia: loma ix, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76116.0, Tipo_Asentamiento: Fraccionamiento
# ---
# Combinación 27:
# Colonia: quintas del marques, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 28:
# Colonia: geo plazas, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76116.0, Tipo_Asentamiento: Fraccionamiento
# ---
# Combinación 29:
# Colonia: cumbres del lago, Municipio: Juriquilla, Estado: Querétaro Arteaga, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 30:
# Colonia: lomas de san pedrito penuelas, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 31:
# Colonia: mansiones del valle, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76185.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 36:
# Colonia: san pedro martir, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 38:
# Colonia: colinas del cimatario, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76090.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 39:
# Colonia: cond hacienda mompani gardenia, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 42:
# Colonia: la joya iii seccion, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 43:
# Colonia: privada juriquilla, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 53:
# Colonia: montenegro, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76220.0, Tipo_Asentamiento: Pueblo
# ---
# Combinación 54:
# Colonia: villas de santiago, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76148.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 56:
# Colonia: hacienda santa rosa, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76223.0, Tipo_Asentamiento: Fraccionamiento
# ---
# Combinación 57:
# Colonia: real de juriquilla, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76226.0, Tipo_Asentamiento: Fraccionamiento
# ---
# Combinación 60:
# Colonia: jardines de la hacienda, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76180.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 62:
# Colonia: loma bonita, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76049.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 70:
# Colonia: eduardo escoto aizcorbe, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 75:
# Colonia: antonio margil de jesus, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 76:
# Colonia: fracc eduardo loarca castillo, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 78:
# Colonia: la joya, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76180.0, Tipo_Asentamiento: Fraccionamiento
# ---
# Combinación 83:
# Colonia: villas la solana, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 84:
# Colonia: punta juriquilla, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76230.0, Tipo_Asentamiento: Fraccionamiento
# ---
# Combinación 103:
# Colonia: fracc juriquilla hacienda grande, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 104:
# Colonia: paraiso diamante, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 108:
# Colonia: punta norte, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 114:
# Colonia: fracc villas de san antonio, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 115:
# Colonia: plazas del sol 2da seccion, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 118:
# Colonia: queretaro centro, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 125:
# Colonia: loma linda, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76070.0, Tipo_Asentamiento: Fraccionamiento
# ---
# Combinación 128:
# Colonia: cuesta bonita, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76063.0, Tipo_Asentamiento: Fraccionamiento
# ---
# Combinación 137:
# Colonia: las teresas, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76138.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 144:
# Colonia: villas del parque, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76140.0, Tipo_Asentamiento: Fraccionamiento
# ---
# Combinación 146:
# Colonia: reforma agraria, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 154:
# Colonia: galindas, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 155:
# Colonia: fracc vista alegre 2da secc, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 166:
# Colonia: el mirador, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76134.0, Tipo_Asentamiento: Fraccionamiento
# ---
# Combinación 167:
# Colonia: lazaro cardenas, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 171:
# Colonia: chula vista ii, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76116.0, Tipo_Asentamiento: Condominio
# ---
# Combinación 175:
# Colonia: villas palmira, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76146.0, Tipo_Asentamiento: Fraccionamiento
# ---
# Combinación 178:
# Colonia: villas del rincon, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 179:
# Colonia: belen, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 183:
# Colonia: misiones 3, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 187:
# Colonia: rancho santa catarina, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 190:
# Colonia: fracc san pablo tecnologico, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 191:
# Colonia: carretas, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76050.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 193:
# Colonia: vista azul, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76087.0, Tipo_Asentamiento: Fraccionamiento
# ---
# Combinación 206:
# Colonia: ensueno, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 213:
# Colonia: las plazas, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76140.0, Tipo_Asentamiento: Condominio
# ---
# Combinación 221:
# Colonia: fracc claustro misiones ii, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 222:
# Colonia: la huerta, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76114.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 223:
# Colonia: exhacienda el tintero, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 225:
# Colonia: la gloria, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 226:
# Colonia: la vista 9, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 230:
# Colonia: lomas de casa blanca, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76080.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 232:
# Colonia: jurica misiones, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76226.0, Tipo_Asentamiento: Fraccionamiento
# ---
# Combinación 238:
# Colonia: la florida, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76150.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 240:
# Colonia: jurica acueducto, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76230.0, Tipo_Asentamiento: Fraccionamiento
# ---
# Combinación 251:
# Colonia: santa rosa de jauregui, Municipio: Querétaro, Estado: Querétaro Arteaga, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 259:
# Colonia: jardines de queretaro, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 273:
# Colonia: ejido modelo, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 277:
# Colonia: rancho bellavista, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76134.0, Tipo_Asentamiento: Fraccionamiento
# ---
# Combinación 281:
# Colonia: privada jurica, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 295:
# Colonia: fracc jard de villas de santiago, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 299:
# Colonia: arboledas, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76140.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 302:
# Colonia: el rosario, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76178.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 303:
# Colonia: fracc san pedrito los arcos, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 319:
# Colonia: colinas de santa cruz 1ra seccion, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 322:
# Colonia: la toscana, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 324:
# Colonia: geo villas, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76116.0, Tipo_Asentamiento: Fraccionamiento
# ---
# Combinación 329:
# Colonia: fracc villas de san miguel, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 333:
# Colonia: san jose el alto, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 335:
# Colonia: el carrizal, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76030.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 336:
# Colonia: jardines de la hacienda, Municipio: Santiago de Querétaro, Estado: Querétaro Arteaga, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 338:
# Colonia: los vinedos, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 339:
# Colonia: sonterra, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76235.0, Tipo_Asentamiento: Fraccionamiento
# ---
# Combinación 341:
# Colonia: cerrito colorado, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76116.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 342:
# Colonia: fracc josefa ortiz de dominguez, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 349:
# Colonia: la loma, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76116.0, Tipo_Asentamiento: Fraccionamiento
# ---
# Combinación 354:
# Colonia: unidad habitacional real del parque, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 355:
# Colonia: fracc pedregal de vista hermosa, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 356:
# Colonia: las haciendas, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 358:
# Colonia: lomas de queretaro, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 359:
# Colonia: el jacal, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76180.0, Tipo_Asentamiento: Fraccionamiento
# ---
# Combinación 361:
# Colonia: el arcangel, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 370:
# Colonia: paseo del piropo, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76230.0, Tipo_Asentamiento: Fraccionamiento
# ---
# Combinación 381:
# Colonia: real del marques, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 383:
# Colonia: fracc claustros del parque, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 388:
# Colonia: fracc valle de santiago sector 3, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 389:
# Colonia: luz del sol, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 400:
# Colonia: ciudad del sol, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76116.0, Tipo_Asentamiento: Fraccionamiento
# ---
# Combinación 425:
# Colonia: zona industrial la montana, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 428:
# Colonia: penuelas, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 431:
# Colonia: quintas la loma, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 440:
# Colonia: lomas del marques, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 441:
# Colonia: fracc josefa ortiz de dguez 2da sec, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 442:
# Colonia: presidentes, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76080.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 447:
# Colonia: colinas de menchaca, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76147.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 449:
# Colonia: ciudad de queretaro, Municipio: Querétaro, Estado: Querétaro Arteaga, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 457:
# Colonia: caletto, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76230.0, Tipo_Asentamiento: Fraccionamiento
# ---
# Combinación 465:
# Colonia: el sabino, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 476:
# Colonia: altozano el nuevo queretaro, Municipio: Querétaro, Estado: Querétaro Arteaga, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 479:
# Colonia: vida 21 coto club, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 480:
# Colonia: azucenas, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 482:
# Colonia: llanura, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 487:
# Colonia: unidad condominal valle, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 497:
# Colonia: el tintero, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76134.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 502:
# Colonia: mision de carrillo, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 513:
# Colonia: puerta navarra, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76116.0, Tipo_Asentamiento: Fraccionamiento
# ---
# Combinación 515:
# Colonia: jardines del valle, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76137.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 540:
# Colonia: hacienda galindo, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76177.0, Tipo_Asentamiento: Fraccionamiento
# ---
# Combinación 542:
# Colonia: bosques del acueducto, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76020.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 570:
# Colonia: desarrollo san pablo, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76125.0, Tipo_Asentamiento: Unidad habitacional
# ---
# Combinación 571:
# Colonia: tlacote el bajo, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76229.0, Tipo_Asentamiento: Pueblo
# ---
# Combinación 573:
# Colonia: menchaca i, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76147.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 574:
# Colonia: exhacienda santana, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 579:
# Colonia: club campestre, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76190.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 584:
# Colonia: fracc mision del mayorazgo, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 603:
# Colonia: fracc colinas del poniente, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 609:
# Colonia: fracc jardines de santiago, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 614:
# Colonia: paseos del pedregal, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76148.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 619:
# Colonia: el rocio, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76114.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 625:
# Colonia: puerta verona, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76235.0, Tipo_Asentamiento: Fraccionamiento
# ---
# Combinación 629:
# Colonia: margaritas, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76125.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 632:
# Colonia: hercules, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 657:
# Colonia: fracc quintas de la hacienda, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 667:
# Colonia: santa monica, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 668:
# Colonia: fracc provincia santa elena, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 670:
# Colonia: vistana, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76147.0, Tipo_Asentamiento: Fraccionamiento
# ---
# Combinación 693:
# Colonia: el marques, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 694:
# Colonia: rinconada la capilla, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76177.0, Tipo_Asentamiento: Fraccionamiento
# ---
# Combinación 698:
# Colonia: el campanario, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76146.0, Tipo_Asentamiento: Fraccionamiento
# ---
# Combinación 702:
# Colonia: real de espana, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 708:
# Colonia: valle de santiago, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 709:
# Colonia: satelite, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 713:
# Colonia: los faroles, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76158.0, Tipo_Asentamiento: Fraccionamiento
# ---
# Combinación 729:
# Colonia: san pedrito penuelas i, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 734:
# Colonia: el sol, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76113.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 744:
# Colonia: colinas de santa cruz 2da seccion, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 750:
# Colonia: fracc cerrito colorado vii, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 751:
# Colonia: loma viii, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 760:
# Colonia: cosmos satelite, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 761:
# Colonia: del valle, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76137.0, Tipo_Asentamiento: Fraccionamiento
# ---
# Combinación 769:
# Colonia: barrio la cruz, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 773:
# Colonia: loma dorada, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76060.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 784:
# Colonia: la estacion, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 796:
# Colonia: privalia ambienta, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76147.0, Tipo_Asentamiento: Fraccionamiento
# ---
# Combinación 803:
# Colonia: mision del mayorazgo, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 814:
# Colonia: urbivilla del real, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 829:
# Colonia: la loma vi, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 841:
# Colonia: los candiles, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 842:
# Colonia: plazas del sol, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 844:
# Colonia: jurica toliman, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 859:
# Colonia: colinas del sur, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76085.0, Tipo_Asentamiento: Fraccionamiento
# ---
# Combinación 883:
# Colonia: la mesita, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 887:
# Colonia: centro, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76000.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 894:
# Colonia: fundadores, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76117.0, Tipo_Asentamiento: Fraccionamiento
# ---
# Combinación 895:
# Colonia: san isidro, Municipio: Juriquilla, Estado: Querétaro, Querétaro Arteaga, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 896:
# Colonia: fracc sendas el naranjo, Municipio: Juriquilla, Estado: Queretaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 897:
# Colonia: fracc eucaliptos 2da seccion, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 933:
# Colonia: fracc tres cantos, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 941:
# Colonia: fracc arboledas, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 942:
# Colonia: santa maria magdalena, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 954:
# Colonia: el granjenal, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 1014:
# Colonia: bosques del cimatario, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76085.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 1017:
# Colonia: constituyentes, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76147.0, Tipo_Asentamiento: Fraccionamiento
# ---
# Combinación 1036:
# Colonia: comerciantes, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76087.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 1038:
# Colonia: fracc palmares de queretaro, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 1096:
# Colonia: la era, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76150.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 1123:
# Colonia: magisterial, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76180.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 1148:
# Colonia: el faro, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 1201:
# Colonia: campestre, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 1205:
# Colonia: santiago de queretaro, Municipio: Querétaro, Estado: Sin_estado, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 1220:
# Colonia: zona industrial benito juarez, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 1229:
# Colonia: carolina, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76177.0, Tipo_Asentamiento: Fraccionamiento
# ---
# Combinación 1267:
# Colonia: el marques queretano, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 1278:
# Colonia: el retablo, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76154.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 1307:
# Colonia: ninos heroes, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 1309:
# Colonia: industrial el fenix, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 1322:
# Colonia: mision del parque, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 1341:
# Colonia: tonatiu, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 1365:
# Colonia: italia, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 1368:
# Colonia: barrio la estacion, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 1404:
# Colonia: fracc claustros del campestre, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 1411:
# Colonia: alta rica, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 1416:
# Colonia: centro sur, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76090.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 1429:
# Colonia: valle de juriquilla, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76100.0, Tipo_Asentamiento: Fraccionamiento
# ---
# Combinación 1443:
# Colonia: fracc altavista juriquilla, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 1458:
# Colonia: los almendros, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 1482:
# Colonia: paseo davinci, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 1508:
# Colonia: cantalagua, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 1516:
# Colonia: santiago, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76120.0, Tipo_Asentamiento: Parque industrial
# ---
# Combinación 1544:
# Colonia: fracc privada de los portones, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 1559:
# Colonia: la pradera, Municipio: El Marqués, Estado: Querétaro, Codigo_Postal: 76269.0, Tipo_Asentamiento: Fraccionamiento
# ---
# Combinación 1585:
# Colonia: de los alamos, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 1600:
# Colonia: barrio juriquilla, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 1647:
# Colonia: fracc juriquilla, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 1652:
# Colonia: plaza del parque, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76169.0, Tipo_Asentamiento: Zona comercial
# ---
# Combinación 1669:
# Colonia: fracc la canada juriquilla, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 1688:
# Colonia: la cima, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76146.0, Tipo_Asentamiento: Fraccionamiento
# ---
# Combinación 1690:
# Colonia: los naranjos ii, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 1695:
# Colonia: balcones les, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 1713:
# Colonia: vista hermosa, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76063.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 1728:
# Colonia: fracc wise living departamentos, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 1744:
# Colonia: universo 2000, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76085.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 1783:
# Colonia: fracc lomas del campanario iii, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 1786:
# Colonia: lomas del campanario ii, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76146.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 1788:
# Colonia: villas del sur, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76040.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 1799:
# Colonia: res centro sur  ii, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 1844:
# Colonia: raquet club, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76127.0, Tipo_Asentamiento: Fraccionamiento
# ---
# Combinación 1846:
# Colonia: nuevo paraiso, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 1862:
# Colonia: villas del sol, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76046.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 1872:
# Colonia: miradores, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 1890:
# Colonia: fracc club  los encinos, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 1897:
# Colonia: bolanos, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 2007:
# Colonia: rincon del lago, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 2014:
# Colonia: palmas v, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 2016:
# Colonia: fracc juriquilla tabachines, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 2027:
# Colonia: arboledas del parque, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76140.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 2047:
# Colonia: alamos 3ra seccion, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 2192:
# Colonia: altos del marques, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 2198:
# Colonia: los fresnos, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76150.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 2202:
# Colonia: las americas 3ra seccion, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 2222:
# Colonia: la campana, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 2261:
# Colonia: rancho largo, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76230.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 2293:
# Colonia: jardines de san jose 4ta seccion, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 2305:
# Colonia: la condesa, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76125.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 2308:
# Colonia: plazas del sol 3ra seccion, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 2311:
# Colonia: fracc rincon de san antonio, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 2339:
# Colonia: bosques, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 2393:
# Colonia: jardines de juriquilla, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 2474:
# Colonia: el bosque, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76069.0, Tipo_Asentamiento: Fraccionamiento
# ---
# Combinación 2560:
# Colonia: los girasoles, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76159.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 2561:
# Colonia: fracc  parque del alamo, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 2635:
# Colonia: puerta del cielo, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76144.0, Tipo_Asentamiento: Fraccionamiento
# ---
# Combinación 2875:
# Colonia: catena, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 2967:
# Colonia: fracc gran puerta paraiso ii, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 3072:
# Colonia: bosques de las lomas, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76087.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 3084:
# Colonia: los olivos, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 3088:
# Colonia: fracc virreyes, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 3101:
# Colonia: fracc miradores del marques, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 3112:
# Colonia: quinta la laborcilla, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76168.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 3150:
# Colonia: conjunto habitacional casa hermosa, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 3156:
# Colonia: villas del oriente, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76063.0, Tipo_Asentamiento: Fraccionamiento
# ---
# Combinación 3161:
# Colonia: fracc rinconada santini juriquilla, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 3191:
# Colonia: ecologico la rica, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 3198:
# Colonia: las misiones, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76030.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 3203:
# Colonia: villas de guadalupe, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76116.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 3204:
# Colonia: las fuentes, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76030.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 3208:
# Colonia: las rosas, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76164.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 3250:
# Colonia: prados del mirador, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76070.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 3260:
# Colonia: residencial centro sur  i, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 3286:
# Colonia: santa fe, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76147.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 3318:
# Colonia: res centro sur  iii, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 3339:
# Colonia: mayoral 2, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 3401:
# Colonia: rincon del cimatario, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 3436:
# Colonia: la alhambra, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76074.0, Tipo_Asentamiento: Fraccionamiento
# ---
# Combinación 3463:
# Colonia: monte real, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 3468:
# Colonia: fracc balcones de juriquilla, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 3522:
# Colonia: fracc colinas de juriquilla, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 3546:
# Colonia: las hadas, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76160.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 3558:
# Colonia: casa blanca, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76030.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 3598:
# Colonia: arquitos, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76048.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 3619:
# Colonia: san pedrito penuelas i el carmen, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 3636:
# Colonia: campestre italiana, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76087.0, Tipo_Asentamiento: Fraccionamiento
# ---
# Combinación 3638:
# Colonia: fracc huertas del cimatario, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 3642:
# Colonia: pathe, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 3689:
# Colonia: los claustros, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76165.0, Tipo_Asentamiento: Fraccionamiento
# ---
# Combinación 3701:
# Colonia: fracc  santorini, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 3721:
# Colonia: puerta paraiso, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 3752:
# Colonia: privada arboledas, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76140.0, Tipo_Asentamiento: Fraccionamiento
# ---
# Combinación 3809:
# Colonia: claustros del sur, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76093.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 3821:
# Colonia: constelacion, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 3823:
# Colonia: el prado, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76030.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 3875:
# Colonia: puerta de hierro, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 3883:
# Colonia: felipe angeles, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 3919:
# Colonia: altozano, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 3981:
# Colonia: lomas de juriquilla, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76226.0, Tipo_Asentamiento: Fraccionamiento
# ---
# Combinación 4013:
# Colonia: claustro de la corregidora 1ra sec, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 4099:
# Colonia: san geronimo, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 4104:
# Colonia: universidad, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76028.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 4105:
# Colonia: alamos 1ra seccion, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 4107:
# Colonia: privada bugambilias, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76160.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 4149:
# Colonia: fracc fuentes de la villa rica, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 4193:
# Colonia: generacion 2000, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 4314:
# Colonia: provincia santa elena, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76177.0, Tipo_Asentamiento: Fraccionamiento
# ---
# Combinación 4318:
# Colonia: la cruz, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76000.0, Tipo_Asentamiento: Fraccionamiento
# ---
# Combinación 4499:
# Colonia: fracc lomas del campanario i, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 4697:
# Colonia: jurica pinar, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76100.0, Tipo_Asentamiento: Fraccionamiento
# ---
# Combinación 4778:
# Colonia: barrio la haciendita, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 4785:
# Colonia: colinas del parque, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76140.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 4979:
# Colonia: el nabo, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76229.0, Tipo_Asentamiento: Pueblo
# ---
# Combinación 5049:
# Colonia: juriquilla, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76226.0, Tipo_Asentamiento: Pueblo
# ---
# Combinación 5077:
# Colonia: bellavista, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76087.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 5402:
# Colonia: el capricho 2, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 5493:
# Colonia: habitarea homes, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 5634:
# Colonia: insurgentes, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76117.0, Tipo_Asentamiento: Fraccionamiento
# ---
# Combinación 5637:
# Colonia: balcones, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 5782:
# Colonia: paseo bernini, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 5811:
# Colonia: alamos 2da seccion, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 5983:
# Colonia: las flores, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76135.0, Tipo_Asentamiento: Fraccionamiento
# ---
# Combinación 6011:
# Colonia: hacienda grande, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76230.0, Tipo_Asentamiento: Fraccionamiento
# ---
# Combinación 6181:
# Colonia: claustros de la corregidora 2, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76093.0, Tipo_Asentamiento: Fraccionamiento
# ---
# Combinación 6269:
# Colonia: san javier, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76020.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 6379:
# Colonia: los naranjos 3, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 6419:
# Colonia: fracc villas del cimatario, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 6491:
# Colonia: fray junipero serra, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 6657:
# Colonia: res claustros de la catedral, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 6798:
# Colonia: aragon, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 6802:
# Colonia: jockey club, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 6808:
# Colonia: vista diamante, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 6824:
# Colonia: fracc real de juriquilla prados, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 6911:
# Colonia: vista lago, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 6937:
# Colonia: fracc rinconada san joaquin, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 7125:
# Colonia: rinconada jurica, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76100.0, Tipo_Asentamiento: Fraccionamiento
# ---
# Combinación 7154:
# Colonia: fracc el pedregal de queretaro, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 7205:
# Colonia: angeles, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 7226:
# Colonia: el pedregal, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76220.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 7234:
# Colonia: jacarandas, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76168.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 7401:
# Colonia: res claustros de las misiones, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 7402:
# Colonia: san angel, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 7509:
# Colonia: las gemas, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76168.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 7663:
# Colonia: el progreso, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76138.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 7876:
# Colonia: fracc balcones del acueducto, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 7903:
# Colonia: independencia, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76118.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 7911:
# Colonia: unidad hab misiones de jurica, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 8064:
# Colonia: mompani, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 8084:
# Colonia: la rica, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 8136:
# Colonia: primavera, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 8173:
# Colonia: lomas de lindavista, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76168.0, Tipo_Asentamiento: Fraccionamiento
# ---
# Combinación 8426:
# Colonia: hidalgo, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76057.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 8472:
# Colonia: los virreyes, Municipio: Querétaro, Estado: Querétaro, Codigo_Postal: 76175.0, Tipo_Asentamiento: Colonia
# ---
# Combinación 8935:
# Colonia: claustro de las misiones 1, Municipio: Santiago de Querétaro, Estado: Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---
# Combinación 9323:
# Colonia: el campanario, Municipio: El Campanario, Estado: Santiago de Querétaro, Querétaro, Codigo_Postal: nan, Tipo_Asentamiento: None
# ---

# %% [markdown]
# ____
# # 11. Variables oficiales

# %% [markdown]
# ## a) Precios

# %%
df[['precio','denominacion','precio_desc','precio_mxn','precio_usd','fecha_conversion']]

# %%
df = df.drop(['denominacion', 'precio_desc',], axis=1, errors='ignore') #'fecha_conversion'

# %% [markdown]
# ## b) Baños

# %%
df[['banos','medio_banos','baños_desc','baños_completos','medios_baños','bano_total']]

# %%
df = df.drop(['baños_desc','baños_completos','medios_baños'], axis=1, errors='ignore')

# %% [markdown]
# # 12. Estandarizar

# %% [markdown]
# #### Propiedad

# %%
# Convierte todos los valores a strings, maneja NaN o None como cadenas vacías
df['propiedad'] = df['propiedad'].astype(str)
# Convertir a minúsculas
df['propiedad'] = df['propiedad'].str.lower()

import unicodedata# Función para eliminar acentos
def eliminar_acentos(texto):
    # Normaliza y elimina los acentos
    texto_normalizado = unicodedata.normalize('NFKD', texto)
    return ''.join(char for char in texto_normalizado if unicodedata.category(char) != 'Mn')
df['propiedad'] = df['propiedad'].apply(eliminar_acentos)

# Reemplazar Ñ
df['propiedad'] = df['propiedad'].str.replace('ñ', 'n')
df['propiedad'] = df['propiedad'].str.replace(r'[^a-zA-Z0-9\s]', '', regex=True)

# %% [markdown]
# #### Ubicación

# %%
# Convierte todos los valores a strings, maneja NaN o None como cadenas vacías
df['ubicacion'] = df['ubicacion'].astype(str)
# Convertir a minúsculas
df['ubicacion'] = df['ubicacion'].str.lower()

import unicodedata# Función para eliminar acentos
def eliminar_acentos(texto):
    # Normaliza y elimina los acentos
    texto_normalizado = unicodedata.normalize('NFKD', texto)
    return ''.join(char for char in texto_normalizado if unicodedata.category(char) != 'Mn')
df['ubicacion'] = df['ubicacion'].apply(eliminar_acentos)

# Reemplazar Ñ
df['ubicacion'] = df['ubicacion'].str.replace('ñ', 'n')
df['ubicacion'] = df['ubicacion'].str.replace(r'[^a-zA-Z0-9\s]', '', regex=True)

# %% [markdown]
# #### Descripción

# %%
# Convierte todos los valores a strings, maneja NaN o None como cadenas vacías
df['descripcion'] = df['descripcion'].astype(str)
# Convertir a minúsculas
df['descripcion'] = df['descripcion'].str.lower()

import unicodedata# Función para eliminar acentos
def eliminar_acentos(texto):
    # Normaliza y elimina los acentos
    texto_normalizado = unicodedata.normalize('NFKD', texto)
    return ''.join(char for char in texto_normalizado if unicodedata.category(char) != 'Mn')
df['descripcion'] = df['descripcion'].apply(eliminar_acentos)

# Reemplazar Ñ
df['descripcion'] = df['descripcion'].str.replace('ñ', 'n')
df['descripcion'] = df['descripcion'].str.replace(r'[^a-zA-Z0-9\s]', '', regex=True)

# %% [markdown]
# # 13. Exportar

# %% [markdown]
# LAS VARIABLES CON LAS QUE SE ESPERA TENER PARA SQL SON:
# * id
# * categoria
# * propiedad
# * precio
# * tipo
# * personas_interesadas
# * m2_total (metros_total)
# * m2_contruido
# * precio_m2_terreno
# * precio_m2_contruido
# * promedio
# * baño
# * medio_baño
# * baño_total
# * estacionamiento
# * recamaras
# * antiguedad
# * publicado_hace
# * status(Estado)

# %%
df.columns
# Out:
# Index(['precio', 'denominacion', 'propiedad', 'metros_total',
#        'metros_construido', 'tiempo_de_publicacion', 'tipo',
#        'estacionamientos', 'recamaras', 'banos', 'medio_banos',
#        'seguridad_privada', 'ubicacion', 'url', 'descripcion',
#        'ubicacion_desc', 'Colonia', 'Municipio', 'Estado', 'TIPO_LUGAR',
#        'Codigo_Postal', 'Tipo_Asentamiento'],
#       dtype='object')

# %%
df['id'] = range(1, len(df) + 1)
df.to_csv('mayo_queretaro_2024.csv', encoding='utf-8', index=False)
